# %%
from maliboo import BayesianOptimization, UtilityFunction
import numpy as np
import os

import matplotlib.pyplot as plt
from matplotlib import gridspec

import pandas as pd
import time
# %matplotlib inline

# %%
# Townsend
def target(x,y):
    return -(-np.cos((x-0.1)*y)**2-x*np.sin(3*x+y))

# %%
def gramacy(x,y):
    return -(x+y)

# %%
# Constraints for Townsend
def constraint(x,y):
    return x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2

# %%
#Constraints for Gramacy
def constraint1(x,y):
    return 3/2 -x-2*y - 1/2*np.sin(2*np.pi*(x**2 - 2*y))

# %%
def constraint2(x,y):
    return x**2 + y**2 - 3/2

# %%
ninit = 10

# %%
# TOWNSEND
resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)

mask = np.where(resultsdf['target'] <= 2.002)[0]
x_iter = resultsdf['x']#.iloc[mask]
y_iter = resultsdf['y']#.iloc[mask]
# plt.hist(x_iter)
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'],first50['y'],s = 10, color = 'red')

# %% [markdown]
# # Gramacy

# %%
# GRAMACY
resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)

# mask = np.where(resultsdf['target'] <= 2.002)[0]
x_iter = resultsdf['x']#.iloc[mask]
y_iter = resultsdf['y']#.iloc[mask]
# plt.hist(x_iter)
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = gramacy(X, Y)
Z_constraint1 = constraint1(X, Y)
Z_constraint2 = constraint2(X,Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint1 <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.contourf(X, Y, Z_constraint2 <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(0.2107769570103368, 0.4055921617970899, color = 'black')
plt.scatter(0.1954, 0.40449, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'],first50['y'],s = 10, color = 'red')

# %% [markdown]
# # Misha's bird

# %%
def target(x,y):
    return -(np.sin(y)*np.exp((1-np.cos(x))**2) + np.cos(x)*np.exp((1-np.sin(y))**2) + (x - y)**2)

# %%
def constraint(x,y):
    return (x+5)**2 + (y+5)**2 - 25

# %%
resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)

# mask = np.where(resultsdf['target'] <= 2.002)[0]
x_iter = resultsdf['x']#.iloc[mask]
y_iter = resultsdf['y']#.iloc[mask]
# plt.hist(x_iter)
# meshgrid
x = np.linspace(-11, 3, 400)
y = np.linspace(-11, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
# plt.contourf(X, Y, Z_constraint2 <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
#plt.scatter(-6.4139970688576815, -1.5326291848621914, color = 'black')
plt.scatter(-3.1302468, -1.5821422, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'],first50['y'],s = 10, color = 'red')

# %% [markdown]
# # Converging case (acq = 'eb', 1/sigma)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27222
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=120,acq='eb',acq_info={'static_lambda':False})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})
# Out:
# Initializing TargetSpace with bounds: {'x': (-2.25, 2.5), 'y': (-2.5, 1.75)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 50 random points
# Uniform randomly sampled point: value [[ 1.18035032 -1.83222497]]
# Uniform randomly sampled point: value [[-1.01028192 -2.15771642]]
# Uniform randomly sampled point: value [[ 0.35257473 -1.76445162]]
# Uniform randomly sampled point: value [[0.6766644  1.62884233]]
# Uniform randomly sampled point: value [[-1.5622215  -0.89778052]]
# Uniform randomly sampled point: value [[-0.27774101 -1.53644378]]
# Uniform randomly sampled point: value [[ 0.73316997 -1.67048958]]
# Uniform randomly sampled point: value [[0.6358628  1.28281612]]
# Uniform randomly sampled point: value [[-2.24108637 -0.64627599]]
# Uniform randomly sampled point: value [[-0.4630531  -0.56044183]]
# Uniform randomly sampled point: value [[ 0.9974256 -0.7096515]]
# Uniform randomly sampled point: value [[-0.60903039  1.3882366 ]]
# Uniform randomly sampled point: value [[-1.01229852  1.15790308]]
# Uniform randomly sampled point: value [[-1.72041086  0.3174128 ]]
# Uniform randomly sampled point: value [[ 1.5696647  -0.30651708]]
# Uniform randomly sampled point: value [[-1.85495737  1.57856182]]
# Uniform randomly sampled point: value [[ 0.63290518 -0.20093481]]
# Uniform randomly sampled point: value [[-0.64013482 -1.06577754]]
# Uniform randomly sampled point: value [[1.38797323 1.16473935]]
# Uniform randomly sampled point: value [[-0.82056387  0.56206324]]
# Uniform randomly sampled point: value [[ 0.87099226 -1.3966168 ]]
# Uniform randomly sampled point: value [[0.34689288 1.27748223]]
# Uniform randomly sampled point: value [[-0.82159302  0.08201164]]
# Uniform randomly sampled point: value [[0.2458041 0.8193955]]
# Uniform randomly sampled point: value [[-0.94880752 -0.13391692]]
# Uniform randomly sampled point: value [[1.85728711 1.16797939]]
# Uniform randomly sampled point: value [[-0.14685476  0.22168027]]
# Uniform randomly sampled point: value [[0.31593137 1.63517331]]
# Uniform randomly sampled point: value [[-1.73149633  1.42405001]]
# Uniform randomly sampled point: value [[ 0.72057912 -1.48084983]]
# Uniform randomly sampled point: value [[0.34880767 0.05552785]]
# Uniform randomly sampled point: value [[ 0.42208191 -0.09440631]]
# Uniform randomly sampled point: value [[ 0.02765431 -1.22492749]]
# Uniform randomly sampled point: value [[-1.54411934 -1.52009926]]
# Uniform randomly sampled point: value [[-2.00256869  0.05198445]]
# Uniform randomly sampled point: value [[-1.52244084 -1.19073287]]
# Uniform randomly sampled point: value [[ 1.32206587 -2.22464303]]
# Uniform randomly sampled point: value [[0.92828252 1.26893066]]
# Uniform randomly sampled point: value [[1.91541394 1.69821197]]
# Uniform randomly sampled point: value [[ 2.02316195 -1.81181606]]
# Uniform randomly sampled point: value [[-2.01631184  0.07306423]]
# Uniform randomly sampled point: value [[-2.24482886 -2.23576202]]
# Uniform randomly sampled point: value [[1.33523089 0.45697979]]
# Uniform randomly sampled point: value [[ 1.02160119 -2.39086375]]
# Uniform randomly sampled point: value [[-0.8114609  -1.41164763]]
# Uniform randomly sampled point: value [[ 1.8095815  -2.46463651]]
# Uniform randomly sampled point: value [[-1.15098272  0.76947939]]
# Uniform randomly sampled point: value [[0.81677548 0.239688  ]]
# Uniform randomly sampled point: value [[ 1.07748948 -1.62917832]]
# Uniform randomly sampled point: value [[-2.13754343  0.68446887]]
# Initializing UtilityFunction of kind 'eb' with acq_info = {'static_lambda': False}
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Registering params [ 1.18035032 -1.83222497] with index None and target value 1.3270265354343607
# Extracting info: target 1.3270265354343607 is scalar
# Point registered successfully
# Probed target value: 1.3270265354343607
# Probing_barriers at point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Probed barrier_target values: [0.18360093]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Registering params [-1.01028192 -2.15771642] with index None and target value -0.35845564463978297
# Extracting info: target -0.35845564463978297 is scalar
# Point registered successfully
# Probed target value: -0.35845564463978297
# Probing_barriers at point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Probed barrier_target values: [0.7733769]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Registering params [ 0.35257473 -1.76445162] with index None and target value 0.5852521951186401
# Extracting info: target 0.5852521951186401 is scalar
# Point registered successfully
# Probed target value: 0.5852521951186401
# Probing_barriers at point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Probed barrier_target values: [-2.22167925]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Registering params [0.6766644  1.62884233] with index None and target value 0.013920491460077067
# Extracting info: target 0.013920491460077067 is scalar
# Point registered successfully
# Probed target value: 0.013920491460077067
# Probing_barriers at point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Probed barrier_target values: [0.56309916]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Registering params [-1.5622215  -0.89778052] with index None and target value -0.9987572867564634
# Extracting info: target -0.9987572867564634 is scalar
# Point registered successfully
# Probed target value: -0.9987572867564634
# Probing_barriers at point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Probed barrier_target values: [-0.63117354]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Registering params [-0.27774101 -1.53644378] with index None and target value 0.8930522558345727
# Extracting info: target 0.8930522558345727 is scalar
# Point registered successfully
# Probed target value: 0.8930522558345727
# Probing_barriers at point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Probed barrier_target values: [-3.0523649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Registering params [ 0.73316997 -1.67048958] with index None and target value 0.6109791136386856
# Extracting info: target 0.6109791136386856 is scalar
# Point registered successfully
# Probed target value: 0.6109791136386856
# Probing_barriers at point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Probed barrier_target values: [-1.63776548]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Registering params [0.6358628  1.28281612] with index None and target value 0.5663334311696665
# Extracting info: target 0.5663334311696665 is scalar
# Point registered successfully
# Probed target value: 0.5663334311696665
# Probing_barriers at point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Probed barrier_target values: [-0.91532842]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Registering params [-2.24108637 -0.64627599] with index None and target value 1.9865490231616305
# Extracting info: target 1.9865490231616305 is scalar
# Point registered successfully
# Probed target value: 1.9865490231616305
# Probing_barriers at point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Probed barrier_target values: [1.60915501]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Registering params [-0.4630531  -0.56044183] with index None and target value 1.333910472267051
# Extracting info: target 1.333910472267051 is scalar
# Point registered successfully
# Probed target value: 1.333910472267051
# Probing_barriers at point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Probed barrier_target values: [-3.78401684]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Registering params [ 0.9974256 -0.7096515] with index None and target value 1.401582650132049
# Extracting info: target 1.401582650132049 is scalar
# Point registered successfully
# Probed target value: 1.401582650132049
# Probing_barriers at point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Probed barrier_target values: [-2.45079968]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Registering params [-0.60903039  1.3882366 ] with index None and target value 0.5650797426098781
# Extracting info: target 0.5650797426098781 is scalar
# Point registered successfully
# Probed target value: 0.5650797426098781
# Probing_barriers at point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Probed barrier_target values: [-0.36990276]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Registering params [-1.01229852  1.15790308] with index None and target value 1.0425012077544027
# Extracting info: target 1.0425012077544027 is scalar
# Point registered successfully
# Probed target value: 1.0425012077544027
# Probing_barriers at point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Probed barrier_target values: [-2.24846974]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Registering params [-1.72041086  0.3174128 ] with index None and target value -1.0039080714402764
# Extracting info: target -1.0039080714402764 is scalar
# Point registered successfully
# Probed target value: -1.0039080714402764
# Probing_barriers at point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Probed barrier_target values: [-1.55926262]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Registering params [ 1.5696647  -0.30651708] with index None and target value -0.6844556040178207
# Extracting info: target -0.6844556040178207 is scalar
# Point registered successfully
# Probed target value: -0.6844556040178207
# Probing_barriers at point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Probed barrier_target values: [-1.31669448]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Registering params [-1.85495737  1.57856182] with index None and target value -0.3901918275873201
# Extracting info: target -0.3901918275873201 is scalar
# Point registered successfully
# Probed target value: -0.3901918275873201
# Probing_barriers at point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Probed barrier_target values: [0.69342346]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Registering params [ 0.63290518 -0.20093481] with index None and target value 1.616387021720416
# Extracting info: target 1.616387021720416 is scalar
# Point registered successfully
# Probed target value: 1.616387021720416
# Probing_barriers at point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Probed barrier_target values: [-3.38448171]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Registering params [-0.64013482 -1.06577754] with index None and target value 0.5956629026120582
# Extracting info: target 0.5956629026120582 is scalar
# Point registered successfully
# Probed target value: 0.5956629026120582
# Probing_barriers at point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Probed barrier_target values: [-3.09645169]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Registering params [1.38797323 1.16473935] with index None and target value -1.127659533198751
# Extracting info: target -1.127659533198751 is scalar
# Point registered successfully
# Probed target value: -1.127659533198751
# Probing_barriers at point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Probed barrier_target values: [-1.97579095]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Registering params [-0.82056387  0.56206324] with index None and target value 1.531934146537457
# Extracting info: target 1.531934146537457 is scalar
# Point registered successfully
# Probed target value: 1.531934146537457
# Probing_barriers at point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Probed barrier_target values: [-4.44465582]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Registering params [ 0.87099226 -1.3966168 ] with index None and target value 1.0416859521454194
# Extracting info: target 1.0416859521454194 is scalar
# Point registered successfully
# Probed target value: 1.0416859521454194
# Probing_barriers at point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Probed barrier_target values: [-1.89240184]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Registering params [0.34689288 1.27748223] with index None and target value 1.1582171615386736
# Extracting info: target 1.1582171615386736 is scalar
# Point registered successfully
# Probed target value: 1.1582171615386736
# Probing_barriers at point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Probed barrier_target values: [-0.11691927]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Registering params [-0.82159302  0.08201164] with index None and target value 1.5596113849454376
# Extracting info: target 1.5596113849454376 is scalar
# Point registered successfully
# Probed target value: 1.5596113849454376
# Probing_barriers at point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Probed barrier_target values: [-3.69749675]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Registering params [0.2458041 0.8193955] with index None and target value 1.2315744617174662
# Extracting info: target 1.2315744617174662 is scalar
# Point registered successfully
# Probed target value: 1.2315744617174662
# Probing_barriers at point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Probed barrier_target values: [-1.2588649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Registering params [-0.94880752 -0.13391692] with index None and target value 1.1327383432973934
# Extracting info: target 1.1327383432973934 is scalar
# Point registered successfully
# Probed target value: 1.1327383432973934
# Probing_barriers at point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Probed barrier_target values: [-3.00375108]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Registering params [1.85728711 1.16797939] with index None and target value 1.0335852024912042
# Extracting info: target 1.0335852024912042 is scalar
# Point registered successfully
# Probed target value: 1.0335852024912042
# Probing_barriers at point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Probed barrier_target values: [-0.63768823]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Registering params [-0.14685476  0.22168027] with index None and target value 1.028896498407277
# Extracting info: target 1.028896498407277 is scalar
# Point registered successfully
# Probed target value: 1.028896498407277
# Probing_barriers at point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Probed barrier_target values: [-3.72585397]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Registering params [0.31593137 1.63517331] with index None and target value 1.0478765103082408
# Extracting info: target 1.0478765103082408 is scalar
# Point registered successfully
# Probed target value: 1.0478765103082408
# Probing_barriers at point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Probed barrier_target values: [1.1914944]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Registering params [-1.73149633  1.42405001] with index None and target value -0.27706681223960516
# Extracting info: target -0.27706681223960516 is scalar
# Point registered successfully
# Probed target value: -0.27706681223960516
# Probing_barriers at point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Probed barrier_target values: [-0.25930596]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Registering params [ 0.72057912 -1.48084983] with index None and target value 0.8215895072673417
# Extracting info: target 0.8215895072673417 is scalar
# Point registered successfully
# Probed target value: 0.8215895072673417
# Probing_barriers at point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Probed barrier_target values: [-2.15223167]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Registering params [0.34880767 0.05552785] with index None and target value 1.3109771707802058
# Extracting info: target 1.3109771707802058 is scalar
# Point registered successfully
# Probed target value: 1.3109771707802058
# Probing_barriers at point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Probed barrier_target values: [-4.42093903]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Registering params [ 0.42208191 -0.09440631] with index None and target value 1.388010141439827
# Extracting info: target 1.388010141439827 is scalar
# Point registered successfully
# Probed target value: 1.388010141439827
# Probing_barriers at point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Probed barrier_target values: [-3.66950243]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Registering params [ 0.02765431 -1.22492749] with index None and target value 0.9670170771123171
# Extracting info: target 0.9670170771123171 is scalar
# Point registered successfully
# Probed target value: 0.9670170771123171
# Probing_barriers at point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Probed barrier_target values: [-4.13691477]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Registering params [-1.54411934 -1.52009926] with index None and target value 0.43980216489469337
# Extracting info: target 0.43980216489469337 is scalar
# Point registered successfully
# Probed target value: 0.43980216489469337
# Probing_barriers at point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Probed barrier_target values: [0.55769396]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Registering params [-2.00256869  0.05198445] with index None and target value 0.3439895360116495
# Extracting info: target 0.3439895360116495 is scalar
# Point registered successfully
# Probed target value: 0.3439895360116495
# Probing_barriers at point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Probed barrier_target values: [-0.18354646]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Registering params [-1.52244084 -1.19073287] with index None and target value -0.6384166908160336
# Extracting info: target -0.6384166908160336 is scalar
# Point registered successfully
# Probed target value: -0.6384166908160336
# Probing_barriers at point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Probed barrier_target values: [-0.25763418]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Registering params [ 1.32206587 -2.22464303] with index None and target value 2.1343801557620763
# Extracting info: target 2.1343801557620763 is scalar
# Point registered successfully
# Probed target value: 2.1343801557620763
# Probing_barriers at point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Probed barrier_target values: [2.04334017]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Registering params [0.92828252 1.26893066] with index None and target value -0.48744022805628173
# Extracting info: target -0.48744022805628173 is scalar
# Point registered successfully
# Probed target value: -0.48744022805628173
# Probing_barriers at point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Probed barrier_target values: [-1.62672166]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Registering params [1.91541394 1.69821197] with index None and target value 2.7535921962394094
# Extracting info: target 2.7535921962394094 is scalar
# Point registered successfully
# Probed target value: 2.7535921962394094
# Probing_barriers at point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Probed barrier_target values: [1.37639855]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Registering params [ 2.02316195 -1.81181606] with index None and target value -0.9305720658093499
# Extracting info: target -0.9305720658093499 is scalar
# Point registered successfully
# Probed target value: -0.9305720658093499
# Probing_barriers at point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Probed barrier_target values: [3.30441413]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Registering params [-2.01631184  0.07306423] with index None and target value 0.36634704489999537
# Extracting info: target 0.36634704489999537 is scalar
# Point registered successfully
# Probed target value: 0.36634704489999537
# Probing_barriers at point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Probed barrier_target values: [-0.14908712]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Registering params [-2.24482886 -2.23576202] with index None and target value 1.2412113033403984
# Extracting info: target 1.2412113033403984 is scalar
# Point registered successfully
# Probed target value: 1.2412113033403984
# Probing_barriers at point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Probed barrier_target values: [5.89183547]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Registering params [1.33523089 0.45697979] with index None and target value -0.5800112932865991
# Extracting info: target -0.5800112932865991 is scalar
# Point registered successfully
# Probed target value: -0.5800112932865991
# Probing_barriers at point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Probed barrier_target values: [-3.07860715]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Registering params [ 1.02160119 -2.39086375] with index None and target value 0.9871442737234035
# Extracting info: target 0.9871442737234035 is scalar
# Point registered successfully
# Probed target value: 0.9871442737234035
# Probing_barriers at point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Probed barrier_target values: [1.76890236]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Registering params [-0.8114609  -1.41164763] with index None and target value -0.4469232927980537
# Extracting info: target -0.4469232927980537 is scalar
# Point registered successfully
# Probed target value: -0.4469232927980537
# Probing_barriers at point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Probed barrier_target values: [-2.03815483]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Registering params [ 1.8095815  -2.46463651] with index None and target value 0.5484065664145346
# Extracting info: target 0.5484065664145346 is scalar
# Point registered successfully
# Probed target value: 0.5484065664145346
# Probing_barriers at point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Probed barrier_target values: [4.92000509]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Registering params [-1.15098272  0.76947939] with index None and target value 0.8355201335245834
# Extracting info: target 0.8355201335245834 is scalar
# Point registered successfully
# Probed target value: 0.8355201335245834
# Probing_barriers at point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Probed barrier_target values: [-3.52507109]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Registering params [0.81677548 0.239688  ] with index None and target value 1.3272026196874078
# Extracting info: target 1.3272026196874078 is scalar
# Point registered successfully
# Probed target value: 1.3272026196874078
# Probing_barriers at point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Probed barrier_target values: [-4.21432764]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# Registering params [ 1.07748948 -1.62917832] with index None and target value 1.077391872799466
# Extracting info: target 1.077391872799466 is scalar
# Point registered successfully
# Probed target value: 1.077391872799466
# Probing_barriers at point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# ...
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.00365766]), 'y': array([1.19739611])}
# Registering params [2.00365766 1.19739611] with index None and target value 2.023923166521236
# Extracting info: target 2.023923166521236 is scalar
# Point registered successfully
# Probed target value: 2.023923166521236
# Probing_barriers at point: index None, value {'x': array([2.00365766]), 'y': array([1.19739611])}
# Probed barrier_target values: [-1.52482181e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     2.023913      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 106: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75235593]
#  [-0.32913227]]) = 1.6594885975547906
# Suggested point: index None, value {'x': array([0.75235593]), 'y': array([-0.32913227])}, acquisition 1.6594885975547906
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75235593]), 'y': array([-0.32913227])}
# Registering params [ 0.75235593 -0.32913227] with index None and target value 1.659485971424801
# Extracting info: target 1.659485971424801 is scalar
# Point registered successfully
# Probed target value: 1.659485971424801
# Probing_barriers at point: index None, value {'x': array([0.75235593]), 'y': array([-0.32913227])}
# Probed barrier_target values: [-3.15726695]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659489      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 107: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75235358]
#  [-0.32913435]]) = 1.6594885513325461
# Suggested point: index None, value {'x': array([0.75235358]), 'y': array([-0.32913435])}, acquisition 1.6594885513325461
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75235358]), 'y': array([-0.32913435])}
# Registering params [ 0.75235358 -0.32913435] with index None and target value 1.659485928124887
# Extracting info: target 1.659485928124887 is scalar
# Point registered successfully
# Probed target value: 1.659485928124887
# Probing_barriers at point: index None, value {'x': array([0.75235358]), 'y': array([-0.32913435])}
# Probed barrier_target values: [-3.15726997]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659489      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 108: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.0020131 ]
#  [1.20033682]]) = 2.0237838197626714
# Suggested point: index None, value {'x': array([2.0020131]), 'y': array([1.20033682])}, acquisition 2.0237838197626714
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.0020131]), 'y': array([1.20033682])}
# Registering params [2.0020131  1.20033682] with index None and target value 2.0237891890374238
# Extracting info: target 2.0237891890374238 is scalar
# Point registered successfully
# Probed target value: 2.0237891890374238
# Probing_barriers at point: index None, value {'x': array([2.0020131]), 'y': array([1.20033682])}
# Probed barrier_target values: [-1.55134488e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     2.023784      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 109: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75235157]
#  [-0.3291383 ]]) = 1.6594885077634747
# Suggested point: index None, value {'x': array([0.75235157]), 'y': array([-0.3291383])}, acquisition 1.6594885077634747
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75235157]), 'y': array([-0.3291383])}
# Registering params [ 0.75235157 -0.3291383 ] with index None and target value 1.6594858723167847
# Extracting info: target 1.6594858723167847 is scalar
# Point registered successfully
# Probed target value: 1.6594858723167847
# Probing_barriers at point: index None, value {'x': array([0.75235157]), 'y': array([-0.3291383])}
# Probed barrier_target values: [-3.15727174]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659489      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 110: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75234929]
#  [-0.32914033]]) = 1.6594884629000364
# Suggested point: index None, value {'x': array([0.75234929]), 'y': array([-0.32914033])}, acquisition 1.6594884629000364
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75234929]), 'y': array([-0.32914033])}
# Registering params [ 0.75234929 -0.32914033] with index None and target value 1.6594858301630766
# Extracting info: target 1.6594858301630766 is scalar
# Point registered successfully
# Probed target value: 1.6594858301630766
# Probing_barriers at point: index None, value {'x': array([0.75234929]), 'y': array([-0.32914033])}
# Probed barrier_target values: [-3.15727467]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659488      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 111: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.00454366]
#  [1.19579998]]) = 2.02393678416332
# Suggested point: index None, value {'x': array([2.00454366]), 'y': array([1.19579998])}, acquisition 2.02393678416332
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.00454366]), 'y': array([1.19579998])}
# Registering params [2.00454366 1.19579998] with index None and target value 2.023955554320863
# Extracting info: target 2.023955554320863 is scalar
# Point registered successfully
# Probed target value: 2.023955554320863
# Probing_barriers at point: index None, value {'x': array([2.00454366]), 'y': array([1.19579998])}
# Probed barrier_target values: [-1.72059041e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     2.023937      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 112: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75234794]
#  [-0.32914419]]) = 1.6594884207622849
# Suggested point: index None, value {'x': array([0.75234794]), 'y': array([-0.32914419])}, acquisition 1.6594884207622849
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75234794]), 'y': array([-0.32914419])}
# Registering params [ 0.75234794 -0.32914419] with index None and target value 1.6594857822017433
# Extracting info: target 1.6594857822017433 is scalar
# Point registered successfully
# Probed target value: 1.6594857822017433
# Probing_barriers at point: index None, value {'x': array([0.75234794]), 'y': array([-0.32914419])}
# Probed barrier_target values: [-3.15727541]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659488      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 113: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72769983]
#  [ 0.21000148]]) = 1.6396927122959062
# Suggested point: index None, value {'x': array([-0.72769983]), 'y': array([0.21000148])}, acquisition 1.6396927122959062
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72769983]), 'y': array([0.21000148])}
# Registering params [-0.72769983  0.21000148] with index None and target value 1.6396921880285407
# Extracting info: target 1.6396921880285407 is scalar
# Point registered successfully
# Probed target value: 1.6396921880285407
# Probing_barriers at point: index None, value {'x': array([-0.72769983]), 'y': array([0.21000148])}
# Probed barrier_target values: [-4.35152197]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.639693      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 114: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.00475798]
#  [1.19540958]]) = 2.023935833297561
# Suggested point: index None, value {'x': array([2.00475798]), 'y': array([1.19540958])}, acquisition 2.023935833297561
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.00475798]), 'y': array([1.19540958])}
# Registering params [2.00475798 1.19540958] with index None and target value 2.023949751039037
# Extracting info: target 2.023949751039037 is scalar
# Point registered successfully
# Probed target value: 2.023949751039037
# Probing_barriers at point: index None, value {'x': array([2.00475798]), 'y': array([1.19540958])}
# Probed barrier_target values: [-2.48080059e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     2.023936      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 115: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75234497]
#  [-0.32916049]]) = 1.659488387564443
# Suggested point: index None, value {'x': array([0.75234497]), 'y': array([-0.32916049])}, acquisition 1.659488387564443
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75234497]), 'y': array([-0.32916049])}
# Registering params [ 0.75234497 -0.32916049] with index None and target value 1.6594856090612788
# Extracting info: target 1.6594856090612788 is scalar
# Point registered successfully
# Probed target value: 1.6594856090612788
# Probing_barriers at point: index None, value {'x': array([0.75234497]), 'y': array([-0.32916049])}
# Probed barrier_target values: [-3.15727403]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659488      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 116: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.00457445]
#  [1.19574492]]) = 2.023940440536816
# Suggested point: index None, value {'x': array([2.00457445]), 'y': array([1.19574492])}, acquisition 2.023940440536816
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.00457445]), 'y': array([1.19574492])}
# Registering params [2.00457445 1.19574492] with index None and target value 2.0239579113776247
# Extracting info: target 2.0239579113776247 is scalar
# Point registered successfully
# Probed target value: 2.0239579113776247
# Probing_barriers at point: index None, value {'x': array([2.00457445]), 'y': array([1.19574492])}
# Probed barrier_target values: [-1.60270884e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None      2.02394      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 117: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.0021137]
#  [1.2001589]]) = 2.023793211499472
# Suggested point: index None, value {'x': array([2.0021137]), 'y': array([1.2001589])}, acquisition 2.023793211499472
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.0021137]), 'y': array([1.2001589])}
# Registering params [2.0021137 1.2001589] with index None and target value 2.023803693574673
# Extracting info: target 2.023803693574673 is scalar
# Point registered successfully
# Probed target value: 2.023803693574673
# Probing_barriers at point: index None, value {'x': array([2.0021137]), 'y': array([1.2001589])}
# Probed barrier_target values: [-1.27100761e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     2.023793      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 118: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.75234245]
#  [-0.32916569]]) = 1.6594883453938962
# Suggested point: index None, value {'x': array([0.75234245]), 'y': array([-0.32916569])}, acquisition 1.6594883453938962
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.75234245]), 'y': array([-0.32916569])}
# Registering params [ 0.75234245 -0.32916569] with index None and target value 1.659485536526177
# Extracting info: target 1.659485536526177 is scalar
# Point registered successfully
# Probed target value: 1.659485536526177
# Probing_barriers at point: index None, value {'x': array([0.75234245]), 'y': array([-0.32916569])}
# Probed barrier_target values: [-3.15727616]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.659488      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 119: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.00577473]
#  [1.19357317]]) = 2.023881840305112
# Suggested point: index None, value {'x': array([2.00577473]), 'y': array([1.19357317])}, acquisition 2.023881840305112
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.00577473]), 'y': array([1.19357317])}
# Registering params [2.00577473 1.19357317] with index None and target value 2.023968945773401
# Extracting info: target 2.023968945773401 is scalar
# Point registered successfully
# Probed target value: 2.023968945773401
# Probing_barriers at point: index None, value {'x': array([2.00577473]), 'y': array([1.19357317])}
# Probed barrier_target values: [-1.13433144e-05]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     2.023882      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# max: {'target': 2.023968945773401, 'params': {'x': 2.0057747253834384, 'y': 1.1935731692870515}}
# Results successfully saved to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# =================================================

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[:50]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')
plt.scatter(x_iter[:-1], y_iter[:-1], s=20, alpha = 0.5)
plt.scatter(x_iter.iloc[-1], y_iter.iloc[-1], s=20, alpha = 0.5, color = 'black')
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)

plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()
# Out:
# first occurrence of maximum at iteration: 119

# %% [markdown]
# # (acq = 'eb', fixed gamma = 1e6)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27222
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=120,acq='eb',acq_info={'static_lambda':True, 'lam': 1e-6})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})
# Out:
# Initializing TargetSpace with bounds: {'x': (-2.25, 2.5), 'y': (-2.5, 1.75)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 50 random points
# Uniform randomly sampled point: value [[ 1.18035032 -1.83222497]]
# Uniform randomly sampled point: value [[-1.01028192 -2.15771642]]
# Uniform randomly sampled point: value [[ 0.35257473 -1.76445162]]
# Uniform randomly sampled point: value [[0.6766644  1.62884233]]
# Uniform randomly sampled point: value [[-1.5622215  -0.89778052]]
# Uniform randomly sampled point: value [[-0.27774101 -1.53644378]]
# Uniform randomly sampled point: value [[ 0.73316997 -1.67048958]]
# Uniform randomly sampled point: value [[0.6358628  1.28281612]]
# Uniform randomly sampled point: value [[-2.24108637 -0.64627599]]
# Uniform randomly sampled point: value [[-0.4630531  -0.56044183]]
# Uniform randomly sampled point: value [[ 0.9974256 -0.7096515]]
# Uniform randomly sampled point: value [[-0.60903039  1.3882366 ]]
# Uniform randomly sampled point: value [[-1.01229852  1.15790308]]
# Uniform randomly sampled point: value [[-1.72041086  0.3174128 ]]
# Uniform randomly sampled point: value [[ 1.5696647  -0.30651708]]
# Uniform randomly sampled point: value [[-1.85495737  1.57856182]]
# Uniform randomly sampled point: value [[ 0.63290518 -0.20093481]]
# Uniform randomly sampled point: value [[-0.64013482 -1.06577754]]
# Uniform randomly sampled point: value [[1.38797323 1.16473935]]
# Uniform randomly sampled point: value [[-0.82056387  0.56206324]]
# Uniform randomly sampled point: value [[ 0.87099226 -1.3966168 ]]
# Uniform randomly sampled point: value [[0.34689288 1.27748223]]
# Uniform randomly sampled point: value [[-0.82159302  0.08201164]]
# Uniform randomly sampled point: value [[0.2458041 0.8193955]]
# Uniform randomly sampled point: value [[-0.94880752 -0.13391692]]
# Uniform randomly sampled point: value [[1.85728711 1.16797939]]
# Uniform randomly sampled point: value [[-0.14685476  0.22168027]]
# Uniform randomly sampled point: value [[0.31593137 1.63517331]]
# Uniform randomly sampled point: value [[-1.73149633  1.42405001]]
# Uniform randomly sampled point: value [[ 0.72057912 -1.48084983]]
# Uniform randomly sampled point: value [[0.34880767 0.05552785]]
# Uniform randomly sampled point: value [[ 0.42208191 -0.09440631]]
# Uniform randomly sampled point: value [[ 0.02765431 -1.22492749]]
# Uniform randomly sampled point: value [[-1.54411934 -1.52009926]]
# Uniform randomly sampled point: value [[-2.00256869  0.05198445]]
# Uniform randomly sampled point: value [[-1.52244084 -1.19073287]]
# Uniform randomly sampled point: value [[ 1.32206587 -2.22464303]]
# Uniform randomly sampled point: value [[0.92828252 1.26893066]]
# Uniform randomly sampled point: value [[1.91541394 1.69821197]]
# Uniform randomly sampled point: value [[ 2.02316195 -1.81181606]]
# Uniform randomly sampled point: value [[-2.01631184  0.07306423]]
# Uniform randomly sampled point: value [[-2.24482886 -2.23576202]]
# Uniform randomly sampled point: value [[1.33523089 0.45697979]]
# Uniform randomly sampled point: value [[ 1.02160119 -2.39086375]]
# Uniform randomly sampled point: value [[-0.8114609  -1.41164763]]
# Uniform randomly sampled point: value [[ 1.8095815  -2.46463651]]
# Uniform randomly sampled point: value [[-1.15098272  0.76947939]]
# Uniform randomly sampled point: value [[0.81677548 0.239688  ]]
# Uniform randomly sampled point: value [[ 1.07748948 -1.62917832]]
# Uniform randomly sampled point: value [[-2.13754343  0.68446887]]
# Initializing UtilityFunction of kind 'eb' with acq_info = {'static_lambda': True, 'lam': 1e-06}
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Registering params [ 1.18035032 -1.83222497] with index None and target value 1.3270265354343607
# Extracting info: target 1.3270265354343607 is scalar
# Point registered successfully
# Probed target value: 1.3270265354343607
# Probing_barriers at point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Probed barrier_target values: [0.18360093]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Registering params [-1.01028192 -2.15771642] with index None and target value -0.35845564463978297
# Extracting info: target -0.35845564463978297 is scalar
# Point registered successfully
# Probed target value: -0.35845564463978297
# Probing_barriers at point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Probed barrier_target values: [0.7733769]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Registering params [ 0.35257473 -1.76445162] with index None and target value 0.5852521951186401
# Extracting info: target 0.5852521951186401 is scalar
# Point registered successfully
# Probed target value: 0.5852521951186401
# Probing_barriers at point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Probed barrier_target values: [-2.22167925]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Registering params [0.6766644  1.62884233] with index None and target value 0.013920491460077067
# Extracting info: target 0.013920491460077067 is scalar
# Point registered successfully
# Probed target value: 0.013920491460077067
# Probing_barriers at point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Probed barrier_target values: [0.56309916]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Registering params [-1.5622215  -0.89778052] with index None and target value -0.9987572867564634
# Extracting info: target -0.9987572867564634 is scalar
# Point registered successfully
# Probed target value: -0.9987572867564634
# Probing_barriers at point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Probed barrier_target values: [-0.63117354]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Registering params [-0.27774101 -1.53644378] with index None and target value 0.8930522558345727
# Extracting info: target 0.8930522558345727 is scalar
# Point registered successfully
# Probed target value: 0.8930522558345727
# Probing_barriers at point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Probed barrier_target values: [-3.0523649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Registering params [ 0.73316997 -1.67048958] with index None and target value 0.6109791136386856
# Extracting info: target 0.6109791136386856 is scalar
# Point registered successfully
# Probed target value: 0.6109791136386856
# Probing_barriers at point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Probed barrier_target values: [-1.63776548]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Registering params [0.6358628  1.28281612] with index None and target value 0.5663334311696665
# Extracting info: target 0.5663334311696665 is scalar
# Point registered successfully
# Probed target value: 0.5663334311696665
# Probing_barriers at point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Probed barrier_target values: [-0.91532842]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Registering params [-2.24108637 -0.64627599] with index None and target value 1.9865490231616305
# Extracting info: target 1.9865490231616305 is scalar
# Point registered successfully
# Probed target value: 1.9865490231616305
# Probing_barriers at point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Probed barrier_target values: [1.60915501]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Registering params [-0.4630531  -0.56044183] with index None and target value 1.333910472267051
# Extracting info: target 1.333910472267051 is scalar
# Point registered successfully
# Probed target value: 1.333910472267051
# Probing_barriers at point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Probed barrier_target values: [-3.78401684]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Registering params [ 0.9974256 -0.7096515] with index None and target value 1.401582650132049
# Extracting info: target 1.401582650132049 is scalar
# Point registered successfully
# Probed target value: 1.401582650132049
# Probing_barriers at point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Probed barrier_target values: [-2.45079968]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Registering params [-0.60903039  1.3882366 ] with index None and target value 0.5650797426098781
# Extracting info: target 0.5650797426098781 is scalar
# Point registered successfully
# Probed target value: 0.5650797426098781
# Probing_barriers at point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Probed barrier_target values: [-0.36990276]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Registering params [-1.01229852  1.15790308] with index None and target value 1.0425012077544027
# Extracting info: target 1.0425012077544027 is scalar
# Point registered successfully
# Probed target value: 1.0425012077544027
# Probing_barriers at point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Probed barrier_target values: [-2.24846974]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Registering params [-1.72041086  0.3174128 ] with index None and target value -1.0039080714402764
# Extracting info: target -1.0039080714402764 is scalar
# Point registered successfully
# Probed target value: -1.0039080714402764
# Probing_barriers at point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Probed barrier_target values: [-1.55926262]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Registering params [ 1.5696647  -0.30651708] with index None and target value -0.6844556040178207
# Extracting info: target -0.6844556040178207 is scalar
# Point registered successfully
# Probed target value: -0.6844556040178207
# Probing_barriers at point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Probed barrier_target values: [-1.31669448]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Registering params [-1.85495737  1.57856182] with index None and target value -0.3901918275873201
# Extracting info: target -0.3901918275873201 is scalar
# Point registered successfully
# Probed target value: -0.3901918275873201
# Probing_barriers at point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Probed barrier_target values: [0.69342346]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Registering params [ 0.63290518 -0.20093481] with index None and target value 1.616387021720416
# Extracting info: target 1.616387021720416 is scalar
# Point registered successfully
# Probed target value: 1.616387021720416
# Probing_barriers at point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Probed barrier_target values: [-3.38448171]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Registering params [-0.64013482 -1.06577754] with index None and target value 0.5956629026120582
# Extracting info: target 0.5956629026120582 is scalar
# Point registered successfully
# Probed target value: 0.5956629026120582
# Probing_barriers at point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Probed barrier_target values: [-3.09645169]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Registering params [1.38797323 1.16473935] with index None and target value -1.127659533198751
# Extracting info: target -1.127659533198751 is scalar
# Point registered successfully
# Probed target value: -1.127659533198751
# Probing_barriers at point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Probed barrier_target values: [-1.97579095]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Registering params [-0.82056387  0.56206324] with index None and target value 1.531934146537457
# Extracting info: target 1.531934146537457 is scalar
# Point registered successfully
# Probed target value: 1.531934146537457
# Probing_barriers at point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Probed barrier_target values: [-4.44465582]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Registering params [ 0.87099226 -1.3966168 ] with index None and target value 1.0416859521454194
# Extracting info: target 1.0416859521454194 is scalar
# Point registered successfully
# Probed target value: 1.0416859521454194
# Probing_barriers at point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Probed barrier_target values: [-1.89240184]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Registering params [0.34689288 1.27748223] with index None and target value 1.1582171615386736
# Extracting info: target 1.1582171615386736 is scalar
# Point registered successfully
# Probed target value: 1.1582171615386736
# Probing_barriers at point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Probed barrier_target values: [-0.11691927]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Registering params [-0.82159302  0.08201164] with index None and target value 1.5596113849454376
# Extracting info: target 1.5596113849454376 is scalar
# Point registered successfully
# Probed target value: 1.5596113849454376
# Probing_barriers at point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Probed barrier_target values: [-3.69749675]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Registering params [0.2458041 0.8193955] with index None and target value 1.2315744617174662
# Extracting info: target 1.2315744617174662 is scalar
# Point registered successfully
# Probed target value: 1.2315744617174662
# Probing_barriers at point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Probed barrier_target values: [-1.2588649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Registering params [-0.94880752 -0.13391692] with index None and target value 1.1327383432973934
# Extracting info: target 1.1327383432973934 is scalar
# Point registered successfully
# Probed target value: 1.1327383432973934
# Probing_barriers at point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Probed barrier_target values: [-3.00375108]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Registering params [1.85728711 1.16797939] with index None and target value 1.0335852024912042
# Extracting info: target 1.0335852024912042 is scalar
# Point registered successfully
# Probed target value: 1.0335852024912042
# Probing_barriers at point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Probed barrier_target values: [-0.63768823]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Registering params [-0.14685476  0.22168027] with index None and target value 1.028896498407277
# Extracting info: target 1.028896498407277 is scalar
# Point registered successfully
# Probed target value: 1.028896498407277
# Probing_barriers at point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Probed barrier_target values: [-3.72585397]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Registering params [0.31593137 1.63517331] with index None and target value 1.0478765103082408
# Extracting info: target 1.0478765103082408 is scalar
# Point registered successfully
# Probed target value: 1.0478765103082408
# Probing_barriers at point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Probed barrier_target values: [1.1914944]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Registering params [-1.73149633  1.42405001] with index None and target value -0.27706681223960516
# Extracting info: target -0.27706681223960516 is scalar
# Point registered successfully
# Probed target value: -0.27706681223960516
# Probing_barriers at point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Probed barrier_target values: [-0.25930596]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Registering params [ 0.72057912 -1.48084983] with index None and target value 0.8215895072673417
# Extracting info: target 0.8215895072673417 is scalar
# Point registered successfully
# Probed target value: 0.8215895072673417
# Probing_barriers at point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Probed barrier_target values: [-2.15223167]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Registering params [0.34880767 0.05552785] with index None and target value 1.3109771707802058
# Extracting info: target 1.3109771707802058 is scalar
# Point registered successfully
# Probed target value: 1.3109771707802058
# Probing_barriers at point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Probed barrier_target values: [-4.42093903]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Registering params [ 0.42208191 -0.09440631] with index None and target value 1.388010141439827
# Extracting info: target 1.388010141439827 is scalar
# Point registered successfully
# Probed target value: 1.388010141439827
# Probing_barriers at point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Probed barrier_target values: [-3.66950243]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Registering params [ 0.02765431 -1.22492749] with index None and target value 0.9670170771123171
# Extracting info: target 0.9670170771123171 is scalar
# Point registered successfully
# Probed target value: 0.9670170771123171
# Probing_barriers at point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Probed barrier_target values: [-4.13691477]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Registering params [-1.54411934 -1.52009926] with index None and target value 0.43980216489469337
# Extracting info: target 0.43980216489469337 is scalar
# Point registered successfully
# Probed target value: 0.43980216489469337
# Probing_barriers at point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Probed barrier_target values: [0.55769396]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Registering params [-2.00256869  0.05198445] with index None and target value 0.3439895360116495
# Extracting info: target 0.3439895360116495 is scalar
# Point registered successfully
# Probed target value: 0.3439895360116495
# Probing_barriers at point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Probed barrier_target values: [-0.18354646]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Registering params [-1.52244084 -1.19073287] with index None and target value -0.6384166908160336
# Extracting info: target -0.6384166908160336 is scalar
# Point registered successfully
# Probed target value: -0.6384166908160336
# Probing_barriers at point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Probed barrier_target values: [-0.25763418]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Registering params [ 1.32206587 -2.22464303] with index None and target value 2.1343801557620763
# Extracting info: target 2.1343801557620763 is scalar
# Point registered successfully
# Probed target value: 2.1343801557620763
# Probing_barriers at point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Probed barrier_target values: [2.04334017]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Registering params [0.92828252 1.26893066] with index None and target value -0.48744022805628173
# Extracting info: target -0.48744022805628173 is scalar
# Point registered successfully
# Probed target value: -0.48744022805628173
# Probing_barriers at point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Probed barrier_target values: [-1.62672166]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Registering params [1.91541394 1.69821197] with index None and target value 2.7535921962394094
# Extracting info: target 2.7535921962394094 is scalar
# Point registered successfully
# Probed target value: 2.7535921962394094
# Probing_barriers at point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Probed barrier_target values: [1.37639855]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Registering params [ 2.02316195 -1.81181606] with index None and target value -0.9305720658093499
# Extracting info: target -0.9305720658093499 is scalar
# Point registered successfully
# Probed target value: -0.9305720658093499
# Probing_barriers at point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Probed barrier_target values: [3.30441413]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Registering params [-2.01631184  0.07306423] with index None and target value 0.36634704489999537
# Extracting info: target 0.36634704489999537 is scalar
# Point registered successfully
# Probed target value: 0.36634704489999537
# Probing_barriers at point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Probed barrier_target values: [-0.14908712]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Registering params [-2.24482886 -2.23576202] with index None and target value 1.2412113033403984
# Extracting info: target 1.2412113033403984 is scalar
# Point registered successfully
# Probed target value: 1.2412113033403984
# Probing_barriers at point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Probed barrier_target values: [5.89183547]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Registering params [1.33523089 0.45697979] with index None and target value -0.5800112932865991
# Extracting info: target -0.5800112932865991 is scalar
# Point registered successfully
# Probed target value: -0.5800112932865991
# Probing_barriers at point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Probed barrier_target values: [-3.07860715]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Registering params [ 1.02160119 -2.39086375] with index None and target value 0.9871442737234035
# Extracting info: target 0.9871442737234035 is scalar
# Point registered successfully
# Probed target value: 0.9871442737234035
# Probing_barriers at point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Probed barrier_target values: [1.76890236]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Registering params [-0.8114609  -1.41164763] with index None and target value -0.4469232927980537
# Extracting info: target -0.4469232927980537 is scalar
# Point registered successfully
# Probed target value: -0.4469232927980537
# Probing_barriers at point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Probed barrier_target values: [-2.03815483]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Registering params [ 1.8095815  -2.46463651] with index None and target value 0.5484065664145346
# Extracting info: target 0.5484065664145346 is scalar
# Point registered successfully
# Probed target value: 0.5484065664145346
# Probing_barriers at point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Probed barrier_target values: [4.92000509]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Registering params [-1.15098272  0.76947939] with index None and target value 0.8355201335245834
# Extracting info: target 0.8355201335245834 is scalar
# Point registered successfully
# Probed target value: 0.8355201335245834
# Probing_barriers at point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Probed barrier_target values: [-3.52507109]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Registering params [0.81677548 0.239688  ] with index None and target value 1.3272026196874078
# Extracting info: target 1.3272026196874078 is scalar
# Point registered successfully
# Probed target value: 1.3272026196874078
# Probing_barriers at point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Probed barrier_target values: [-4.21432764]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# Registering params [ 1.07748948 -1.62917832] with index None and target value 1.077391872799466
# Extracting info: target 1.077391872799466 is scalar
# Point registered successfully
# Probed target value: 1.077391872799466
# Probing_barriers at point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# ...
# Probing point: index None, value {'x': array([0.74089004]), 'y': array([-0.29932492])}
# Registering params [ 0.74089004 -0.29932492] with index None and target value 1.6589708792229632
# Extracting info: target 1.6589708792229632 is scalar
# Point registered successfully
# Probed target value: 1.6589708792229632
# Probing_barriers at point: index None, value {'x': array([0.74089004]), 'y': array([-0.29932492])}
# Probed barrier_target values: [-3.18741111]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None      1.77488      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 106: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530178]
#  [ 0.24021869]]) = 1.7882260204569256
# Suggested point: index None, value {'x': array([-0.72530178]), 'y': array([0.24021869])}, acquisition 1.7882260204569256
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530178]), 'y': array([0.24021869])}
# Registering params [-0.72530178  0.24021869] with index None and target value 1.6387580495158511
# Extracting info: target 1.6387580495158511 is scalar
# Point registered successfully
# Probed target value: 1.6387580495158511
# Probing_barriers at point: index None, value {'x': array([-0.72530178]), 'y': array([0.24021869])}
# Probed barrier_target values: [-4.45785765]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 107: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530302]
#  [ 0.2402141 ]]) = 1.788226008700248
# Suggested point: index None, value {'x': array([-0.72530302]), 'y': array([0.2402141])}, acquisition 1.788226008700248
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530302]), 'y': array([0.2402141])}
# Registering params [-0.72530302  0.2402141 ] with index None and target value 1.6387584051537387
# Extracting info: target 1.6387584051537387 is scalar
# Point registered successfully
# Probed target value: 1.6387584051537387
# Probing_barriers at point: index None, value {'x': array([-0.72530302]), 'y': array([0.2402141])}
# Probed barrier_target values: [-4.45783994]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 108: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530374]
#  [ 0.24020839]]) = 1.7882259967435559
# Suggested point: index None, value {'x': array([-0.72530374]), 'y': array([0.24020839])}, acquisition 1.7882259967435559
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530374]), 'y': array([0.24020839])}
# Registering params [-0.72530374  0.24020839] with index None and target value 1.638758794063671
# Extracting info: target 1.638758794063671 is scalar
# Point registered successfully
# Probed target value: 1.638758794063671
# Probing_barriers at point: index None, value {'x': array([-0.72530374]), 'y': array([0.24020839])}
# Probed barrier_target values: [-4.4578201]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 109: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530455]
#  [ 0.24020377]]) = 1.7882259844200967
# Suggested point: index None, value {'x': array([-0.72530455]), 'y': array([0.24020377])}, acquisition 1.7882259844200967
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530455]), 'y': array([0.24020377])}
# Registering params [-0.72530455  0.24020377] with index None and target value 1.6387591226682099
# Extracting info: target 1.6387591226682099 is scalar
# Point registered successfully
# Probed target value: 1.6387591226682099
# Probing_barriers at point: index None, value {'x': array([-0.72530455]), 'y': array([0.24020377])}
# Probed barrier_target values: [-4.45780348]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 110: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530517]
#  [ 0.24019939]]) = 1.7882259718777247
# Suggested point: index None, value {'x': array([-0.72530517]), 'y': array([0.24019939])}, acquisition 1.7882259718777247
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530517]), 'y': array([0.24019939])}
# Registering params [-0.72530517  0.24019939] with index None and target value 1.6387594255780544
# Extracting info: target 1.6387594255780544 is scalar
# Point registered successfully
# Probed target value: 1.6387594255780544
# Probing_barriers at point: index None, value {'x': array([-0.72530517]), 'y': array([0.24019939])}
# Probed barrier_target values: [-4.45778807]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 111: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.74088297]
#  [-0.29916254]]) = 1.7748826423510693
# Suggested point: index None, value {'x': array([0.74088297]), 'y': array([-0.29916254])}, acquisition 1.7748826423510693
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.74088297]), 'y': array([-0.29916254])}
# Registering params [ 0.74088297 -0.29916254] with index None and target value 1.6589678597128565
# Extracting info: target 1.6589678597128565 is scalar
# Point registered successfully
# Probed target value: 1.6589678597128565
# Probing_barriers at point: index None, value {'x': array([0.74088297]), 'y': array([-0.29916254])}
# Probed barrier_target values: [-3.18749077]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.774883      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 112: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530675]
#  [ 0.2401919 ]]) = 1.78822596046869
# Suggested point: index None, value {'x': array([-0.72530675]), 'y': array([0.2401919])}, acquisition 1.78822596046869
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530675]), 'y': array([0.2401919])}
# Registering params [-0.72530675  0.2401919 ] with index None and target value 1.6387599765348593
# Extracting info: target 1.6387599765348593 is scalar
# Point registered successfully
# Probed target value: 1.6387599765348593
# Probing_barriers at point: index None, value {'x': array([-0.72530675]), 'y': array([0.2401919])}
# Probed barrier_target values: [-4.45776036]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 113: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530755]
#  [ 0.24018719]]) = 1.7882259472353659
# Suggested point: index None, value {'x': array([-0.72530755]), 'y': array([0.24018719])}, acquisition 1.7882259472353659
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530755]), 'y': array([0.24018719])}
# Registering params [-0.72530755  0.24018719] with index None and target value 1.6387603098435481
# Extracting info: target 1.6387603098435481 is scalar
# Point registered successfully
# Probed target value: 1.6387603098435481
# Probing_barriers at point: index None, value {'x': array([-0.72530755]), 'y': array([0.24018719])}
# Probed barrier_target values: [-4.45774347]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 114: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530775]
#  [ 0.24018187]]) = 1.7882259337926087
# Suggested point: index None, value {'x': array([-0.72530775]), 'y': array([0.24018187])}, acquisition 1.7882259337926087
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530775]), 'y': array([0.24018187])}
# Registering params [-0.72530775  0.24018187] with index None and target value 1.6387606409725914
# Extracting info: target 1.6387606409725914 is scalar
# Point registered successfully
# Probed target value: 1.6387606409725914
# Probing_barriers at point: index None, value {'x': array([-0.72530775]), 'y': array([0.24018187])}
# Probed barrier_target values: [-4.45772624]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 115: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530875]
#  [ 0.24017841]]) = 1.7882259200403952
# Suggested point: index None, value {'x': array([-0.72530875]), 'y': array([0.24017841])}, acquisition 1.7882259200403952
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530875]), 'y': array([0.24017841])}
# Registering params [-0.72530875  0.24017841] with index None and target value 1.6387609129518466
# Extracting info: target 1.6387609129518466 is scalar
# Point registered successfully
# Probed target value: 1.6387609129518466
# Probing_barriers at point: index None, value {'x': array([-0.72530875]), 'y': array([0.24017841])}
# Probed barrier_target values: [-4.45771272]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 116: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.7408732 ]
#  [-0.29902625]]) = 1.774884142436996
# Suggested point: index None, value {'x': array([0.7408732]), 'y': array([-0.29902625])}, acquisition 1.774884142436996
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.7408732]), 'y': array([-0.29902625])}
# Registering params [ 0.7408732  -0.29902625] with index None and target value 1.6589650733589711
# Extracting info: target 1.6589650733589711 is scalar
# Point registered successfully
# Probed target value: 1.6589650733589711
# Probing_barriers at point: index None, value {'x': array([0.7408732]), 'y': array([-0.29902625])}
# Probed barrier_target values: [-3.18756364]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.774884      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 117: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.74087316]
#  [-0.29896991]]) = 1.774885091799494
# Suggested point: index None, value {'x': array([0.74087316]), 'y': array([-0.29896991])}, acquisition 1.774885091799494
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.74087316]), 'y': array([-0.29896991])}
# Registering params [ 0.74087316 -0.29896991] with index None and target value 1.658964148617694
# Extracting info: target 1.658964148617694 is scalar
# Point registered successfully
# Probed target value: 1.658964148617694
# Probing_barriers at point: index None, value {'x': array([0.74087316]), 'y': array([-0.29896991])}
# Probed barrier_target values: [-3.18758757]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.774885      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 118: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72531109]
#  [ 0.24016718]]) = 1.7882259091267634
# Suggested point: index None, value {'x': array([-0.72531109]), 'y': array([0.24016718])}, acquisition 1.7882259091267634
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72531109]), 'y': array([0.24016718])}
# Registering params [-0.72531109  0.24016718] with index None and target value 1.6387617362409908
# Extracting info: target 1.6387617362409908 is scalar
# Point registered successfully
# Probed target value: 1.6387617362409908
# Probing_barriers at point: index None, value {'x': array([-0.72531109]), 'y': array([0.24016718])}
# Probed barrier_target values: [-4.45767126]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 119: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72531052]
#  [ 0.24016141]]) = 1.7882258944556633
# Suggested point: index None, value {'x': array([-0.72531052]), 'y': array([0.24016141])}, acquisition 1.7882258944556633
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72531052]), 'y': array([0.24016141])}
# Registering params [-0.72531052  0.24016141] with index None and target value 1.6387620442572657
# Extracting info: target 1.6387620442572657 is scalar
# Point registered successfully
# Probed target value: 1.6387620442572657
# Probing_barriers at point: index None, value {'x': array([-0.72531052]), 'y': array([0.24016141])}
# Probed barrier_target values: [-4.45765466]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# max: {'target': 1.658977811382505, 'params': {'x': 0.7409081432446327, 'y': -0.2996990062679479}}
# Results successfully saved to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# =================================================

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[:50]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')
plt.scatter(x_iter[:-1], y_iter[:-1], s=20, alpha = 0.5)
plt.scatter(x_iter.iloc[-1], y_iter.iloc[-1], s=20, alpha = 0.5, color = 'black')
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)


plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()
# Out:
# first occurrence of maximum at iteration: 87

# %% [markdown]
# # (acq: 'eb', fixed gamma = 10)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27122
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=120,acq='eb',acq_info={'static_lambda':True, 'lam': 1e-1})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})
# Out:
# Initializing TargetSpace with bounds: {'x': (-2.25, 2.5), 'y': (-2.5, 1.75)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 50 random points
# Uniform randomly sampled point: value [[ 1.18035032 -1.83222497]]
# Uniform randomly sampled point: value [[-1.01028192 -2.15771642]]
# Uniform randomly sampled point: value [[ 0.35257473 -1.76445162]]
# Uniform randomly sampled point: value [[0.6766644  1.62884233]]
# Uniform randomly sampled point: value [[-1.5622215  -0.89778052]]
# Uniform randomly sampled point: value [[-0.27774101 -1.53644378]]
# Uniform randomly sampled point: value [[ 0.73316997 -1.67048958]]
# Uniform randomly sampled point: value [[0.6358628  1.28281612]]
# Uniform randomly sampled point: value [[-2.24108637 -0.64627599]]
# Uniform randomly sampled point: value [[-0.4630531  -0.56044183]]
# Uniform randomly sampled point: value [[ 0.9974256 -0.7096515]]
# Uniform randomly sampled point: value [[-0.60903039  1.3882366 ]]
# Uniform randomly sampled point: value [[-1.01229852  1.15790308]]
# Uniform randomly sampled point: value [[-1.72041086  0.3174128 ]]
# Uniform randomly sampled point: value [[ 1.5696647  -0.30651708]]
# Uniform randomly sampled point: value [[-1.85495737  1.57856182]]
# Uniform randomly sampled point: value [[ 0.63290518 -0.20093481]]
# Uniform randomly sampled point: value [[-0.64013482 -1.06577754]]
# Uniform randomly sampled point: value [[1.38797323 1.16473935]]
# Uniform randomly sampled point: value [[-0.82056387  0.56206324]]
# Uniform randomly sampled point: value [[ 0.87099226 -1.3966168 ]]
# Uniform randomly sampled point: value [[0.34689288 1.27748223]]
# Uniform randomly sampled point: value [[-0.82159302  0.08201164]]
# Uniform randomly sampled point: value [[0.2458041 0.8193955]]
# Uniform randomly sampled point: value [[-0.94880752 -0.13391692]]
# Uniform randomly sampled point: value [[1.85728711 1.16797939]]
# Uniform randomly sampled point: value [[-0.14685476  0.22168027]]
# Uniform randomly sampled point: value [[0.31593137 1.63517331]]
# Uniform randomly sampled point: value [[-1.73149633  1.42405001]]
# Uniform randomly sampled point: value [[ 0.72057912 -1.48084983]]
# Uniform randomly sampled point: value [[0.34880767 0.05552785]]
# Uniform randomly sampled point: value [[ 0.42208191 -0.09440631]]
# Uniform randomly sampled point: value [[ 0.02765431 -1.22492749]]
# Uniform randomly sampled point: value [[-1.54411934 -1.52009926]]
# Uniform randomly sampled point: value [[-2.00256869  0.05198445]]
# Uniform randomly sampled point: value [[-1.52244084 -1.19073287]]
# Uniform randomly sampled point: value [[ 1.32206587 -2.22464303]]
# Uniform randomly sampled point: value [[0.92828252 1.26893066]]
# Uniform randomly sampled point: value [[1.91541394 1.69821197]]
# Uniform randomly sampled point: value [[ 2.02316195 -1.81181606]]
# Uniform randomly sampled point: value [[-2.01631184  0.07306423]]
# Uniform randomly sampled point: value [[-2.24482886 -2.23576202]]
# Uniform randomly sampled point: value [[1.33523089 0.45697979]]
# Uniform randomly sampled point: value [[ 1.02160119 -2.39086375]]
# Uniform randomly sampled point: value [[-0.8114609  -1.41164763]]
# Uniform randomly sampled point: value [[ 1.8095815  -2.46463651]]
# Uniform randomly sampled point: value [[-1.15098272  0.76947939]]
# Uniform randomly sampled point: value [[0.81677548 0.239688  ]]
# Uniform randomly sampled point: value [[ 1.07748948 -1.62917832]]
# Uniform randomly sampled point: value [[-2.13754343  0.68446887]]
# Initializing UtilityFunction of kind 'eb' with acq_info = {'static_lambda': True, 'lam': 0.1}
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Registering params [ 1.18035032 -1.83222497] with index None and target value 1.3270265354343607
# Extracting info: target 1.3270265354343607 is scalar
# Point registered successfully
# Probed target value: 1.3270265354343607
# Probing_barriers at point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Probed barrier_target values: [0.18360093]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Registering params [-1.01028192 -2.15771642] with index None and target value -0.35845564463978297
# Extracting info: target -0.35845564463978297 is scalar
# Point registered successfully
# Probed target value: -0.35845564463978297
# Probing_barriers at point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Probed barrier_target values: [0.7733769]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Registering params [ 0.35257473 -1.76445162] with index None and target value 0.5852521951186401
# Extracting info: target 0.5852521951186401 is scalar
# Point registered successfully
# Probed target value: 0.5852521951186401
# Probing_barriers at point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Probed barrier_target values: [-2.22167925]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Registering params [0.6766644  1.62884233] with index None and target value 0.013920491460077067
# Extracting info: target 0.013920491460077067 is scalar
# Point registered successfully
# Probed target value: 0.013920491460077067
# Probing_barriers at point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Probed barrier_target values: [0.56309916]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Registering params [-1.5622215  -0.89778052] with index None and target value -0.9987572867564634
# Extracting info: target -0.9987572867564634 is scalar
# Point registered successfully
# Probed target value: -0.9987572867564634
# Probing_barriers at point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Probed barrier_target values: [-0.63117354]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Registering params [-0.27774101 -1.53644378] with index None and target value 0.8930522558345727
# Extracting info: target 0.8930522558345727 is scalar
# Point registered successfully
# Probed target value: 0.8930522558345727
# Probing_barriers at point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Probed barrier_target values: [-3.0523649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Registering params [ 0.73316997 -1.67048958] with index None and target value 0.6109791136386856
# Extracting info: target 0.6109791136386856 is scalar
# Point registered successfully
# Probed target value: 0.6109791136386856
# Probing_barriers at point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Probed barrier_target values: [-1.63776548]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Registering params [0.6358628  1.28281612] with index None and target value 0.5663334311696665
# Extracting info: target 0.5663334311696665 is scalar
# Point registered successfully
# Probed target value: 0.5663334311696665
# Probing_barriers at point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Probed barrier_target values: [-0.91532842]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Registering params [-2.24108637 -0.64627599] with index None and target value 1.9865490231616305
# Extracting info: target 1.9865490231616305 is scalar
# Point registered successfully
# Probed target value: 1.9865490231616305
# Probing_barriers at point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Probed barrier_target values: [1.60915501]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Registering params [-0.4630531  -0.56044183] with index None and target value 1.333910472267051
# Extracting info: target 1.333910472267051 is scalar
# Point registered successfully
# Probed target value: 1.333910472267051
# Probing_barriers at point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Probed barrier_target values: [-3.78401684]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Registering params [ 0.9974256 -0.7096515] with index None and target value 1.401582650132049
# Extracting info: target 1.401582650132049 is scalar
# Point registered successfully
# Probed target value: 1.401582650132049
# Probing_barriers at point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Probed barrier_target values: [-2.45079968]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Registering params [-0.60903039  1.3882366 ] with index None and target value 0.5650797426098781
# Extracting info: target 0.5650797426098781 is scalar
# Point registered successfully
# Probed target value: 0.5650797426098781
# Probing_barriers at point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Probed barrier_target values: [-0.36990276]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Registering params [-1.01229852  1.15790308] with index None and target value 1.0425012077544027
# Extracting info: target 1.0425012077544027 is scalar
# Point registered successfully
# Probed target value: 1.0425012077544027
# Probing_barriers at point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Probed barrier_target values: [-2.24846974]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Registering params [-1.72041086  0.3174128 ] with index None and target value -1.0039080714402764
# Extracting info: target -1.0039080714402764 is scalar
# Point registered successfully
# Probed target value: -1.0039080714402764
# Probing_barriers at point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Probed barrier_target values: [-1.55926262]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Registering params [ 1.5696647  -0.30651708] with index None and target value -0.6844556040178207
# Extracting info: target -0.6844556040178207 is scalar
# Point registered successfully
# Probed target value: -0.6844556040178207
# Probing_barriers at point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Probed barrier_target values: [-1.31669448]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Registering params [-1.85495737  1.57856182] with index None and target value -0.3901918275873201
# Extracting info: target -0.3901918275873201 is scalar
# Point registered successfully
# Probed target value: -0.3901918275873201
# Probing_barriers at point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Probed barrier_target values: [0.69342346]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Registering params [ 0.63290518 -0.20093481] with index None and target value 1.616387021720416
# Extracting info: target 1.616387021720416 is scalar
# Point registered successfully
# Probed target value: 1.616387021720416
# Probing_barriers at point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Probed barrier_target values: [-3.38448171]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Registering params [-0.64013482 -1.06577754] with index None and target value 0.5956629026120582
# Extracting info: target 0.5956629026120582 is scalar
# Point registered successfully
# Probed target value: 0.5956629026120582
# Probing_barriers at point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Probed barrier_target values: [-3.09645169]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Registering params [1.38797323 1.16473935] with index None and target value -1.127659533198751
# Extracting info: target -1.127659533198751 is scalar
# Point registered successfully
# Probed target value: -1.127659533198751
# Probing_barriers at point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Probed barrier_target values: [-1.97579095]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Registering params [-0.82056387  0.56206324] with index None and target value 1.531934146537457
# Extracting info: target 1.531934146537457 is scalar
# Point registered successfully
# Probed target value: 1.531934146537457
# Probing_barriers at point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Probed barrier_target values: [-4.44465582]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Registering params [ 0.87099226 -1.3966168 ] with index None and target value 1.0416859521454194
# Extracting info: target 1.0416859521454194 is scalar
# Point registered successfully
# Probed target value: 1.0416859521454194
# Probing_barriers at point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Probed barrier_target values: [-1.89240184]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Registering params [0.34689288 1.27748223] with index None and target value 1.1582171615386736
# Extracting info: target 1.1582171615386736 is scalar
# Point registered successfully
# Probed target value: 1.1582171615386736
# Probing_barriers at point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Probed barrier_target values: [-0.11691927]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Registering params [-0.82159302  0.08201164] with index None and target value 1.5596113849454376
# Extracting info: target 1.5596113849454376 is scalar
# Point registered successfully
# Probed target value: 1.5596113849454376
# Probing_barriers at point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Probed barrier_target values: [-3.69749675]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Registering params [0.2458041 0.8193955] with index None and target value 1.2315744617174662
# Extracting info: target 1.2315744617174662 is scalar
# Point registered successfully
# Probed target value: 1.2315744617174662
# Probing_barriers at point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Probed barrier_target values: [-1.2588649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Registering params [-0.94880752 -0.13391692] with index None and target value 1.1327383432973934
# Extracting info: target 1.1327383432973934 is scalar
# Point registered successfully
# Probed target value: 1.1327383432973934
# Probing_barriers at point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Probed barrier_target values: [-3.00375108]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Registering params [1.85728711 1.16797939] with index None and target value 1.0335852024912042
# Extracting info: target 1.0335852024912042 is scalar
# Point registered successfully
# Probed target value: 1.0335852024912042
# Probing_barriers at point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Probed barrier_target values: [-0.63768823]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Registering params [-0.14685476  0.22168027] with index None and target value 1.028896498407277
# Extracting info: target 1.028896498407277 is scalar
# Point registered successfully
# Probed target value: 1.028896498407277
# Probing_barriers at point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Probed barrier_target values: [-3.72585397]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Registering params [0.31593137 1.63517331] with index None and target value 1.0478765103082408
# Extracting info: target 1.0478765103082408 is scalar
# Point registered successfully
# Probed target value: 1.0478765103082408
# Probing_barriers at point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Probed barrier_target values: [1.1914944]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Registering params [-1.73149633  1.42405001] with index None and target value -0.27706681223960516
# Extracting info: target -0.27706681223960516 is scalar
# Point registered successfully
# Probed target value: -0.27706681223960516
# Probing_barriers at point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Probed barrier_target values: [-0.25930596]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Registering params [ 0.72057912 -1.48084983] with index None and target value 0.8215895072673417
# Extracting info: target 0.8215895072673417 is scalar
# Point registered successfully
# Probed target value: 0.8215895072673417
# Probing_barriers at point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Probed barrier_target values: [-2.15223167]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Registering params [0.34880767 0.05552785] with index None and target value 1.3109771707802058
# Extracting info: target 1.3109771707802058 is scalar
# Point registered successfully
# Probed target value: 1.3109771707802058
# Probing_barriers at point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Probed barrier_target values: [-4.42093903]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Registering params [ 0.42208191 -0.09440631] with index None and target value 1.388010141439827
# Extracting info: target 1.388010141439827 is scalar
# Point registered successfully
# Probed target value: 1.388010141439827
# Probing_barriers at point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Probed barrier_target values: [-3.66950243]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Registering params [ 0.02765431 -1.22492749] with index None and target value 0.9670170771123171
# Extracting info: target 0.9670170771123171 is scalar
# Point registered successfully
# Probed target value: 0.9670170771123171
# Probing_barriers at point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Probed barrier_target values: [-4.13691477]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Registering params [-1.54411934 -1.52009926] with index None and target value 0.43980216489469337
# Extracting info: target 0.43980216489469337 is scalar
# Point registered successfully
# Probed target value: 0.43980216489469337
# Probing_barriers at point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Probed barrier_target values: [0.55769396]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Registering params [-2.00256869  0.05198445] with index None and target value 0.3439895360116495
# Extracting info: target 0.3439895360116495 is scalar
# Point registered successfully
# Probed target value: 0.3439895360116495
# Probing_barriers at point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Probed barrier_target values: [-0.18354646]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Registering params [-1.52244084 -1.19073287] with index None and target value -0.6384166908160336
# Extracting info: target -0.6384166908160336 is scalar
# Point registered successfully
# Probed target value: -0.6384166908160336
# Probing_barriers at point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Probed barrier_target values: [-0.25763418]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Registering params [ 1.32206587 -2.22464303] with index None and target value 2.1343801557620763
# Extracting info: target 2.1343801557620763 is scalar
# Point registered successfully
# Probed target value: 2.1343801557620763
# Probing_barriers at point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Probed barrier_target values: [2.04334017]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Registering params [0.92828252 1.26893066] with index None and target value -0.48744022805628173
# Extracting info: target -0.48744022805628173 is scalar
# Point registered successfully
# Probed target value: -0.48744022805628173
# Probing_barriers at point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Probed barrier_target values: [-1.62672166]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Registering params [1.91541394 1.69821197] with index None and target value 2.7535921962394094
# Extracting info: target 2.7535921962394094 is scalar
# Point registered successfully
# Probed target value: 2.7535921962394094
# Probing_barriers at point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Probed barrier_target values: [1.37639855]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Registering params [ 2.02316195 -1.81181606] with index None and target value -0.9305720658093499
# Extracting info: target -0.9305720658093499 is scalar
# Point registered successfully
# Probed target value: -0.9305720658093499
# Probing_barriers at point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Probed barrier_target values: [3.30441413]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Registering params [-2.01631184  0.07306423] with index None and target value 0.36634704489999537
# Extracting info: target 0.36634704489999537 is scalar
# Point registered successfully
# Probed target value: 0.36634704489999537
# Probing_barriers at point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Probed barrier_target values: [-0.14908712]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Registering params [-2.24482886 -2.23576202] with index None and target value 1.2412113033403984
# Extracting info: target 1.2412113033403984 is scalar
# Point registered successfully
# Probed target value: 1.2412113033403984
# Probing_barriers at point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Probed barrier_target values: [5.89183547]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Registering params [1.33523089 0.45697979] with index None and target value -0.5800112932865991
# Extracting info: target -0.5800112932865991 is scalar
# Point registered successfully
# Probed target value: -0.5800112932865991
# Probing_barriers at point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Probed barrier_target values: [-3.07860715]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Registering params [ 1.02160119 -2.39086375] with index None and target value 0.9871442737234035
# Extracting info: target 0.9871442737234035 is scalar
# Point registered successfully
# Probed target value: 0.9871442737234035
# Probing_barriers at point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Probed barrier_target values: [1.76890236]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Registering params [-0.8114609  -1.41164763] with index None and target value -0.4469232927980537
# Extracting info: target -0.4469232927980537 is scalar
# Point registered successfully
# Probed target value: -0.4469232927980537
# Probing_barriers at point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Probed barrier_target values: [-2.03815483]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Registering params [ 1.8095815  -2.46463651] with index None and target value 0.5484065664145346
# Extracting info: target 0.5484065664145346 is scalar
# Point registered successfully
# Probed target value: 0.5484065664145346
# Probing_barriers at point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Probed barrier_target values: [4.92000509]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Registering params [-1.15098272  0.76947939] with index None and target value 0.8355201335245834
# Extracting info: target 0.8355201335245834 is scalar
# Point registered successfully
# Probed target value: 0.8355201335245834
# Probing_barriers at point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Probed barrier_target values: [-3.52507109]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Registering params [0.81677548 0.239688  ] with index None and target value 1.3272026196874078
# Extracting info: target 1.3272026196874078 is scalar
# Point registered successfully
# Probed target value: 1.3272026196874078
# Probing_barriers at point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Probed barrier_target values: [-4.21432764]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# Registering params [ 1.07748948 -1.62917832] with index None and target value 1.077391872799466
# Extracting info: target 1.077391872799466 is scalar
# Point registered successfully
# Probed target value: 1.077391872799466
# Probing_barriers at point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# ...
# Probing point: index None, value {'x': array([0.74089004]), 'y': array([-0.29932492])}
# Registering params [ 0.74089004 -0.29932492] with index None and target value 1.6589708792229632
# Extracting info: target 1.6589708792229632 is scalar
# Point registered successfully
# Probed target value: 1.6589708792229632
# Probing_barriers at point: index None, value {'x': array([0.74089004]), 'y': array([-0.29932492])}
# Probed barrier_target values: [-3.18741111]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None      1.77488      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 106: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530178]
#  [ 0.24021869]]) = 1.7882260204569256
# Suggested point: index None, value {'x': array([-0.72530178]), 'y': array([0.24021869])}, acquisition 1.7882260204569256
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530178]), 'y': array([0.24021869])}
# Registering params [-0.72530178  0.24021869] with index None and target value 1.6387580495158511
# Extracting info: target 1.6387580495158511 is scalar
# Point registered successfully
# Probed target value: 1.6387580495158511
# Probing_barriers at point: index None, value {'x': array([-0.72530178]), 'y': array([0.24021869])}
# Probed barrier_target values: [-4.45785765]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 107: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530302]
#  [ 0.2402141 ]]) = 1.788226008700248
# Suggested point: index None, value {'x': array([-0.72530302]), 'y': array([0.2402141])}, acquisition 1.788226008700248
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530302]), 'y': array([0.2402141])}
# Registering params [-0.72530302  0.2402141 ] with index None and target value 1.6387584051537387
# Extracting info: target 1.6387584051537387 is scalar
# Point registered successfully
# Probed target value: 1.6387584051537387
# Probing_barriers at point: index None, value {'x': array([-0.72530302]), 'y': array([0.2402141])}
# Probed barrier_target values: [-4.45783994]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 108: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530374]
#  [ 0.24020839]]) = 1.7882259967435559
# Suggested point: index None, value {'x': array([-0.72530374]), 'y': array([0.24020839])}, acquisition 1.7882259967435559
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530374]), 'y': array([0.24020839])}
# Registering params [-0.72530374  0.24020839] with index None and target value 1.638758794063671
# Extracting info: target 1.638758794063671 is scalar
# Point registered successfully
# Probed target value: 1.638758794063671
# Probing_barriers at point: index None, value {'x': array([-0.72530374]), 'y': array([0.24020839])}
# Probed barrier_target values: [-4.4578201]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 109: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530455]
#  [ 0.24020377]]) = 1.7882259844200967
# Suggested point: index None, value {'x': array([-0.72530455]), 'y': array([0.24020377])}, acquisition 1.7882259844200967
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530455]), 'y': array([0.24020377])}
# Registering params [-0.72530455  0.24020377] with index None and target value 1.6387591226682099
# Extracting info: target 1.6387591226682099 is scalar
# Point registered successfully
# Probed target value: 1.6387591226682099
# Probing_barriers at point: index None, value {'x': array([-0.72530455]), 'y': array([0.24020377])}
# Probed barrier_target values: [-4.45780348]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 110: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530517]
#  [ 0.24019939]]) = 1.7882259718777247
# Suggested point: index None, value {'x': array([-0.72530517]), 'y': array([0.24019939])}, acquisition 1.7882259718777247
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530517]), 'y': array([0.24019939])}
# Registering params [-0.72530517  0.24019939] with index None and target value 1.6387594255780544
# Extracting info: target 1.6387594255780544 is scalar
# Point registered successfully
# Probed target value: 1.6387594255780544
# Probing_barriers at point: index None, value {'x': array([-0.72530517]), 'y': array([0.24019939])}
# Probed barrier_target values: [-4.45778807]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 111: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.74088297]
#  [-0.29916254]]) = 1.7748826423510693
# Suggested point: index None, value {'x': array([0.74088297]), 'y': array([-0.29916254])}, acquisition 1.7748826423510693
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.74088297]), 'y': array([-0.29916254])}
# Registering params [ 0.74088297 -0.29916254] with index None and target value 1.6589678597128565
# Extracting info: target 1.6589678597128565 is scalar
# Point registered successfully
# Probed target value: 1.6589678597128565
# Probing_barriers at point: index None, value {'x': array([0.74088297]), 'y': array([-0.29916254])}
# Probed barrier_target values: [-3.18749077]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.774883      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 112: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530675]
#  [ 0.2401919 ]]) = 1.78822596046869
# Suggested point: index None, value {'x': array([-0.72530675]), 'y': array([0.2401919])}, acquisition 1.78822596046869
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530675]), 'y': array([0.2401919])}
# Registering params [-0.72530675  0.2401919 ] with index None and target value 1.6387599765348593
# Extracting info: target 1.6387599765348593 is scalar
# Point registered successfully
# Probed target value: 1.6387599765348593
# Probing_barriers at point: index None, value {'x': array([-0.72530675]), 'y': array([0.2401919])}
# Probed barrier_target values: [-4.45776036]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 113: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530755]
#  [ 0.24018719]]) = 1.7882259472353659
# Suggested point: index None, value {'x': array([-0.72530755]), 'y': array([0.24018719])}, acquisition 1.7882259472353659
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530755]), 'y': array([0.24018719])}
# Registering params [-0.72530755  0.24018719] with index None and target value 1.6387603098435481
# Extracting info: target 1.6387603098435481 is scalar
# Point registered successfully
# Probed target value: 1.6387603098435481
# Probing_barriers at point: index None, value {'x': array([-0.72530755]), 'y': array([0.24018719])}
# Probed barrier_target values: [-4.45774347]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 114: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530775]
#  [ 0.24018187]]) = 1.7882259337926087
# Suggested point: index None, value {'x': array([-0.72530775]), 'y': array([0.24018187])}, acquisition 1.7882259337926087
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530775]), 'y': array([0.24018187])}
# Registering params [-0.72530775  0.24018187] with index None and target value 1.6387606409725914
# Extracting info: target 1.6387606409725914 is scalar
# Point registered successfully
# Probed target value: 1.6387606409725914
# Probing_barriers at point: index None, value {'x': array([-0.72530775]), 'y': array([0.24018187])}
# Probed barrier_target values: [-4.45772624]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 115: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72530875]
#  [ 0.24017841]]) = 1.7882259200403952
# Suggested point: index None, value {'x': array([-0.72530875]), 'y': array([0.24017841])}, acquisition 1.7882259200403952
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72530875]), 'y': array([0.24017841])}
# Registering params [-0.72530875  0.24017841] with index None and target value 1.6387609129518466
# Extracting info: target 1.6387609129518466 is scalar
# Point registered successfully
# Probed target value: 1.6387609129518466
# Probing_barriers at point: index None, value {'x': array([-0.72530875]), 'y': array([0.24017841])}
# Probed barrier_target values: [-4.45771272]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 116: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.7408732 ]
#  [-0.29902625]]) = 1.774884142436996
# Suggested point: index None, value {'x': array([0.7408732]), 'y': array([-0.29902625])}, acquisition 1.774884142436996
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.7408732]), 'y': array([-0.29902625])}
# Registering params [ 0.7408732  -0.29902625] with index None and target value 1.6589650733589711
# Extracting info: target 1.6589650733589711 is scalar
# Point registered successfully
# Probed target value: 1.6589650733589711
# Probing_barriers at point: index None, value {'x': array([0.7408732]), 'y': array([-0.29902625])}
# Probed barrier_target values: [-3.18756364]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.774884      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 117: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.74087316]
#  [-0.29896991]]) = 1.774885091799494
# Suggested point: index None, value {'x': array([0.74087316]), 'y': array([-0.29896991])}, acquisition 1.774885091799494
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.74087316]), 'y': array([-0.29896991])}
# Registering params [ 0.74087316 -0.29896991] with index None and target value 1.658964148617694
# Extracting info: target 1.658964148617694 is scalar
# Point registered successfully
# Probed target value: 1.658964148617694
# Probing_barriers at point: index None, value {'x': array([0.74087316]), 'y': array([-0.29896991])}
# Probed barrier_target values: [-3.18758757]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.774885      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 118: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72531109]
#  [ 0.24016718]]) = 1.7882259091267634
# Suggested point: index None, value {'x': array([-0.72531109]), 'y': array([0.24016718])}, acquisition 1.7882259091267634
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72531109]), 'y': array([0.24016718])}
# Registering params [-0.72531109  0.24016718] with index None and target value 1.6387617362409908
# Extracting info: target 1.6387617362409908 is scalar
# Point registered successfully
# Probed target value: 1.6387617362409908
# Probing_barriers at point: index None, value {'x': array([-0.72531109]), 'y': array([0.24016718])}
# Probed barrier_target values: [-4.45767126]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 119: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.72531052]
#  [ 0.24016141]]) = 1.7882258944556633
# Suggested point: index None, value {'x': array([-0.72531052]), 'y': array([0.24016141])}, acquisition 1.7882258944556633
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.72531052]), 'y': array([0.24016141])}
# Registering params [-0.72531052  0.24016141] with index None and target value 1.6387620442572657
# Extracting info: target 1.6387620442572657 is scalar
# Point registered successfully
# Probed target value: 1.6387620442572657
# Probing_barriers at point: index None, value {'x': array([-0.72531052]), 'y': array([0.24016141])}
# Probed barrier_target values: [-4.45765466]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.788226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# max: {'target': 1.658977811382505, 'params': {'x': 0.7409081432446327, 'y': -0.2996990062679479}}
# Results successfully saved to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# =================================================

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[:50]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')
plt.scatter(x_iter[:-1], y_iter[:-1], s=20, alpha = 0.5)
plt.scatter(x_iter.iloc[-1], y_iter.iloc[-1], s=20, alpha = 0.5, color = 'black')
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)


plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()
# Out:
# first occurrence of maximum at iteration: 87

# %% [markdown]
# # (acq = eic_bm, gamma = 10)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27122
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam': 1e-1})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})
# Out:
# Initializing TargetSpace with bounds: {'x': (-2.25, 2.5), 'y': (-2.5, 1.75)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 50 random points
# Uniform randomly sampled point: value [[ 1.18035032 -1.83222497]]
# Uniform randomly sampled point: value [[-1.01028192 -2.15771642]]
# Uniform randomly sampled point: value [[ 0.35257473 -1.76445162]]
# Uniform randomly sampled point: value [[0.6766644  1.62884233]]
# Uniform randomly sampled point: value [[-1.5622215  -0.89778052]]
# Uniform randomly sampled point: value [[-0.27774101 -1.53644378]]
# Uniform randomly sampled point: value [[ 0.73316997 -1.67048958]]
# Uniform randomly sampled point: value [[0.6358628  1.28281612]]
# Uniform randomly sampled point: value [[-2.24108637 -0.64627599]]
# Uniform randomly sampled point: value [[-0.4630531  -0.56044183]]
# Uniform randomly sampled point: value [[ 0.9974256 -0.7096515]]
# Uniform randomly sampled point: value [[-0.60903039  1.3882366 ]]
# Uniform randomly sampled point: value [[-1.01229852  1.15790308]]
# Uniform randomly sampled point: value [[-1.72041086  0.3174128 ]]
# Uniform randomly sampled point: value [[ 1.5696647  -0.30651708]]
# Uniform randomly sampled point: value [[-1.85495737  1.57856182]]
# Uniform randomly sampled point: value [[ 0.63290518 -0.20093481]]
# Uniform randomly sampled point: value [[-0.64013482 -1.06577754]]
# Uniform randomly sampled point: value [[1.38797323 1.16473935]]
# Uniform randomly sampled point: value [[-0.82056387  0.56206324]]
# Uniform randomly sampled point: value [[ 0.87099226 -1.3966168 ]]
# Uniform randomly sampled point: value [[0.34689288 1.27748223]]
# Uniform randomly sampled point: value [[-0.82159302  0.08201164]]
# Uniform randomly sampled point: value [[0.2458041 0.8193955]]
# Uniform randomly sampled point: value [[-0.94880752 -0.13391692]]
# Uniform randomly sampled point: value [[1.85728711 1.16797939]]
# Uniform randomly sampled point: value [[-0.14685476  0.22168027]]
# Uniform randomly sampled point: value [[0.31593137 1.63517331]]
# Uniform randomly sampled point: value [[-1.73149633  1.42405001]]
# Uniform randomly sampled point: value [[ 0.72057912 -1.48084983]]
# Uniform randomly sampled point: value [[0.34880767 0.05552785]]
# Uniform randomly sampled point: value [[ 0.42208191 -0.09440631]]
# Uniform randomly sampled point: value [[ 0.02765431 -1.22492749]]
# Uniform randomly sampled point: value [[-1.54411934 -1.52009926]]
# Uniform randomly sampled point: value [[-2.00256869  0.05198445]]
# Uniform randomly sampled point: value [[-1.52244084 -1.19073287]]
# Uniform randomly sampled point: value [[ 1.32206587 -2.22464303]]
# Uniform randomly sampled point: value [[0.92828252 1.26893066]]
# Uniform randomly sampled point: value [[1.91541394 1.69821197]]
# Uniform randomly sampled point: value [[ 2.02316195 -1.81181606]]
# Uniform randomly sampled point: value [[-2.01631184  0.07306423]]
# Uniform randomly sampled point: value [[-2.24482886 -2.23576202]]
# Uniform randomly sampled point: value [[1.33523089 0.45697979]]
# Uniform randomly sampled point: value [[ 1.02160119 -2.39086375]]
# Uniform randomly sampled point: value [[-0.8114609  -1.41164763]]
# Uniform randomly sampled point: value [[ 1.8095815  -2.46463651]]
# Uniform randomly sampled point: value [[-1.15098272  0.76947939]]
# Uniform randomly sampled point: value [[0.81677548 0.239688  ]]
# Uniform randomly sampled point: value [[ 1.07748948 -1.62917832]]
# Uniform randomly sampled point: value [[-2.13754343  0.68446887]]
# Initializing UtilityFunction of kind 'eic_bm' with acq_info = {'static_lambda': True, 'lam': 0.1}
# Using default eic_P_func, P(x) == 1
# Using default eic_Q_func, Q(x) == 0
# Setting 'eic_P_func' field of acq_info to 'eic_P_func' member
# Setting 'eic_Q_func' field of acq_info to 'eic_Q_func' member
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Registering params [ 1.18035032 -1.83222497] with index None and target value 1.3270265354343607
# Extracting info: target 1.3270265354343607 is scalar
# Point registered successfully
# Probed target value: 1.3270265354343607
# Probing_barriers at point: index None, value {'x': 1.1803503176562358, 'y': -1.832224972818946}
# Probed barrier_target values: [0.18360093]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Registering params [-1.01028192 -2.15771642] with index None and target value -0.35845564463978297
# Extracting info: target -0.35845564463978297 is scalar
# Point registered successfully
# Probed target value: -0.35845564463978297
# Probing_barriers at point: index None, value {'x': -1.0102819177794244, 'y': -2.157716422720346}
# Probed barrier_target values: [0.7733769]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Registering params [ 0.35257473 -1.76445162] with index None and target value 0.5852521951186401
# Extracting info: target 0.5852521951186401 is scalar
# Point registered successfully
# Probed target value: 0.5852521951186401
# Probing_barriers at point: index None, value {'x': 0.35257473208633705, 'y': -1.7644516216417312}
# Probed barrier_target values: [-2.22167925]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Registering params [0.6766644  1.62884233] with index None and target value 0.013920491460077067
# Extracting info: target 0.013920491460077067 is scalar
# Point registered successfully
# Probed target value: 0.013920491460077067
# Probing_barriers at point: index None, value {'x': 0.6766643980182168, 'y': 1.6288423309489337}
# Probed barrier_target values: [0.56309916]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Registering params [-1.5622215  -0.89778052] with index None and target value -0.9987572867564634
# Extracting info: target -0.9987572867564634 is scalar
# Point registered successfully
# Probed target value: -0.9987572867564634
# Probing_barriers at point: index None, value {'x': -1.562221503087234, 'y': -0.897780524923455}
# Probed barrier_target values: [-0.63117354]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Registering params [-0.27774101 -1.53644378] with index None and target value 0.8930522558345727
# Extracting info: target 0.8930522558345727 is scalar
# Point registered successfully
# Probed target value: 0.8930522558345727
# Probing_barriers at point: index None, value {'x': -0.27774101279757746, 'y': -1.5364437846340926}
# Probed barrier_target values: [-3.0523649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Registering params [ 0.73316997 -1.67048958] with index None and target value 0.6109791136386856
# Extracting info: target 0.6109791136386856 is scalar
# Point registered successfully
# Probed target value: 0.6109791136386856
# Probing_barriers at point: index None, value {'x': 0.7331699749053904, 'y': -1.6704895817855006}
# Probed barrier_target values: [-1.63776548]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Registering params [0.6358628  1.28281612] with index None and target value 0.5663334311696665
# Extracting info: target 0.5663334311696665 is scalar
# Point registered successfully
# Probed target value: 0.5663334311696665
# Probing_barriers at point: index None, value {'x': 0.63586280143641, 'y': 1.2828161186154103}
# Probed barrier_target values: [-0.91532842]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Registering params [-2.24108637 -0.64627599] with index None and target value 1.9865490231616305
# Extracting info: target 1.9865490231616305 is scalar
# Point registered successfully
# Probed target value: 1.9865490231616305
# Probing_barriers at point: index None, value {'x': -2.2410863694996674, 'y': -0.6462759873101074}
# Probed barrier_target values: [1.60915501]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Registering params [-0.4630531  -0.56044183] with index None and target value 1.333910472267051
# Extracting info: target 1.333910472267051 is scalar
# Point registered successfully
# Probed target value: 1.333910472267051
# Probing_barriers at point: index None, value {'x': -0.4630531032393497, 'y': -0.5604418306593952}
# Probed barrier_target values: [-3.78401684]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Registering params [ 0.9974256 -0.7096515] with index None and target value 1.401582650132049
# Extracting info: target 1.401582650132049 is scalar
# Point registered successfully
# Probed target value: 1.401582650132049
# Probing_barriers at point: index None, value {'x': 0.9974255987916467, 'y': -0.7096514951625146}
# Probed barrier_target values: [-2.45079968]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Registering params [-0.60903039  1.3882366 ] with index None and target value 0.5650797426098781
# Extracting info: target 0.5650797426098781 is scalar
# Point registered successfully
# Probed target value: 0.5650797426098781
# Probing_barriers at point: index None, value {'x': -0.6090303947225473, 'y': 1.3882365999289785}
# Probed barrier_target values: [-0.36990276]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Registering params [-1.01229852  1.15790308] with index None and target value 1.0425012077544027
# Extracting info: target 1.0425012077544027 is scalar
# Point registered successfully
# Probed target value: 1.0425012077544027
# Probing_barriers at point: index None, value {'x': -1.0122985239036024, 'y': 1.1579030817566704}
# Probed barrier_target values: [-2.24846974]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Registering params [-1.72041086  0.3174128 ] with index None and target value -1.0039080714402764
# Extracting info: target -1.0039080714402764 is scalar
# Point registered successfully
# Probed target value: -1.0039080714402764
# Probing_barriers at point: index None, value {'x': -1.7204108607691802, 'y': 0.31741279870286254}
# Probed barrier_target values: [-1.55926262]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Registering params [ 1.5696647  -0.30651708] with index None and target value -0.6844556040178207
# Extracting info: target -0.6844556040178207 is scalar
# Point registered successfully
# Probed target value: -0.6844556040178207
# Probing_barriers at point: index None, value {'x': 1.5696646998239556, 'y': -0.306517082017717}
# Probed barrier_target values: [-1.31669448]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Registering params [-1.85495737  1.57856182] with index None and target value -0.3901918275873201
# Extracting info: target -0.3901918275873201 is scalar
# Point registered successfully
# Probed target value: -0.3901918275873201
# Probing_barriers at point: index None, value {'x': -1.8549573656776772, 'y': 1.5785618237815848}
# Probed barrier_target values: [0.69342346]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Registering params [ 0.63290518 -0.20093481] with index None and target value 1.616387021720416
# Extracting info: target 1.616387021720416 is scalar
# Point registered successfully
# Probed target value: 1.616387021720416
# Probing_barriers at point: index None, value {'x': 0.632905177579878, 'y': -0.20093481040436867}
# Probed barrier_target values: [-3.38448171]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Registering params [-0.64013482 -1.06577754] with index None and target value 0.5956629026120582
# Extracting info: target 0.5956629026120582 is scalar
# Point registered successfully
# Probed target value: 0.5956629026120582
# Probing_barriers at point: index None, value {'x': -0.640134823610061, 'y': -1.065777540399843}
# Probed barrier_target values: [-3.09645169]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Registering params [1.38797323 1.16473935] with index None and target value -1.127659533198751
# Extracting info: target -1.127659533198751 is scalar
# Point registered successfully
# Probed target value: -1.127659533198751
# Probing_barriers at point: index None, value {'x': 1.3879732250538286, 'y': 1.1647393540290651}
# Probed barrier_target values: [-1.97579095]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Registering params [-0.82056387  0.56206324] with index None and target value 1.531934146537457
# Extracting info: target 1.531934146537457 is scalar
# Point registered successfully
# Probed target value: 1.531934146537457
# Probing_barriers at point: index None, value {'x': -0.8205638713123986, 'y': 0.5620632449602891}
# Probed barrier_target values: [-4.44465582]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Registering params [ 0.87099226 -1.3966168 ] with index None and target value 1.0416859521454194
# Extracting info: target 1.0416859521454194 is scalar
# Point registered successfully
# Probed target value: 1.0416859521454194
# Probing_barriers at point: index None, value {'x': 0.8709922616960735, 'y': -1.3966168034540856}
# Probed barrier_target values: [-1.89240184]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Registering params [0.34689288 1.27748223] with index None and target value 1.1582171615386736
# Extracting info: target 1.1582171615386736 is scalar
# Point registered successfully
# Probed target value: 1.1582171615386736
# Probing_barriers at point: index None, value {'x': 0.3468928824170674, 'y': 1.2774822349546127}
# Probed barrier_target values: [-0.11691927]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Registering params [-0.82159302  0.08201164] with index None and target value 1.5596113849454376
# Extracting info: target 1.5596113849454376 is scalar
# Point registered successfully
# Probed target value: 1.5596113849454376
# Probing_barriers at point: index None, value {'x': -0.8215930242320897, 'y': 0.08201163642152798}
# Probed barrier_target values: [-3.69749675]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Registering params [0.2458041 0.8193955] with index None and target value 1.2315744617174662
# Extracting info: target 1.2315744617174662 is scalar
# Point registered successfully
# Probed target value: 1.2315744617174662
# Probing_barriers at point: index None, value {'x': 0.2458041041695198, 'y': 0.8193955043758705}
# Probed barrier_target values: [-1.2588649]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Registering params [-0.94880752 -0.13391692] with index None and target value 1.1327383432973934
# Extracting info: target 1.1327383432973934 is scalar
# Point registered successfully
# Probed target value: 1.1327383432973934
# Probing_barriers at point: index None, value {'x': -0.9488075198718833, 'y': -0.13391691733846134}
# Probed barrier_target values: [-3.00375108]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Registering params [1.85728711 1.16797939] with index None and target value 1.0335852024912042
# Extracting info: target 1.0335852024912042 is scalar
# Point registered successfully
# Probed target value: 1.0335852024912042
# Probing_barriers at point: index None, value {'x': 1.8572871050195152, 'y': 1.1679793935564695}
# Probed barrier_target values: [-0.63768823]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Registering params [-0.14685476  0.22168027] with index None and target value 1.028896498407277
# Extracting info: target 1.028896498407277 is scalar
# Point registered successfully
# Probed target value: 1.028896498407277
# Probing_barriers at point: index None, value {'x': -0.1468547565608822, 'y': 0.22168027012376879}
# Probed barrier_target values: [-3.72585397]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Registering params [0.31593137 1.63517331] with index None and target value 1.0478765103082408
# Extracting info: target 1.0478765103082408 is scalar
# Point registered successfully
# Probed target value: 1.0478765103082408
# Probing_barriers at point: index None, value {'x': 0.3159313703433151, 'y': 1.6351733135118636}
# Probed barrier_target values: [1.1914944]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Registering params [-1.73149633  1.42405001] with index None and target value -0.27706681223960516
# Extracting info: target -0.27706681223960516 is scalar
# Point registered successfully
# Probed target value: -0.27706681223960516
# Probing_barriers at point: index None, value {'x': -1.7314963261245482, 'y': 1.4240500140543406}
# Probed barrier_target values: [-0.25930596]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Registering params [ 0.72057912 -1.48084983] with index None and target value 0.8215895072673417
# Extracting info: target 0.8215895072673417 is scalar
# Point registered successfully
# Probed target value: 0.8215895072673417
# Probing_barriers at point: index None, value {'x': 0.7205791183900967, 'y': -1.4808498280565516}
# Probed barrier_target values: [-2.15223167]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Registering params [0.34880767 0.05552785] with index None and target value 1.3109771707802058
# Extracting info: target 1.3109771707802058 is scalar
# Point registered successfully
# Probed target value: 1.3109771707802058
# Probing_barriers at point: index None, value {'x': 0.3488076712881165, 'y': 0.0555278510991557}
# Probed barrier_target values: [-4.42093903]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Registering params [ 0.42208191 -0.09440631] with index None and target value 1.388010141439827
# Extracting info: target 1.388010141439827 is scalar
# Point registered successfully
# Probed target value: 1.388010141439827
# Probing_barriers at point: index None, value {'x': 0.4220819059272394, 'y': -0.09440631064485938}
# Probed barrier_target values: [-3.66950243]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Registering params [ 0.02765431 -1.22492749] with index None and target value 0.9670170771123171
# Extracting info: target 0.9670170771123171 is scalar
# Point registered successfully
# Probed target value: 0.9670170771123171
# Probing_barriers at point: index None, value {'x': 0.027654307113972987, 'y': -1.2249274867243074}
# Probed barrier_target values: [-4.13691477]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Registering params [-1.54411934 -1.52009926] with index None and target value 0.43980216489469337
# Extracting info: target 0.43980216489469337 is scalar
# Point registered successfully
# Probed target value: 0.43980216489469337
# Probing_barriers at point: index None, value {'x': -1.5441193399235962, 'y': -1.5200992628954724}
# Probed barrier_target values: [0.55769396]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Registering params [-2.00256869  0.05198445] with index None and target value 0.3439895360116495
# Extracting info: target 0.3439895360116495 is scalar
# Point registered successfully
# Probed target value: 0.3439895360116495
# Probing_barriers at point: index None, value {'x': -2.0025686865738517, 'y': 0.051984451666742704}
# Probed barrier_target values: [-0.18354646]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Registering params [-1.52244084 -1.19073287] with index None and target value -0.6384166908160336
# Extracting info: target -0.6384166908160336 is scalar
# Point registered successfully
# Probed target value: -0.6384166908160336
# Probing_barriers at point: index None, value {'x': -1.5224408421534161, 'y': -1.1907328720044945}
# Probed barrier_target values: [-0.25763418]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Registering params [ 1.32206587 -2.22464303] with index None and target value 2.1343801557620763
# Extracting info: target 2.1343801557620763 is scalar
# Point registered successfully
# Probed target value: 2.1343801557620763
# Probing_barriers at point: index None, value {'x': 1.3220658694314391, 'y': -2.224643033221029}
# Probed barrier_target values: [2.04334017]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Registering params [0.92828252 1.26893066] with index None and target value -0.48744022805628173
# Extracting info: target -0.48744022805628173 is scalar
# Point registered successfully
# Probed target value: -0.48744022805628173
# Probing_barriers at point: index None, value {'x': 0.9282825183655152, 'y': 1.2689306610936546}
# Probed barrier_target values: [-1.62672166]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Registering params [1.91541394 1.69821197] with index None and target value 2.7535921962394094
# Extracting info: target 2.7535921962394094 is scalar
# Point registered successfully
# Probed target value: 2.7535921962394094
# Probing_barriers at point: index None, value {'x': 1.9154139438265618, 'y': 1.698211969785664}
# Probed barrier_target values: [1.37639855]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Registering params [ 2.02316195 -1.81181606] with index None and target value -0.9305720658093499
# Extracting info: target -0.9305720658093499 is scalar
# Point registered successfully
# Probed target value: -0.9305720658093499
# Probing_barriers at point: index None, value {'x': 2.023161947749122, 'y': -1.811816064462719}
# Probed barrier_target values: [3.30441413]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Registering params [-2.01631184  0.07306423] with index None and target value 0.36634704489999537
# Extracting info: target 0.36634704489999537 is scalar
# Point registered successfully
# Probed target value: 0.36634704489999537
# Probing_barriers at point: index None, value {'x': -2.0163118419677377, 'y': 0.07306422925233491}
# Probed barrier_target values: [-0.14908712]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Registering params [-2.24482886 -2.23576202] with index None and target value 1.2412113033403984
# Extracting info: target 1.2412113033403984 is scalar
# Point registered successfully
# Probed target value: 1.2412113033403984
# Probing_barriers at point: index None, value {'x': -2.244828864640144, 'y': -2.2357620241256235}
# Probed barrier_target values: [5.89183547]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Registering params [1.33523089 0.45697979] with index None and target value -0.5800112932865991
# Extracting info: target -0.5800112932865991 is scalar
# Point registered successfully
# Probed target value: -0.5800112932865991
# Probing_barriers at point: index None, value {'x': 1.3352308917594726, 'y': 0.45697979270586453}
# Probed barrier_target values: [-3.07860715]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Registering params [ 1.02160119 -2.39086375] with index None and target value 0.9871442737234035
# Extracting info: target 0.9871442737234035 is scalar
# Point registered successfully
# Probed target value: 0.9871442737234035
# Probing_barriers at point: index None, value {'x': 1.0216011902379436, 'y': -2.390863754884657}
# Probed barrier_target values: [1.76890236]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Registering params [-0.8114609  -1.41164763] with index None and target value -0.4469232927980537
# Extracting info: target -0.4469232927980537 is scalar
# Point registered successfully
# Probed target value: -0.4469232927980537
# Probing_barriers at point: index None, value {'x': -0.8114608976290234, 'y': -1.4116476287699375}
# Probed barrier_target values: [-2.03815483]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Registering params [ 1.8095815  -2.46463651] with index None and target value 0.5484065664145346
# Extracting info: target 0.5484065664145346 is scalar
# Point registered successfully
# Probed target value: 0.5484065664145346
# Probing_barriers at point: index None, value {'x': 1.8095815015888332, 'y': -2.4646365138700674}
# Probed barrier_target values: [4.92000509]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Registering params [-1.15098272  0.76947939] with index None and target value 0.8355201335245834
# Extracting info: target 0.8355201335245834 is scalar
# Point registered successfully
# Probed target value: 0.8355201335245834
# Probing_barriers at point: index None, value {'x': -1.1509827166855635, 'y': 0.7694793918835758}
# Probed barrier_target values: [-3.52507109]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Registering params [0.81677548 0.239688  ] with index None and target value 1.3272026196874078
# Extracting info: target 1.3272026196874078 is scalar
# Point registered successfully
# Probed target value: 1.3272026196874078
# Probing_barriers at point: index None, value {'x': 0.8167754829266243, 'y': 0.2396879996414829}
# Probed barrier_target values: [-4.21432764]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#      acquisition terminated
# None        None      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration: selected point from queue, index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0774894760609595, 'y': -1.6291783233635453}
# Registering params [ 1.07748948 -1.62917832] with index None and target value 1.077391872799466
# ...
# Probing point: index None, value {'x': array([0.72676711]), 'y': array([-0.23234444])}
# Registering params [ 0.72676711 -0.23234444] with index None and target value 1.6546282250046276
# Extracting info: target 1.6546282250046276 is scalar
# Point registered successfully
# Probed target value: 1.6546282250046276
# Probing_barriers at point: index None, value {'x': array([0.72676711]), 'y': array([-0.23234444])}
# Probed barrier_target values: [-3.24296031]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.196936      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 106: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70834532]
#  [ 0.19007117]]) = -1.1839677586132331
# Suggested point: index None, value {'x': array([-0.70834532]), 'y': array([0.19007117])}, acquisition -1.1839677586132331
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70834532]), 'y': array([0.19007117])}
# Registering params [-0.70834532  0.19007117] with index None and target value 1.6384711673225612
# Extracting info: target 1.6384711673225612 is scalar
# Point registered successfully
# Probed target value: 1.6384711673225612
# Probing_barriers at point: index None, value {'x': array([-0.70834532]), 'y': array([0.19007117])}
# Probed barrier_target values: [-4.32934651]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183968      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 107: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70832837]
#  [ 0.19008943]]) = -1.183965662393978
# Suggested point: index None, value {'x': array([-0.70832837]), 'y': array([0.19008943])}, acquisition -1.183965662393978
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70832837]), 'y': array([0.19008943])}
# Registering params [-0.70832837  0.19008943] with index None and target value 1.6384692724730603
# Extracting info: target 1.6384692724730603 is scalar
# Point registered successfully
# Probed target value: 1.6384692724730603
# Probing_barriers at point: index None, value {'x': array([-0.70832837]), 'y': array([0.19008943])}
# Probed barrier_target values: [-4.3294567]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183966      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 108: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70831658]
#  [ 0.1901019 ]]) = -1.1839636242993807
# Suggested point: index None, value {'x': array([-0.70831658]), 'y': array([0.1901019])}, acquisition -1.1839636242993807
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70831658]), 'y': array([0.1901019])}
# Registering params [-0.70831658  0.1901019 ] with index None and target value 1.6384679505576802
# Extracting info: target 1.6384679505576802 is scalar
# Point registered successfully
# Probed target value: 1.6384679505576802
# Probing_barriers at point: index None, value {'x': array([-0.70831658]), 'y': array([0.1901019])}
# Probed barrier_target values: [-4.32953253]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183964      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 109: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70830268]
#  [ 0.19011731]]) = -1.1839616473067438
# Suggested point: index None, value {'x': array([-0.70830268]), 'y': array([0.19011731])}, acquisition -1.1839616473067438
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70830268]), 'y': array([0.19011731])}
# Registering params [-0.70830268  0.19011731] with index None and target value 1.6384663945094378
# Extracting info: target 1.6384663945094378 is scalar
# Point registered successfully
# Probed target value: 1.6384663945094378
# Probing_barriers at point: index None, value {'x': array([-0.70830268]), 'y': array([0.19011731])}
# Probed barrier_target values: [-4.32962451]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183962      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 110: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70828889]
#  [ 0.19013197]]) = -1.1839597243473547
# Suggested point: index None, value {'x': array([-0.70828889]), 'y': array([0.19013197])}, acquisition -1.1839597243473547
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70828889]), 'y': array([0.19013197])}
# Registering params [-0.70828889  0.19013197] with index None and target value 1.6384648437211111
# Extracting info: target 1.6384648437211111 is scalar
# Point registered successfully
# Probed target value: 1.6384648437211111
# Probing_barriers at point: index None, value {'x': array([-0.70828889]), 'y': array([0.19013197])}
# Probed barrier_target values: [-4.32971346]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     -1.18396      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 111: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.72708858]
#  [-0.23259637]]) = -1.1968927815022123
# Suggested point: index None, value {'x': array([0.72708858]), 'y': array([-0.23259637])}, acquisition -1.1968927815022123
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.72708858]), 'y': array([-0.23259637])}
# Registering params [ 0.72708858 -0.23259637] with index None and target value 1.6546692808988142
# Extracting info: target 1.6546692808988142 is scalar
# Point registered successfully
# Probed target value: 1.6546692808988142
# Probing_barriers at point: index None, value {'x': array([0.72708858]), 'y': array([-0.23259637])}
# Probed barrier_target values: [-3.24234978]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.196893      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 112: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70827231]
#  [ 0.19015019]]) = -1.1839575849612576
# Suggested point: index None, value {'x': array([-0.70827231]), 'y': array([0.19015019])}, acquisition -1.1839575849612576
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70827231]), 'y': array([0.19015019])}
# Registering params [-0.70827231  0.19015019] with index None and target value 1.638462980508875
# Extracting info: target 1.638462980508875 is scalar
# Point registered successfully
# Probed target value: 1.638462980508875
# Probing_barriers at point: index None, value {'x': array([-0.70827231]), 'y': array([0.19015019])}
# Probed barrier_target values: [-4.32982256]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183958      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 113: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70826554]
#  [ 0.19015719]]) = -1.1839557652808903
# Suggested point: index None, value {'x': array([-0.70826554]), 'y': array([0.19015719])}, acquisition -1.1839557652808903
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70826554]), 'y': array([0.19015719])}
# Registering params [-0.70826554  0.19015719] with index None and target value 1.6384622149005263
# Extracting info: target 1.6384622149005263 is scalar
# Point registered successfully
# Probed target value: 1.6384622149005263
# Probing_barriers at point: index None, value {'x': array([-0.70826554]), 'y': array([0.19015719])}
# Probed barrier_target values: [-4.32986552]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183956      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 114: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.72737086]
#  [-0.23282417]]) = -1.1968571084708592
# Suggested point: index None, value {'x': array([0.72737086]), 'y': array([-0.23282417])}, acquisition -1.1968571084708592
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.72737086]), 'y': array([-0.23282417])}
# Registering params [ 0.72737086 -0.23282417] with index None and target value 1.6547053650144936
# Extracting info: target 1.6547053650144936 is scalar
# Point registered successfully
# Probed target value: 1.6547053650144936
# Probing_barriers at point: index None, value {'x': array([0.72737086]), 'y': array([-0.23282417])}
# Probed barrier_target values: [-3.24180936]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.196857      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 115: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70824799]
#  [ 0.19017621]]) = -1.1839537402063751
# Suggested point: index None, value {'x': array([-0.70824799]), 'y': array([0.19017621])}, acquisition -1.1839537402063751
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70824799]), 'y': array([0.19017621])}
# Registering params [-0.70824799  0.19017621] with index None and target value 1.6384602336118665
# Extracting info: target 1.6384602336118665 is scalar
# Point registered successfully
# Probed target value: 1.6384602336118665
# Probing_barriers at point: index None, value {'x': array([-0.70824799]), 'y': array([0.19017621])}
# Probed barrier_target values: [-4.32998007]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183954      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 116: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.72762901]
#  [-0.23303714]]) = -1.1968259833898771
# Suggested point: index None, value {'x': array([0.72762901]), 'y': array([-0.23303714])}, acquisition -1.1968259833898771
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.72762901]), 'y': array([-0.23303714])}
# Registering params [ 0.72762901 -0.23303714] with index None and target value 1.6547383293543767
# Extracting info: target 1.6547383293543767 is scalar
# Point registered successfully
# Probed target value: 1.6547383293543767
# Probing_barriers at point: index None, value {'x': array([0.72762901]), 'y': array([-0.23303714])}
# Probed barrier_target values: [-3.24131207]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.196826      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 117: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.7278643 ]
#  [-0.23323543]]) = -1.1967985794875193
# Suggested point: index None, value {'x': array([0.7278643]), 'y': array([-0.23323543])}, acquisition -1.1967985794875193
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.7278643]), 'y': array([-0.23323543])}
# Registering params [ 0.7278643  -0.23323543] with index None and target value 1.6547683743021366
# Extracting info: target 1.6547683743021366 is scalar
# Point registered successfully
# Probed target value: 1.6547683743021366
# Probing_barriers at point: index None, value {'x': array([0.7278643]), 'y': array([-0.23323543])}
# Probed barrier_target values: [-3.24085608]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.196799      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 118: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.70823377]
#  [ 0.19019153]]) = -1.1839515130344969
# Suggested point: index None, value {'x': array([-0.70823377]), 'y': array([0.19019153])}, acquisition -1.1839515130344969
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.70823377]), 'y': array([0.19019153])}
# Registering params [-0.70823377  0.19019153] with index None and target value 1.638458625288141
# Extracting info: target 1.638458625288141 is scalar
# Point registered successfully
# Probed target value: 1.638458625288141
# Probing_barriers at point: index None, value {'x': array([-0.70823377]), 'y': array([0.19019153])}
# Probed barrier_target values: [-4.33007251]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.183952      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# New iteration 119: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.72808442]
#  [-0.23342521]]) = -1.1967731272555409
# Suggested point: index None, value {'x': array([0.72808442]), 'y': array([-0.23342521])}, acquisition -1.1967731272555409
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.72808442]), 'y': array([-0.23342521])}
# Registering params [ 0.72808442 -0.23342521] with index None and target value 1.6547965435432608
# Extracting info: target 1.6547965435432608 is scalar
# Point registered successfully
# Probed target value: 1.6547965435432608
# Probing_barriers at point: index None, value {'x': array([0.72808442]), 'y': array([-0.23342521])}
# Probed barrier_target values: [-3.24042669]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    -1.196773      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# max: {'target': 1.930380616202914, 'params': {'x': 1.9848685917481657, 'y': 1.201682594244355}}
# Results successfully saved to c:\Users\alyra\OneDrive\Desktop\bayesian_opt\MALIBOO
# =================================================

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[:50]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')
plt.scatter(x_iter[:-1], y_iter[:-1], s=20, alpha = 0.5)
plt.scatter(x_iter.iloc[-1], y_iter.iloc[-1], s=20, alpha = 0.5, color = 'black')
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)


plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()
# Out:
# first occurrence of maximum at iteration: 92
