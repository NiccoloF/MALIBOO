# %% [markdown]
# # Townsend

# %%
from maliboo import BayesianOptimization, UtilityFunction
import numpy as np
import os

import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

import pandas as pd
import time

import warnings

# %%
# Townsend
def target(x,y):
    return -(-np.cos((x-0.1)*y)**2-x*np.sin(3*x+y))

# %%
def constraint(x,y):
    return x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2

# %%
ninit = 10

# %%
# DEFINE THE OPTIMIZATION CLASS AND OTHER FUNCTIONS 


import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27222
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=52187381,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=10, n_iter=100,acq='eb',mean_p = 1.,std_p = 1.,acq_info={'static_lambda':False})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})
# Out:
# Initializing TargetSpace with bounds: {'x': (-2.25, 2.5), 'y': (-2.5, 1.75)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 10 random points
# Uniform randomly sampled point: value [[-2.07562266  1.42160195]]
# Uniform randomly sampled point: value [[ 0.47320286 -0.44350775]]
# Uniform randomly sampled point: value [[-0.22446244 -1.70765114]]
# Uniform randomly sampled point: value [[2.260542  1.1312322]]
# Uniform randomly sampled point: value [[1.62077785 0.57205078]]
# Uniform randomly sampled point: value [[-0.90128857 -0.24241176]]
# Uniform randomly sampled point: value [[0.65519899 0.05031477]]
# Uniform randomly sampled point: value [[ 1.08695541 -1.60048165]]
# Uniform randomly sampled point: value [[-1.52026279 -1.20927477]]
# Uniform randomly sampled point: value [[-0.41073856 -2.30159415]]
# Initializing UtilityFunction of kind 'eb' with acq_info = {'static_lambda': False}
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': -2.0756226620322975, 'y': 1.4216019478592505}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.0756226620322975, 'y': 1.4216019478592505}
# Registering params [-2.07562266  1.42160195] with index None and target value -1.069048857609296
# Extracting info: target -1.069048857609296 is scalar
# Point registered successfully
# Probed target value: -1.069048857609296
# Probing_barriers at point: index None, value {'x': -2.0756226620322975, 'y': 1.4216019478592505}
# Probed barrier_target values: [0.89522745]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.47320285581719146, 'y': -0.4435077527450595}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.47320285581719146, 'y': -0.4435077527450595}
# Registering params [ 0.47320286 -0.44350775] with index None and target value 1.3648159238586821
# Extracting info: target 1.3648159238586821 is scalar
# Point registered successfully
# Probed target value: 1.3648159238586821
# Probing_barriers at point: index None, value {'x': 0.47320285581719146, 'y': -0.4435077527450595}
# Probed barrier_target values: [-3.6813318]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.2244624358257168, 'y': -1.7076511381615305}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.2244624358257168, 'y': -1.7076511381615305}
# Registering params [-0.22446244 -1.70765114] with index None and target value 0.8778917137852461
# Extracting info: target 0.8778917137852461 is scalar
# Point registered successfully
# Probed target value: 0.8778917137852461
# Probing_barriers at point: index None, value {'x': -0.2244624358257168, 'y': -1.7076511381615305}
# Probed barrier_target values: [-2.59222857]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 2.260542003146579, 'y': 1.1312321979541298}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.260542003146579, 'y': 1.1312321979541298}
# Registering params [2.260542  1.1312322] with index None and target value 2.844053531487501
# Extracting info: target 2.844053531487501 is scalar
# Point registered successfully
# Probed target value: 2.844053531487501
# Probing_barriers at point: index None, value {'x': 2.260542003146579, 'y': 1.1312321979541298}
# Probed barrier_target values: [1.0124274]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.6207778543450324, 'y': 0.5720507834842987}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.6207778543450324, 'y': 0.5720507834842987}
# Registering params [1.62077785 0.57205078] with index None and target value -0.8005365995347926
# Extracting info: target -0.8005365995347926 is scalar
# Point registered successfully
# Probed target value: -0.8005365995347926
# Probing_barriers at point: index None, value {'x': 1.6207778543450324, 'y': 0.5720507834842987}
# Probed barrier_target values: [-2.14315492]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.901288572942599, 'y': -0.24241175928687797}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.901288572942599, 'y': -0.24241175928687797}
# Registering params [-0.90128857 -0.24241176] with index None and target value 1.1171511768738749
# Extracting info: target 1.1171511768738749 is scalar
# Point registered successfully
# Probed target value: 1.1171511768738749
# Probing_barriers at point: index None, value {'x': -0.901288572942599, 'y': -0.24241175928687797}
# Probed barrier_target values: [-2.96553965]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.6551989901561868, 'y': 0.0503147738754679}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6551989901561868, 'y': 0.0503147738754679}
# Registering params [0.65519899 0.05031477] with index None and target value 1.5905768955239465
# Extracting info: target 1.5905768955239465 is scalar
# Point registered successfully
# Probed target value: 1.5905768955239465
# Probing_barriers at point: index None, value {'x': 0.6551989901561868, 'y': 0.0503147738754679}
# Probed barrier_target values: [-3.88704838]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.0869554084734747, 'y': -1.6004816455602286}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.0869554084734747, 'y': -1.6004816455602286}
# Registering params [ 1.08695541 -1.60048165] with index None and target value 1.082673916546671
# Extracting info: target 1.082673916546671 is scalar
# Point registered successfully
# Probed target value: 1.082673916546671
# Probing_barriers at point: index None, value {'x': 1.0869554084734747, 'y': -1.6004816455602286}
# Probed barrier_target values: [-0.76734915]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.520262789285339, 'y': -1.2092747701432647}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.520262789285339, 'y': -1.2092747701432647}
# Registering params [-1.52026279 -1.20927477] with index None and target value -0.6027739986962634
# Extracting info: target -0.6027739986962634 is scalar
# Point registered successfully
# Probed target value: -0.6027739986962634
# Probing_barriers at point: index None, value {'x': -1.520262789285339, 'y': -1.2092747701432647}
# Probed barrier_target values: [-0.2285033]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.41073856361785355, 'y': -2.3015941458844993}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.41073856361785355, 'y': -2.3015941458844993}
# Registering params [-0.41073856 -2.30159415] with index None and target value -0.008721217308007873
# Extracting info: target -0.008721217308007873 is scalar
# Point registered successfully
# Probed target value: -0.008721217308007873
# Probing_barriers at point: index None, value {'x': -0.41073856361785355, 'y': -2.3015941458844993}
# Probed barrier_target values: [-0.02771291]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 0: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 2.38277993]
#  [-2.1499981 ]]) = 6394844927.598625
# Suggested point: index None, value {'x': array([2.38277993]), 'y': array([-2.1499981])}, acquisition 6394844927.598625
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.38277993]), 'y': array([-2.1499981])}
# Registering params [ 2.38277993 -2.1499981 ] with index None and target value -2.248255591932527
# Extracting info: target -2.248255591932527 is scalar
# Point registered successfully
# Probed target value: -2.248255591932527
# Probing_barriers at point: index None, value {'x': array([2.38277993]), 'y': array([-2.1499981])}
# Probed barrier_target values: [6.22378773]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  6.394845e+09      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 1: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.84961363]
#  [ 1.75      ]]) = 9059736382.099678
# Suggested point: index None, value {'x': array([-0.84961363]), 'y': array([1.75])}, acquisition 9059736382.099678
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.84961363]), 'y': array([1.75])}
# Registering params [-0.84961363  1.75      ] with index None and target value 0.6170521317342225
# Extracting info: target 0.6170521317342225 is scalar
# Point registered successfully
# Probed target value: 0.6170521317342225
# Probing_barriers at point: index None, value {'x': array([-0.84961363]), 'y': array([1.75])}
# Probed barrier_target values: [0.872288]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  9.059736e+09      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 2: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.26902432]
#  [0.63086331]]) = 1632827.384939687
# Suggested point: index None, value {'x': array([2.26902432]), 'y': array([0.63086331])}, acquisition 1632827.384939687
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.26902432]), 'y': array([0.63086331])}
# Registering params [2.26902432 0.63086331] with index None and target value 2.115888265812874
# Extracting info: target 2.115888265812874 is scalar
# Point registered successfully
# Probed target value: 2.115888265812874
# Probing_barriers at point: index None, value {'x': array([2.26902432]), 'y': array([0.63086331])}
# Probed barrier_target values: [0.65130827]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  1.632827e+06      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 3: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-2.19720563]
#  [-0.87504256]]) = 5757390131.137873
# Suggested point: index None, value {'x': array([-2.19720563]), 'y': array([-0.87504256])}, acquisition 5757390131.137873
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-2.19720563]), 'y': array([-0.87504256])}
# Registering params [-2.19720563 -0.87504256] with index None and target value 2.2153736593508255
# Extracting info: target 2.2153736593508255 is scalar
# Point registered successfully
# Probed target value: 2.2153736593508255
# Probing_barriers at point: index None, value {'x': array([-2.19720563]), 'y': array([-0.87504256])}
# Probed barrier_target values: [1.76819497]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  5.757390e+09      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 4: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.24033796]
#  [-0.77734403]]) = 11.050568377238918
# Suggested point: index None, value {'x': array([-0.24033796]), 'y': array([-0.77734403])}, acquisition 11.050568377238918
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.24033796]), 'y': array([-0.77734403])}
# Registering params [-0.24033796 -0.77734403] with index None and target value 1.1713336352407426
# Extracting info: target 1.1713336352407426 is scalar
# Point registered successfully
# Probed target value: 1.1713336352407426
# Probing_barriers at point: index None, value {'x': array([-0.24033796]), 'y': array([-0.77734403])}
# Probed barrier_target values: [-4.58603722]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    11.050568      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 5: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 1.87409121]
#  [-0.73675559]]) = 36389633.234161764
# Suggested point: index None, value {'x': array([1.87409121]), 'y': array([-0.73675559])}, acquisition 36389633.234161764
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.87409121]), 'y': array([-0.73675559])}
# Registering params [ 1.87409121 -0.73675559] with index None and target value -1.7781214329111434
# Extracting info: target -1.7781214329111434 is scalar
# Point registered successfully
# Probed target value: -1.7781214329111434
# Probing_barriers at point: index None, value {'x': array([1.87409121]), 'y': array([-0.73675559])}
# Probed barrier_target values: [0.23036744]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  3.638963e+07      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 6: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.22209152]
#  [-0.73646247]]) = 12.515216636611155
# Suggested point: index None, value {'x': array([-0.22209152]), 'y': array([-0.73646247])}, acquisition 12.515216636611155
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.22209152]), 'y': array([-0.73646247])}
# Registering params [-0.22209152 -0.73646247] with index None and target value 1.1637422072506016
# Extracting info: target 1.1637422072506016 is scalar
# Point registered successfully
# Probed target value: 1.1637422072506016
# Probing_barriers at point: index None, value {'x': array([-0.22209152]), 'y': array([-0.73646247])}
# Probed barrier_target values: [-4.67240881]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    12.515217      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 7: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.87793001]
#  [-2.28201965]]) = 904.5790090815555
# Suggested point: index None, value {'x': array([0.87793001]), 'y': array([-2.28201965])}, acquisition 904.5790090815555
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.87793001]), 'y': array([-2.28201965])}
# Registering params [ 0.87793001 -2.28201965] with index None and target value 0.3437225617992818
# Extracting info: target 0.3437225617992818 is scalar
# Point registered successfully
# Probed target value: 0.3437225617992818
# Probing_barriers at point: index None, value {'x': array([0.87793001]), 'y': array([-2.28201965])}
# Probed barrier_target values: [0.89420131]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None   904.579009      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 8: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.17571759]
#  [ 0.48581016]]) = 9.678935576637501
# Suggested point: index None, value {'x': array([-0.17571759]), 'y': array([0.48581016])}, acquisition 9.678935576637501
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.17571759]), 'y': array([0.48581016])}
# Registering params [-0.17571759  0.48581016] with index None and target value 0.9894279590401632
# Extracting info: target 0.9894279590401632 is scalar
# Point registered successfully
# Probed target value: 0.9894279590401632
# Probing_barriers at point: index None, value {'x': array([-0.17571759]), 'y': array([0.48581016])}
# Probed barrier_target values: [-2.0115025]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     9.678936      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 9: suggesting new point
# End of acq_max(): maximizer of utility is ac([[1.63718784]
#  [1.75      ]]) = 3679.7726716086463
# Suggested point: index None, value {'x': array([1.63718784]), 'y': array([1.75])}, acquisition 3679.7726716086463
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.63718784]), 'y': array([1.75])}
# Registering params [1.63718784 1.75      ] with index None and target value 1.4144175654131963
# Extracting info: target 1.4144175654131963 is scalar
# Point registered successfully
# Probed target value: 1.4144175654131963
# Probing_barriers at point: index None, value {'x': array([1.63718784]), 'y': array([1.75])}
# Probed barrier_target values: [0.95391688]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None  3679.772672      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 10: suggesting new point
# End of acq_max(): maximizer of utility is ac([[0.18928409]
#  [1.6037293 ]]) = 3478.039935804529
# Suggested point: index None, value {'x': array([0.18928409]), 'y': array([1.6037293])}, acquisition 3478.039935804529
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.18928409]), 'y': array([1.6037293])}
# Registering params [0.18928409 1.6037293 ] with index None and target value 1.1357760018883827
# Extracting info: target 1.1357760018883827 is scalar
# Point registered successfully
# Probed target value: 1.1357760018883827
# Probing_barriers at point: index None, value {'x': array([0.18928409]), 'y': array([1.6037293])}
# Probed barrier_target values: [1.22140261]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None  3478.039936      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 11: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.30397011]
#  [-2.16612701]]) = 1276076770.7277453
# Suggested point: index None, value {'x': array([-1.30397011]), 'y': array([-2.16612701])}, acquisition 1276076770.7277453
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.30397011]), 'y': array([-2.16612701])}
# Registering params [-1.30397011 -2.16612701] with index None and target value 0.7243162599822323
# Extracting info: target 0.7243162599822323 is scalar
# Point registered successfully
# Probed target value: 0.7243162599822323
# Probing_barriers at point: index None, value {'x': array([-1.30397011]), 'y': array([-2.16612701])}
# Probed barrier_target values: [1.75276839]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  1.276077e+09      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 12: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.17309404]
#  [-0.55955422]]) = 9.60814733900722
# Suggested point: index None, value {'x': array([-0.17309404]), 'y': array([-0.55955422])}, acquisition 9.60814733900722
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.17309404]), 'y': array([-0.55955422])}
# Registering params [-0.17309404 -0.55955422] with index None and target value 1.1293966194323328
# Extracting info: target 1.1293966194323328 is scalar
# Point registered successfully
# Probed target value: 1.1293966194323328
# Probing_barriers at point: index None, value {'x': array([-0.17309404]), 'y': array([-0.55955422])}
# Probed barrier_target values: [-4.9046529]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     9.608147      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 13: suggesting new point
# End of acq_max(): maximizer of utility is ac([[0.87855273]
#  [1.35174269]]) = 21575.29705154293
# Suggested point: index None, value {'x': array([0.87855273]), 'y': array([1.35174269])}, acquisition 21575.29705154293
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.87855273]), 'y': array([1.35174269])}
# Registering params [0.87855273 1.35174269] with index None and target value -0.41209752082955886
# Extracting info: target -0.41209752082955886 is scalar
# Point registered successfully
# Probed target value: -0.41209752082955886
# Probing_barriers at point: index None, value {'x': array([0.87855273]), 'y': array([1.35174269])}
# Probed barrier_target values: [-1.13947845]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  21575.297052      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 14: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.24712645]
#  [-2.25659465]]) = 37.56216842654028
# Suggested point: index None, value {'x': array([0.24712645]), 'y': array([-2.25659465])}, acquisition 37.56216842654028
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.24712645]), 'y': array([-2.25659465])}
# Registering params [ 0.24712645 -2.25659465] with index None and target value 0.6470189711123953
# Extracting info: target 0.6470189711123953 is scalar
# Point registered successfully
# Probed target value: 0.6470189711123953
# Probing_barriers at point: index None, value {'x': array([0.24712645]), 'y': array([-2.25659465])}
# Probed barrier_target values: [-0.42986806]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    37.562168      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 15: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.62062051]
#  [ 0.4685106 ]]) = 40742.64283612459
# Suggested point: index None, value {'x': array([-1.62062051]), 'y': array([0.4685106])}, acquisition 40742.64283612459
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.62062051]), 'y': array([0.4685106])}
# Registering params [-1.62062051  0.4685106 ] with index None and target value -1.0595649208430213
# Extracting info: target -1.0595649208430213 is scalar
# Point registered successfully
# Probed target value: -1.0595649208430213
# Probing_barriers at point: index None, value {'x': array([-1.62062051]), 'y': array([0.4685106])}
# Probed barrier_target values: [-2.08069986]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  40742.642836      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 16: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.92196086]
#  [-0.35360068]]) = 797986891.3924698
# Suggested point: index None, value {'x': array([-1.92196086]), 'y': array([-0.35360068])}, acquisition 797986891.3924698
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.92196086]), 'y': array([-0.35360068])}
# Registering params [-1.92196086 -0.35360068] with index None and target value 0.25697316589297425
# Extracting info: target 0.25697316589297425 is scalar
# Point registered successfully
# Probed target value: 0.25697316589297425
# Probing_barriers at point: index None, value {'x': array([-1.92196086]), 'y': array([-0.35360068])}
# Probed barrier_target values: [-0.06393507]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  7.979869e+08      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 17: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.36365273]
#  [ 1.04776106]]) = 8068.657417994037
# Suggested point: index None, value {'x': array([-0.36365273]), 'y': array([1.04776106])}, acquisition 8068.657417994037
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.36365273]), 'y': array([1.04776106])}
# Registering params [-0.36365273  1.04776106] with index None and target value 0.7976956148285602
# Extracting info: target 0.7976956148285602 is scalar
# Point registered successfully
# Probed target value: 0.7976956148285602
# Probing_barriers at point: index None, value {'x': array([-0.36365273]), 'y': array([1.04776106])}
# Probed barrier_target values: [-0.97764319]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None  8068.657418      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 18: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-2.15459659]
#  [-0.16559803]]) = 12337.65497904647
# Suggested point: index None, value {'x': array([-2.15459659]), 'y': array([-0.16559803])}, acquisition 12337.65497904647
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-2.15459659]), 'y': array([-0.16559803])}
# Registering params [-2.15459659 -0.16559803] with index None and target value 1.5980776344060854
# Extracting info: target 1.5980776344060854 is scalar
# Point registered successfully
# Probed target value: 1.5980776344060854
# Probing_barriers at point: index None, value {'x': array([-2.15459659]), 'y': array([-0.16559803])}
# Probed barrier_target values: [0.66608034]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  12337.654979      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 19: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.1710702 ]
#  [-1.62079281]]) = 139.28824346241746
# Suggested point: index None, value {'x': array([-1.1710702]), 'y': array([-1.62079281])}, acquisition 139.28824346241746
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.1710702]), 'y': array([-1.62079281])}
# Registering params [-1.1710702  -1.62079281] with index None and target value -0.8475738433597484
# Extracting info: target -0.8475738433597484 is scalar
# Point registered successfully
# Probed target value: -0.8475738433597484
# Probing_barriers at point: index None, value {'x': array([-1.1710702]), 'y': array([-1.62079281])}
# Probed barrier_target values: [-0.44715121]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None   139.288243      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 20: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-2.25      ]
#  [ 0.72921083]]) = 2414.4946801411947
# Suggested point: index None, value {'x': array([-2.25]), 'y': array([0.72921083])}, acquisition 2414.4946801411947
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-2.25]), 'y': array([0.72921083])}
# Registering params [-2.25        0.72921083] with index None and target value -0.5633722367357342
# Extracting info: target -0.5633722367357342 is scalar
# Point registered successfully
# Probed target value: -0.5633722367357342
# Probing_barriers at point: index None, value {'x': array([-2.25]), 'y': array([0.72921083])}
# Probed barrier_target values: [0.57141508]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None   2414.49468      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 21: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.99552843]
#  [-0.18053015]]) = 3545200.0383515665
# Suggested point: index None, value {'x': array([-1.99552843]), 'y': array([-0.18053015])}, acquisition 3545200.0383515665
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.99552843]), 'y': array([-0.18053015])}
# Registering params [-1.99552843 -0.18053015] with index None and target value 0.6324819291001025
# Extracting info: target 0.6324819291001025 is scalar
# Point registered successfully
# Probed target value: 0.6324819291001025
# Probing_barriers at point: index None, value {'x': array([-1.99552843]), 'y': array([-0.18053015])}
# Probed barrier_target values: [0.03084004]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  3.545200e+06      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 22: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.74648143]
#  [-0.76083404]]) = 115.50501216705739
# Suggested point: index None, value {'x': array([-1.74648143]), 'y': array([-0.76083404])}, acquisition 115.50501216705739
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.74648143]), 'y': array([-0.76083404])}
# Registering params [-1.74648143 -0.76083404] with index None and target value -0.460246087498455
# Extracting info: target -0.460246087498455 is scalar
# Point registered successfully
# Probed target value: -0.460246087498455
# Probing_barriers at point: index None, value {'x': array([-1.74648143]), 'y': array([-0.76083404])}
# Probed barrier_target values: [-0.20218945]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None   115.505012      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 23: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.42351829]
#  [-1.24436275]]) = 4.778926248560696
# Suggested point: index None, value {'x': array([0.42351829]), 'y': array([-1.24436275])}, acquisition 4.778926248560696
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.42351829]), 'y': array([-1.24436275])}
# Registering params [ 0.42351829 -1.24436275] with index None and target value 0.8575937663538223
# Extracting info: target 0.8575937663538223 is scalar
# Point registered successfully
# Probed target value: 0.8575937663538223
# Probing_barriers at point: index None, value {'x': array([0.42351829]), 'y': array([-1.24436275])}
# Probed barrier_target values: [-3.4533873]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     4.778926      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 24: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 1.3102937 ]
#  [-0.22447079]]) = 4.73799537567143
# Suggested point: index None, value {'x': array([1.3102937]), 'y': array([-0.22447079])}, acquisition 4.73799537567143
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.3102937]), 'y': array([-0.22447079])}
# Registering params [ 1.3102937  -0.22447079] with index None and target value 0.22664027381929763
# Extracting info: target 0.22664027381929763 is scalar
# Point registered successfully
# Probed target value: 0.22664027381929763
# Probing_barriers at point: index None, value {'x': array([1.3102937]), 'y': array([-0.22447079])}
# Probed barrier_target values: [-2.12598118]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     4.737995      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 25: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 1.50017264]
#  [-1.16992248]]) = 152.590443866951
# Suggested point: index None, value {'x': array([1.50017264]), 'y': array([-1.16992248])}, acquisition 152.590443866951
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.50017264]), 'y': array([-1.16992248])}
# Registering params [ 1.50017264 -1.16992248] with index None and target value -0.2773296751986739
# Extracting info: target -0.2773296751986739 is scalar
# Point registered successfully
# Probed target value: -0.2773296751986739
# Probing_barriers at point: index None, value {'x': array([1.50017264]), 'y': array([-1.16992248])}
# Probed barrier_target values: [-0.3725962]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None   152.590444      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 26: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.77323192]
#  [ 1.41012014]]) = 1683968.095972736
# Suggested point: index None, value {'x': array([-0.77323192]), 'y': array([1.41012014])}, acquisition 1683968.095972736
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.77323192]), 'y': array([1.41012014])}
# Registering params [-0.77323192  1.41012014] with index None and target value 0.7211262876015353
# Extracting info: target 0.7211262876015353 is scalar
# Point registered successfully
# Probed target value: 0.7211262876015353
# Probing_barriers at point: index None, value {'x': array([-0.77323192]), 'y': array([1.41012014])}
# Probed barrier_target values: [-0.65196287]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#        acquisition terminated
# None  1.683968e+06      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 27: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.06809768]
#  [-2.42345274]]) = 10.534053322176371
# Suggested point: index None, value {'x': array([-0.06809768]), 'y': array([-2.42345274])}, acquisition 10.534053322176371
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.06809768]), 'y': array([-2.42345274])}
# Registering params [-0.06809768 -2.42345274] with index None and target value 0.8764959776139211
# Extracting info: target 0.8764959776139211 is scalar
# Point registered successfully
# Probed target value: 0.8764959776139211
# Probing_barriers at point: index None, value {'x': array([-0.06809768]), 'y': array([-2.42345274])}
# Probed barrier_target values: [0.24100327]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    10.534053      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 28: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.1334448 ]
#  [-0.52179435]]) = 7.273476495425971
# Suggested point: index None, value {'x': array([-0.1334448]), 'y': array([-0.52179435])}, acquisition 7.273476495425971
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.1334448]), 'y': array([-0.52179435])}
# Registering params [-0.1334448  -0.52179435] with index None and target value 1.0915762796481965
# Extracting info: target 1.0915762796481965 is scalar
# Point registered successfully
# Probed target value: 1.0915762796481965
# Probing_barriers at point: index None, value {'x': array([-0.1334448]), 'y': array([-0.52179435])}
# Probed barrier_target values: [-5.06714536]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     7.273476      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 29: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.07054767]
#  [ 1.22017552]]) = 110750.09900262009
# Suggested point: index None, value {'x': array([-0.07054767]), 'y': array([1.22017552])}, acquisition 110750.09900262009
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.07054767]), 'y': array([1.22017552])}
# Registering params [-0.07054767  1.22017552] with index None and target value 0.8976298008406449
# Extracting info: target 0.8976298008406449 is scalar
# Point registered successfully
# Probed target value: 0.8976298008406449
# Probing_barriers at point: index None, value {'x': array([-0.07054767]), 'y': array([1.22017552])}
# Probed barrier_target values: [0.19891651]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#         acquisition terminated
# None  110750.099003      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 30: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.01004938]
#  [-0.4948473 ]]) = 7.080217470994637
# Suggested point: index None, value {'x': array([0.01004938]), 'y': array([-0.4948473])}, acquisition 7.080217470994637
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.01004938]), 'y': array([-0.4948473])}
# Registering params [ 0.01004938 -0.4948473 ] with index None and target value 0.9935163353899175
# Extracting info: target 0.9935163353899175 is scalar
# Point registered successfully
# Probed target value: 0.9935163353899175
# Probing_barriers at point: index None, value {'x': array([0.01004938]), 'y': array([-0.4948473])}
# Probed barrier_target values: [-5.3936284]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     7.080217      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 31: suggesting new point
# End of acq_max(): maximizer of utility is ac([[2.17070545]
#  [0.04950546]]) = 7122.765270712948
# Suggested point: index None, value {'x': array([2.17070545]), 'y': array([0.04950546])}, acquisition 7122.765270712948
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([2.17070545]), 'y': array([0.04950546])}
# Registering params [2.17070545 0.04950546] with index None and target value 1.5861524377489575
# Extracting info: target 1.5861524377489575 is scalar
# Point registered successfully
# Probed target value: 1.5861524377489575
# Probing_barriers at point: index None, value {'x': array([2.17070545]), 'y': array([0.04950546])}
# Probed barrier_target values: [0.52492108]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None  7122.765271      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 32: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.61936563]
#  [ 1.3361494 ]]) = 413.80627624824723
# Suggested point: index None, value {'x': array([-1.61936563]), 'y': array([1.3361494])}, acquisition 413.80627624824723
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.61936563]), 'y': array([1.3361494])}
# Registering params [-1.61936563  1.3361494 ] with index None and target value -0.15991866087173057
# Extracting info: target -0.15991866087173057 is scalar
# Point registered successfully
# Probed target value: -0.15991866087173057
# Probing_barriers at point: index None, value {'x': array([-1.61936563]), 'y': array([1.3361494])}
# Probed barrier_target values: [-0.87355105]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None   413.806276      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 33: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.94201743]
#  [-1.92478016]]) = 50.86309656742178
# Suggested point: index None, value {'x': array([0.94201743]), 'y': array([-1.92478016])}, acquisition 50.86309656742178
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.94201743]), 'y': array([-1.92478016])}
# Registering params [ 0.94201743 -1.92478016] with index None and target value 0.7411400802189644
# Extracting info: target 0.7411400802189644 is scalar
# Point registered successfully
# Probed target value: 0.7411400802189644
# Probing_barriers at point: index None, value {'x': array([0.94201743]), 'y': array([-1.92478016])}
# Probed barrier_target values: [-0.26633917]
# No termination criteria have been used
# ...
#       acquisition terminated
# None     0.218711      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 86: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.63249259]
#  [ 0.88395165]]) = 0.24714408764288573
# Suggested point: index None, value {'x': array([-1.63249259]), 'y': array([0.88395165])}, acquisition 0.24714408764288573
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.63249259]), 'y': array([0.88395165])}
# Registering params [-1.63249259  0.88395165] with index None and target value -1.248246156850397
# Extracting info: target -1.248246156850397 is scalar
# Point registered successfully
# Probed target value: -1.248246156850397
# Probing_barriers at point: index None, value {'x': array([-1.63249259]), 'y': array([0.88395165])}
# Probed barrier_target values: [-1.97252905]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.247144      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 87: suggesting new point
# End of acq_max(): maximizer of utility is ac([[1.16537054]
#  [1.6408449 ]]) = 1313.440614008027
# Suggested point: index None, value {'x': array([1.16537054]), 'y': array([1.6408449])}, acquisition 1313.440614008027
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.16537054]), 'y': array([1.6408449])}
# Registering params [1.16537054 1.6408449 ] with index None and target value -1.03079414279693
# Extracting info: target -1.03079414279693 is scalar
# Point registered successfully
# Probed target value: -1.03079414279693
# Probing_barriers at point: index None, value {'x': array([1.16537054]), 'y': array([1.6408449])}
# Probed barrier_target values: [0.04164046]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None  1313.440614      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 88: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.10905514]
#  [-1.25510067]]) = 0.2026848025303923
# Suggested point: index None, value {'x': array([-1.10905514]), 'y': array([-1.25510067])}, acquisition 0.2026848025303923
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.10905514]), 'y': array([-1.25510067])}
# Registering params [-1.10905514 -1.25510067] with index None and target value -1.0968398309345835
# Extracting info: target -1.0968398309345835 is scalar
# Point registered successfully
# Probed target value: -1.0968398309345835
# Probing_barriers at point: index None, value {'x': array([-1.10905514]), 'y': array([-1.25510067])}
# Probed barrier_target values: [-1.44581543]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.202685      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 89: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.52934563]
#  [-1.86140678]]) = 0.18933817439053569
# Suggested point: index None, value {'x': array([-0.52934563]), 'y': array([-1.86140678])}, acquisition 0.18933817439053569
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.52934563]), 'y': array([-1.86140678])}
# Registering params [-0.52934563 -1.86140678] with index None and target value -0.009232789186066737
# Extracting info: target -0.009232789186066737 is scalar
# Point registered successfully
# Probed target value: -0.009232789186066737
# Probing_barriers at point: index None, value {'x': array([-0.52934563]), 'y': array([-1.86140678])}
# Probed barrier_target values: [-1.55475585]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.189338      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 90: suggesting new point
# End of acq_max(): maximizer of utility is ac([[0.5901154 ]
#  [0.39327342]]) = 0.1935652288655449
# Suggested point: index None, value {'x': array([0.5901154]), 'y': array([0.39327342])}, acquisition 0.1935652288655449
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.5901154]), 'y': array([0.39327342])}
# Registering params [0.5901154  0.39327342] with index None and target value 1.4527275102730464
# Extracting info: target 1.4527275102730464 is scalar
# Point registered successfully
# Probed target value: 1.4527275102730464
# Probing_barriers at point: index None, value {'x': array([0.5901154]), 'y': array([0.39327342])}
# Probed barrier_target values: [-4.9398903]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.193565      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 91: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.17939873]
#  [-1.74732705]]) = 0.5022116114041214
# Suggested point: index None, value {'x': array([-1.17939873]), 'y': array([-1.74732705])}, acquisition 0.5022116114041214
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.17939873]), 'y': array([-1.74732705])}
# Registering params [-1.17939873 -1.74732705] with index None and target value -0.6104358911923193
# Extracting info: target -0.6104358911923193 is scalar
# Point registered successfully
# Probed target value: -0.6104358911923193
# Probing_barriers at point: index None, value {'x': array([-1.17939873]), 'y': array([-1.74732705])}
# Probed barrier_target values: [-0.07275831]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.502212      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 92: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 1.19053359]
#  [-1.1199639 ]]) = 0.14097868669759797
# Suggested point: index None, value {'x': array([1.19053359]), 'y': array([-1.1199639])}, acquisition 0.14097868669759797
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.19053359]), 'y': array([-1.1199639])}
# Registering params [ 1.19053359 -1.1199639 ] with index None and target value 0.8749954299156237
# Extracting info: target 0.8749954299156237 is scalar
# Point registered successfully
# Probed target value: 0.8749954299156237
# Probing_barriers at point: index None, value {'x': array([1.19053359]), 'y': array([-1.1199639])}
# Probed barrier_target values: [-1.43283991]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.140979      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 93: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.00589142]
#  [ 1.59810039]]) = 51.30462716900048
# Suggested point: index None, value {'x': array([-1.00589142]), 'y': array([1.59810039])}, acquisition 51.30462716900048
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.00589142]), 'y': array([1.59810039])}
# Registering params [-1.00589142  1.59810039] with index None and target value 1.0325408561430964
# Extracting info: target 1.0325408561430964 is scalar
# Point registered successfully
# Probed target value: 1.0325408561430964
# Probing_barriers at point: index None, value {'x': array([-1.00589142]), 'y': array([1.59810039])}
# Probed barrier_target values: [-0.07579632]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None    51.304627      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 94: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.56207454]
#  [-0.33779869]]) = 0.13340498171342402
# Suggested point: index None, value {'x': array([-1.56207454]), 'y': array([-0.33779869])}, acquisition 0.13340498171342402
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.56207454]), 'y': array([-0.33779869])}
# Registering params [-1.56207454 -0.33779869] with index None and target value -0.7702974894948386
# Extracting info: target -0.7702974894948386 is scalar
# Point registered successfully
# Probed target value: -0.7702974894948386
# Probing_barriers at point: index None, value {'x': array([-1.56207454]), 'y': array([-0.33779869])}
# Probed barrier_target values: [-1.3066391]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.133405      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 95: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.084951  ]
#  [-2.02321366]]) = 0.16846133160416132
# Suggested point: index None, value {'x': array([-0.084951]), 'y': array([-2.02321366])}, acquisition 0.16846133160416132
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.084951]), 'y': array([-2.02321366])}
# Registering params [-0.084951   -2.02321366] with index None and target value 0.9309669290849502
# Extracting info: target 0.9309669290849502 is scalar
# Point registered successfully
# Probed target value: 0.9309669290849502
# Probing_barriers at point: index None, value {'x': array([-0.084951]), 'y': array([-2.02321366])}
# Probed barrier_target values: [-1.5313953]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.168461      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 96: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.13816219]
#  [-0.97490096]]) = 0.14157177001845328
# Suggested point: index None, value {'x': array([0.13816219]), 'y': array([-0.97490096])}, acquisition 0.14157177001845328
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.13816219]), 'y': array([-0.97490096])}
# Registering params [ 0.13816219 -0.97490096] with index None and target value 0.925178125984588
# Extracting info: target 0.925178125984588 is scalar
# Point registered successfully
# Probed target value: 0.925178125984588
# Probing_barriers at point: index None, value {'x': array([0.13816219]), 'y': array([-0.97490096])}
# Probed barrier_target values: [-4.57636992]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.141572      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 97: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-1.28050748]
#  [ 0.47191894]]) = 0.15394285630409874
# Suggested point: index None, value {'x': array([-1.28050748]), 'y': array([0.47191894])}, acquisition 0.15394285630409874
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-1.28050748]), 'y': array([0.47191894])}
# Registering params [-1.28050748  0.47191894] with index None and target value 0.3428691313755661
# Extracting info: target 0.3428691313755661 is scalar
# Point registered successfully
# Probed target value: 0.3428691313755661
# Probing_barriers at point: index None, value {'x': array([-1.28050748]), 'y': array([0.47191894])}
# Probed barrier_target values: [-3.27295961]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.153943      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 98: suggesting new point
# End of acq_max(): maximizer of utility is ac([[1.0023227 ]
#  [1.03489553]]) = 0.12479205126152369
# Suggested point: index None, value {'x': array([1.0023227]), 'y': array([1.03489553])}, acquisition 0.12479205126152369
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([1.0023227]), 'y': array([1.03489553])}
# Registering params [1.0023227  1.03489553] with index None and target value -0.4315570119523107
# Extracting info: target -0.4315570119523107 is scalar
# Point registered successfully
# Probed target value: -0.4315570119523107
# Probing_barriers at point: index None, value {'x': array([1.0023227]), 'y': array([1.03489553])}
# Probed barrier_target values: [-2.7964812]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.124792      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 99: suggesting new point
# End of acq_max(): maximizer of utility is ac([[-0.32740386]
#  [ 1.28851407]]) = 3.6684484778968467
# Suggested point: index None, value {'x': array([-0.32740386]), 'y': array([1.28851407])}, acquisition 3.6684484778968467
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([-0.32740386]), 'y': array([1.28851407])}
# Registering params [-0.32740386  1.28851407] with index None and target value 0.6274360055491377
# Extracting info: target 0.6274360055491377 is scalar
# Point registered successfully
# Probed target value: 0.6274360055491377
# Probing_barriers at point: index None, value {'x': array([-0.32740386]), 'y': array([1.28851407])}
# Probed barrier_target values: [-0.03139028]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     3.668448      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# max: {'target': 1.5905768955239465, 'params': {'x': 0.6551989901561868, 'y': 0.0503147738754679}}
# Results successfully saved to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# =================================================

# %%
# TOWNSEND
resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)

mask = np.where(resultsdf['target'] <= 2.002)[0]
x_iter = resultsdf['x']#.iloc[mask]
y_iter = resultsdf['y']#.iloc[mask]
# plt.hist(x_iter)
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'],first50['y'],s = 10, color = 'red')
