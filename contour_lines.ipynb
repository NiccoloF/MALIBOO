# %%
from maliboo import BayesianOptimization, UtilityFunction
import numpy as np
import os

import matplotlib.pyplot as plt
from matplotlib import gridspec

import pandas as pd
import time
# %matplotlib inline

# %%
# Townsend
def target(x,y):
    return -(-np.cos((x-0.1)*y)**2-x*np.sin(3*x+y))

# %%
def constraint(x,y):
    return x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2

# %%
ninit = 10
resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)

mask = np.where(resultsdf['target'] <= 2.002)[0]
x_iter = resultsdf['x']#.iloc[mask]
y_iter = resultsdf['y']#.iloc[mask]
plt.hist(x_iter)
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'],first50['y'],s = 10, color = 'red')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 ninit = 10
# ----> 2 resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
#       3 first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
#       4 resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)
#
# File ~/miniconda3/envs/bima/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/bima/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniconda3/envs/bima/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/bima/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniconda3/envs/bima/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results.csv'

# %% [markdown]
# # Converging case (acq = 'eb', 1/sigma)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27222
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    #optimizer.maximize(init_points=50, n_iter=120,acq='eb',acq_info={'static_lambda':False})
    optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})
# Out:
# Initializing TargetSpace with bounds: {'x': (-2.25, 2.5), 'y': (-2.5, 1.75)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 50 random points
# Uniform randomly sampled point: value [[0.55620501 0.73315315]]
# Uniform randomly sampled point: value [[0.79187646 1.01577063]]
# Uniform randomly sampled point: value [[-0.44670471 -1.92330102]]
# Uniform randomly sampled point: value [[-1.60092079 -0.77789777]]
# Uniform randomly sampled point: value [[1.30657698 1.12465506]]
# Uniform randomly sampled point: value [[-0.40496934 -0.98031718]]
# Uniform randomly sampled point: value [[ 0.75005114 -2.04030843]]
# Uniform randomly sampled point: value [[2.34178487 0.48838346]]
# Uniform randomly sampled point: value [[0.06698838 1.62149772]]
# Uniform randomly sampled point: value [[ 0.19519877 -0.48737969]]
# Uniform randomly sampled point: value [[1.83885518 0.46645768]]
# Uniform randomly sampled point: value [[ 1.77601853 -0.95742703]]
# Uniform randomly sampled point: value [[ 2.07253517 -0.60072736]]
# Uniform randomly sampled point: value [[-0.68227748 -1.90388142]]
# Uniform randomly sampled point: value [[-0.24226074 -0.82380744]]
# Uniform randomly sampled point: value [[0.68696793 0.62364103]]
# Uniform randomly sampled point: value [[2.21323655 1.44302382]]
# Uniform randomly sampled point: value [[-1.41907893 -1.08780578]]
# Uniform randomly sampled point: value [[1.98576124 0.38984198]]
# Uniform randomly sampled point: value [[ 1.06617535 -0.33380016]]
# Uniform randomly sampled point: value [[-0.10338771  0.70725363]]
# Uniform randomly sampled point: value [[-1.03570844 -0.43091935]]
# Uniform randomly sampled point: value [[ 1.55590522 -1.58915231]]
# Uniform randomly sampled point: value [[1.14410751 1.69112899]]
# Uniform randomly sampled point: value [[ 1.70703261 -0.1246026 ]]
# Uniform randomly sampled point: value [[0.96690333 0.05379501]]
# Uniform randomly sampled point: value [[-2.14096418 -1.30714124]]
# Uniform randomly sampled point: value [[-2.0059081  -2.12041038]]
# Uniform randomly sampled point: value [[ 1.52487496 -1.70032748]]
# Uniform randomly sampled point: value [[-1.7876779  -0.07993499]]
# Uniform randomly sampled point: value [[-0.31543875 -1.50737943]]
# Uniform randomly sampled point: value [[-1.88739811 -2.42756395]]
# Uniform randomly sampled point: value [[-1.01222346  0.21098874]]
# Uniform randomly sampled point: value [[ 2.26959635 -2.27076825]]
# Uniform randomly sampled point: value [[-0.74179536  1.33964459]]
# Uniform randomly sampled point: value [[ 1.18978092 -0.23627108]]
# Uniform randomly sampled point: value [[-0.04871926 -2.3870583 ]]
# Uniform randomly sampled point: value [[-1.35599272  0.84319487]]
# Uniform randomly sampled point: value [[-1.75618808 -1.76050843]]
# Uniform randomly sampled point: value [[-2.19650719 -1.34788528]]
# Uniform randomly sampled point: value [[ 1.43143794 -2.22220564]]
# Uniform randomly sampled point: value [[-0.60952123  1.54761719]]
# Uniform randomly sampled point: value [[-1.57308485 -1.1861155 ]]
# Uniform randomly sampled point: value [[ 0.41109176 -1.43524171]]
# Uniform randomly sampled point: value [[ 2.43208371 -0.70641736]]
# Uniform randomly sampled point: value [[-1.19167663  0.24403619]]
# Uniform randomly sampled point: value [[-1.26004159  1.31209453]]
# Uniform randomly sampled point: value [[0.28752113 0.95963659]]
# Uniform randomly sampled point: value [[0.33763242 1.20997698]]
# Uniform randomly sampled point: value [[-0.84964371  0.01938233]]
# Initializing UtilityFunction of kind 'eic_bm' with acq_info = {'static_lambda': True, 'lam': 10}
# Using default eic_P_func, P(x) == 1
# Using default eic_Q_func, Q(x) == 0
# Setting 'eic_P_func' field of acq_info to 'eic_P_func' member
# Setting 'eic_Q_func' field of acq_info to 'eic_Q_func' member
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': 0.5562050050715497, 'y': 0.7331531494546879}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.5562050050715497, 'y': 0.7331531494546879}
# Registering params [0.55620501 0.73315315] with index None and target value 1.2672111072037846
# Extracting info: target 1.2672111072037846 is scalar
# Point registered successfully
# Probed target value: 1.2672111072037846
# Probing_barriers at point: index None, value {'x': 0.5562050050715497, 'y': 0.7331531494546879}
# Probed barrier_target values: [-3.36120965]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.7918764613844362, 'y': 1.0157706256237558}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7918764613844362, 'y': 1.0157706256237558}
# Registering params [0.79187646 1.01577063] with index None and target value 0.38646948128473535
# Extracting info: target 0.38646948128473535 is scalar
# Point registered successfully
# Probed target value: 0.38646948128473535
# Probing_barriers at point: index None, value {'x': 0.7918764613844362, 'y': 1.0157706256237558}
# Probed barrier_target values: [-2.6301235]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.4467047069908139, 'y': -1.9233010191740938}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.4467047069908139, 'y': -1.9233010191740938}
# Registering params [-0.44670471 -1.92330102] with index None and target value 0.19201829413675536
# Extracting info: target 0.19201829413675536 is scalar
# Point registered successfully
# Probed target value: 0.19201829413675536
# Probing_barriers at point: index None, value {'x': -0.4467047069908139, 'y': -1.9233010191740938}
# Probed barrier_target values: [-1.50329613]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.6009207931590077, 'y': -0.7778977734643528}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.6009207931590077, 'y': -0.7778977734643528}
# Registering params [-1.60092079 -0.77789777] with index None and target value -0.9743413894372147
# Extracting info: target -0.9743413894372147 is scalar
# Point registered successfully
# Probed target value: -0.9743413894372147
# Probing_barriers at point: index None, value {'x': -1.6009207931590077, 'y': -0.7778977734643528}
# Probed barrier_target values: [-0.67610463]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.3065769788781059, 'y': 1.1246550638390818}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.3065769788781059, 'y': 1.1246550638390818}
# Registering params [1.30657698 1.12465506] with index None and target value -1.1902054163343374
# Extracting info: target -1.1902054163343374 is scalar
# Point registered successfully
# Probed target value: -1.1902054163343374
# Probing_barriers at point: index None, value {'x': 1.3065769788781059, 'y': 1.1246550638390818}
# Probed barrier_target values: [-2.25061942]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.4049693382296493, 'y': -0.9803171801193875}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.4049693382296493, 'y': -0.9803171801193875}
# Registering params [-0.40496934 -0.98031718] with index None and target value 1.1028702225774092
# Extracting info: target 1.1028702225774092 is scalar
# Point registered successfully
# Probed target value: 1.1028702225774092
# Probing_barriers at point: index None, value {'x': -0.4049693382296493, 'y': -0.9803171801193875}
# Probed barrier_target values: [-3.89692417]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.7500511398592087, 'y': -2.0403084348938734}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7500511398592087, 'y': -2.0403084348938734}
# Registering params [ 0.75005114 -2.04030843] with index None and target value 0.21483635557546704
# Extracting info: target 0.21483635557546704 is scalar
# Point registered successfully
# Probed target value: 0.21483635557546704
# Probing_barriers at point: index None, value {'x': 0.7500511398592087, 'y': -2.0403084348938734}
# Probed barrier_target values: [-0.39625868]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 2.341784866677294, 'y': 0.4883834601286381}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.341784866677294, 'y': 0.4883834601286381}
# Registering params [2.34178487 0.48838346] with index None and target value 2.4174665261775563
# Extracting info: target 2.4174665261775563 is scalar
# Point registered successfully
# Probed target value: 2.4174665261775563
# Probing_barriers at point: index None, value {'x': 2.341784866677294, 'y': 0.4883834601286381}
# Probed barrier_target values: [1.03136895]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.06698838269220708, 'y': 1.621497719114151}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.06698838269220708, 'y': 1.621497719114151}
# Registering params [0.06698838 1.62149772] with index None and target value 1.0620156267916454
# Extracting info: target 1.0620156267916454 is scalar
# Point registered successfully
# Probed target value: 1.0620156267916454
# Probing_barriers at point: index None, value {'x': 0.06698838269220708, 'y': 1.621497719114151}
# Probed barrier_target values: [1.35315371]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.19519876656733448, 'y': -0.48737969058856345}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.19519876656733448, 'y': -0.48737969058856345}
# Registering params [ 0.19519877 -0.48737969] with index None and target value 1.016989727437956
# Extracting info: target 1.016989727437956 is scalar
# Point registered successfully
# Probed target value: 1.016989727437956
# Probing_barriers at point: index None, value {'x': 0.19519876656733448, 'y': -0.48737969058856345}
# Probed barrier_target values: [-4.77387955]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.838855175553979, 'y': 0.4664576820880115}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.838855175553979, 'y': 0.4664576820880115}
# Registering params [1.83885518 0.46645768] with index None and target value -0.06939648763703216
# Extracting info: target -0.06939648763703216 is scalar
# Point registered successfully
# Probed target value: -0.06939648763703216
# Probing_barriers at point: index None, value {'x': 1.838855175553979, 'y': 0.4664576820880115}
# Probed barrier_target values: [-1.22556633]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.7760185283664045, 'y': -0.9574270279106929}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.7760185283664045, 'y': -0.9574270279106929}
# Registering params [ 1.77601853 -0.95742703] with index None and target value -1.672157819444706
# Extracting info: target -1.672157819444706 is scalar
# Point registered successfully
# Probed target value: -1.672157819444706
# Probing_barriers at point: index None, value {'x': 1.7760185283664045, 'y': -0.9574270279106929}
# Probed barrier_target values: [0.20808352]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 2.0725351666302263, 'y': -0.6007273611756854}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.0725351666302263, 'y': -0.6007273611756854}
# Registering params [ 2.07253517 -0.60072736] with index None and target value -1.1393772762035022
# Extracting info: target -1.1393772762035022 is scalar
# Point registered successfully
# Probed target value: -1.1393772762035022
# Probing_barriers at point: index None, value {'x': 2.0725351666302263, 'y': -0.6007273611756854}
# Probed barrier_target values: [0.82565258]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.682277481735351, 'y': -1.9038814170654283}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.682277481735351, 'y': -1.9038814170654283}
# Registering params [-0.68227748 -1.90388142] with index None and target value -0.4871345791156846
# Extracting info: target -0.4871345791156846 is scalar
# Point registered successfully
# Probed target value: -0.4871345791156846
# Probing_barriers at point: index None, value {'x': -0.682277481735351, 'y': -1.9038814170654283}
# Probed barrier_target values: [-1.0516883]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.24226073533423742, 'y': -0.823807435764996}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.24226073533423742, 'y': -0.823807435764996}
# Registering params [-0.24226074 -0.82380744] with index None and target value 1.1647960929227361
# Extracting info: target 1.1647960929227361 is scalar
# Point registered successfully
# Probed target value: 1.1647960929227361
# Probing_barriers at point: index None, value {'x': -0.24226073533423742, 'y': -0.823807435764996}
# Probed barrier_target values: [-4.54241408]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.6869679297417295, 'y': 0.6236410321908332}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6869679297417295, 'y': 0.6236410321908332}
# Registering params [0.68696793 0.62364103] with index None and target value 1.175040848224393
# Extracting info: target 1.175040848224393 is scalar
# Point registered successfully
# Probed target value: 1.175040848224393
# Probing_barriers at point: index None, value {'x': 0.6869679297417295, 'y': 0.6236410321908332}
# Probed barrier_target values: [-4.27537715]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 2.2132365451519647, 'y': 1.4430238190382578}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.2132365451519647, 'y': 1.4430238190382578}
# Registering params [2.21323655 1.44302382] with index None and target value 3.1471160162315313
# Extracting info: target 3.1471160162315313 is scalar
# Point registered successfully
# Probed target value: 3.1471160162315313
# Probing_barriers at point: index None, value {'x': 2.2132365451519647, 'y': 1.4430238190382578}
# Probed barrier_target values: [1.53311699]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.4190789329226368, 'y': -1.0878057758358726}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.4190789329226368, 'y': -1.0878057758358726}
# Registering params [-1.41907893 -1.08780578] with index None and target value -1.1377776560601482
# Extracting info: target -1.1377776560601482 is scalar
# Point registered successfully
# Probed target value: -1.1377776560601482
# Probing_barriers at point: index None, value {'x': -1.4190789329226368, 'y': -1.0878057758358726}
# Probed barrier_target values: [-0.7861486]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.9857612438939904, 'y': 0.38984197858910674}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.9857612438939904, 'y': 0.38984197858910674}
# Registering params [1.98576124 0.38984198] with index None and target value 0.6770486007096268
# Extracting info: target 0.6770486007096268 is scalar
# Point registered successfully
# Probed target value: 0.6770486007096268
# Probing_barriers at point: index None, value {'x': 1.9857612438939904, 'y': 0.38984197858910674}
# Probed barrier_target values: [-0.55957466]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.066175354642605, 'y': -0.3338001564775741}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.066175354642605, 'y': -0.3338001564775741}
# Registering params [ 1.06617535 -0.33380016] with index None and target value 1.1909758219454054
# Extracting info: target 1.1909758219454054 is scalar
# Point registered successfully
# Probed target value: 1.1909758219454054
# Probing_barriers at point: index None, value {'x': 1.066175354642605, 'y': -0.3338001564775741}
# Probed barrier_target values: [-2.57790392]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.10338770898613925, 'y': 0.7072536321077347}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.10338770898613925, 'y': 0.7072536321077347}
# Registering params [-0.10338771  0.70725363] with index None and target value 0.9394666132146061
# Extracting info: target 0.9394666132146061 is scalar
# Point registered successfully
# Probed target value: 0.9394666132146061
# Probing_barriers at point: index None, value {'x': -0.10338770898613925, 'y': 0.7072536321077347}
# Probed barrier_target values: [-0.93866267]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.035708435587928, 'y': -0.4309193497735131}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.035708435587928, 'y': -0.4309193497735131}
# Registering params [-1.03570844 -0.43091935] with index None and target value 0.37907369968123467
# Extracting info: target 0.37907369968123467 is scalar
# Point registered successfully
# Probed target value: 0.37907369968123467
# Probing_barriers at point: index None, value {'x': -1.035708435587928, 'y': -0.4309193497735131}
# Probed barrier_target values: [-2.56929223]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.5559052156450206, 'y': -1.589152309800804}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.5559052156450206, 'y': -1.589152309800804}
# Registering params [ 1.55590522 -1.58915231] with index None and target value 0.5555146698856651
# Extracting info: target 0.5555146698856651 is scalar
# Point registered successfully
# Probed target value: 0.5555146698856651
# Probing_barriers at point: index None, value {'x': 1.5559052156450206, 'y': -1.589152309800804}
# Probed barrier_target values: [0.78078149]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.144107509959615, 'y': 1.6911289886211405}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.144107509959615, 'y': 1.6911289886211405}
# Registering params [1.14410751 1.69112899] with index None and target value -1.0112830178432268
# Extracting info: target -1.0112830178432268 is scalar
# Point registered successfully
# Probed target value: -1.0112830178432268
# Probing_barriers at point: index None, value {'x': 1.144107509959615, 'y': 1.6911289886211405}
# Probed barrier_target values: [0.30826846]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.7070326057550949, 'y': -0.12460260281699487}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.7070326057550949, 'y': -0.12460260281699487}
# Registering params [ 1.70703261 -0.1246026 ] with index None and target value -0.6781652257856428
# Extracting info: target -0.6781652257856428 is scalar
# Point registered successfully
# Probed target value: -0.6781652257856428
# Probing_barriers at point: index None, value {'x': 1.7070326057550949, 'y': -0.12460260281699487}
# Probed barrier_target values: [-1.07999474]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.9669033285859188, 'y': 0.053795011286549954}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9669033285859188, 'y': 0.053795011286549954}
# Registering params [0.96690333 0.05379501] with index None and target value 1.1776689903658033
# Extracting info: target 1.1776689903658033 is scalar
# Point registered successfully
# Probed target value: 1.1776689903658033
# Probing_barriers at point: index None, value {'x': 0.9669033285859188, 'y': 0.053795011286549954}
# Probed barrier_target values: [-3.32820432]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -2.140964175657382, 'y': -1.3071412391353912}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.140964175657382, 'y': -1.3071412391353912}
# Registering params [-2.14096418 -1.30714124] with index None and target value 3.080126301707284
# Extracting info: target 3.080126301707284 is scalar
# Point registered successfully
# Probed target value: 3.080126301707284
# Probing_barriers at point: index None, value {'x': -2.140964175657382, 'y': -1.3071412391353912}
# Probed barrier_target values: [2.39791717]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -2.005908097494997, 'y': -2.1204103815473587}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.005908097494997, 'y': -2.1204103815473587}
# Registering params [-2.0059081  -2.12041038] with index None and target value 1.9852482083896708
# Extracting info: target 1.9852482083896708 is scalar
# Point registered successfully
# Probed target value: 1.9852482083896708
# Probing_barriers at point: index None, value {'x': -2.005908097494997, 'y': -2.1204103815473587}
# Probed barrier_target values: [4.32680886]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.5248749638962331, 'y': -1.7003274801844173}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.5248749638962331, 'y': -1.7003274801844173}
# Registering params [ 1.52487496 -1.70032748] with index None and target value 0.9691187737541641
# Extracting info: target 0.9691187737541641 is scalar
# Point registered successfully
# Probed target value: 0.9691187737541641
# Probing_barriers at point: index None, value {'x': 1.5248749638962331, 'y': -1.7003274801844173}
# Probed barrier_target values: [0.97824841]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.7876778963617803, 'y': -0.07993499336218379}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.7876778963617803, 'y': -0.07993499336218379}
# Registering params [-1.7876779  -0.07993499] with index None and target value -0.35403647030980856
# Extracting info: target -0.35403647030980856 is scalar
# Point registered successfully
# Probed target value: -0.35403647030980856
# Probing_barriers at point: index None, value {'x': -1.7876778963617803, 'y': -0.07993499336218379}
# Probed barrier_target values: [-0.85346322]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.3154387546177302, 'y': -1.5073794298018761}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.3154387546177302, 'y': -1.5073794298018761}
# Registering params [-0.31543875 -1.50737943] with index None and target value 0.8567757342746812
# Extracting info: target 0.8567757342746812 is scalar
# Point registered successfully
# Probed target value: 0.8567757342746812
# Probing_barriers at point: index None, value {'x': -0.3154387546177302, 'y': -1.5073794298018761}
# Probed barrier_target values: [-3.07147507]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.8873981087352183, 'y': -2.427563952925199}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.8873981087352183, 'y': -2.427563952925199}
# Registering params [-1.88739811 -2.42756395] with index None and target value 1.847704182506454
# Extracting info: target 1.847704182506454 is scalar
# Point registered successfully
# Probed target value: 1.847704182506454
# Probing_barriers at point: index None, value {'x': -1.8873981087352183, 'y': -2.427563952925199}
# Probed barrier_target values: [5.08401798]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.0122234615025967, 'y': 0.21098873903472093}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.0122234615025967, 'y': 0.21098873903472093}
# Registering params [-1.01222346  0.21098874] with index None and target value 1.2604151673178006
# Extracting info: target 1.2604151673178006 is scalar
# Point registered successfully
# Probed target value: 1.2604151673178006
# Probing_barriers at point: index None, value {'x': -1.0122234615025967, 'y': 0.21098873903472093}
# Probed barrier_target values: [-3.62166373]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 2.2695963532286747, 'y': -2.270768247356941}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.2695963532286747, 'y': -2.270768247356941}
# Registering params [ 2.26959635 -2.27076825] with index None and target value -2.1899712135784277
# Extracting info: target -2.1899712135784277 is scalar
# Point registered successfully
# Probed target value: -2.1899712135784277
# Probing_barriers at point: index None, value {'x': 2.2695963532286747, 'y': -2.270768247356941}
# Probed barrier_target values: [6.15793524]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.7417953608622905, 'y': 1.339644591937128}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.7417953608622905, 'y': 1.339644591937128}
# Registering params [-0.74179536  1.33964459] with index None and target value 0.7582465859766825
# Extracting info: target 0.7582465859766825 is scalar
# Point registered successfully
# Probed target value: 0.7582465859766825
# Probing_barriers at point: index None, value {'x': -0.7417953608622905, 'y': 1.339644591937128}
# Probed barrier_target values: [-0.9209238]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.1897809175563192, 'y': -0.2362710783076154}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.1897809175563192, 'y': -0.2362710783076154}
# Registering params [ 1.18978092 -0.23627108] with index None and target value 0.7087258767665657
# Extracting info: target 0.7087258767665657 is scalar
# Point registered successfully
# Probed target value: 0.7087258767665657
# Probing_barriers at point: index None, value {'x': 1.1897809175563192, 'y': -0.2362710783076154}
# Probed barrier_target values: [-2.40077062]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.04871925851444514, 'y': -2.387058301836287}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.04871925851444514, 'y': -2.387058301836287}
# Registering params [-0.04871926 -2.3870583 ] with index None and target value 0.907024747256161
# Extracting info: target 0.907024747256161 is scalar
# Point registered successfully
# Probed target value: 0.907024747256161
# Probing_barriers at point: index None, value {'x': -0.04871925851444514, 'y': -2.387058301836287}
# Probed barrier_target values: [0.06183795]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.3559927156889482, 'y': 0.8431948651508798}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.3559927156889482, 'y': 0.8431948651508798}
# Registering params [-1.35599272  0.84319487] with index None and target value 0.0005013517913763643
# Extracting info: target 0.0005013517913763643 is scalar
# Point registered successfully
# Probed target value: 0.0005013517913763643
# Probing_barriers at point: index None, value {'x': -1.3559927156889482, 'y': 0.8431948651508798}
# Probed barrier_target values: [-2.90183663]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.756188078229571, 'y': -1.7605084312081711}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.756188078229571, 'y': -1.7605084312081711}
# Registering params [-1.75618808 -1.76050843] with index None and target value 2.1759384938952078
# Extracting info: target 2.1759384938952078 is scalar
# Point registered successfully
# Probed target value: 2.1759384938952078
# Probing_barriers at point: index None, value {'x': -1.756188078229571, 'y': -1.7605084312081711}
# Probed barrier_target values: [2.03258426]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -2.1965071852474076, 'y': -1.347885278860568}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -2.1965071852474076, 'y': -1.347885278860568}
# Registering params [-2.19650719 -1.34788528] with index None and target value 3.186738390722263
# Extracting info: target 3.186738390722263 is scalar
# Point registered successfully
# Probed target value: 3.186738390722263
# Probing_barriers at point: index None, value {'x': -2.1965071852474076, 'y': -1.347885278860568}
# Probed barrier_target values: [2.74548548]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 1.4314379434046662, 'y': -2.2222056444829916}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 1.4314379434046662, 'y': -2.2222056444829916}
# Registering params [ 1.43143794 -2.22220564] with index None and target value 2.222235530280085
# Extracting info: target 2.222235530280085 is scalar
# Point registered successfully
# Probed target value: 2.222235530280085
# Probing_barriers at point: index None, value {'x': 1.4314379434046662, 'y': -2.2222056444829916}
# Probed barrier_target values: [2.42042993]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -0.6095212330384452, 'y': 1.5476171901853046}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -0.6095212330384452, 'y': 1.5476171901853046}
# Registering params [-0.60952123  1.54761719] with index None and target value 0.3763132611777319
# Extracting info: target 0.3763132611777319 is scalar
# Point registered successfully
# Probed target value: 0.3763132611777319
# Probing_barriers at point: index None, value {'x': -0.6095212330384452, 'y': 1.5476171901853046}
# Probed barrier_target values: [0.32855347]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.5730848504861128, 'y': -1.1861154960063405}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.5730848504861128, 'y': -1.1861154960063405}
# Registering params [-1.57308485 -1.1861155 ] with index None and target value -0.41871041867097664
# Extracting info: target -0.41871041867097664 is scalar
# Point registered successfully
# Probed target value: -0.41871041867097664
# Probing_barriers at point: index None, value {'x': -1.5730848504861128, 'y': -1.1861154960063405}
# Probed barrier_target values: [-0.09382075]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 0.41109176073797427, 'y': -1.4352417123177181}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.41109176073797427, 'y': -1.4352417123177181}
# Registering params [ 0.41109176 -1.43524171] with index None and target value 0.7310818870907386
# Extracting info: target 0.7310818870907386 is scalar
# Point registered successfully
# Probed target value: 0.7310818870907386
# Probing_barriers at point: index None, value {'x': 0.41109176073797427, 'y': -1.4352417123177181}
# Probed barrier_target values: [-3.06667384]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': 2.4320837128510195, 'y': -0.7064173596512531}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 2.4320837128510195, 'y': -0.7064173596512531}
# Registering params [ 2.43208371 -0.70641736] with index None and target value 0.7400217104579755
# Extracting info: target 0.7400217104579755 is scalar
# Point registered successfully
# Probed target value: 0.7400217104579755
# Probing_barriers at point: index None, value {'x': 2.4320837128510195, 'y': -0.7064173596512531}
# Probed barrier_target values: [2.58358041]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.19167663424421, 'y': 0.2440361892777969}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.19167663424421, 'y': 0.2440361892777969}
# Registering params [-1.19167663  0.24403619] with index None and target value 0.6795287600162878
# Extracting info: target 0.6795287600162878 is scalar
# Point registered successfully
# Probed target value: 0.6795287600162878
# Probing_barriers at point: index None, value {'x': -1.19167663424421, 'y': 0.2440361892777969}
# Probed barrier_target values: [-3.20026916]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration: selected point from queue, index None, value {'x': -1.2600415852480489, 'y': 1.3120945258518328}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': -1.2600415852480489, 'y': 1.3120945258518328}
# Registering params [-1.26004159  1.31209453] with index None and target value 0.8309611605580749
# Extracting info: target 0.8309611605580749 is scalar
# ...
# Registered optimization information:
#       acquisition terminated
# None     1.718221      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 106: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00198404]
#  [-0.25583275]]) = 1.718221419144903
# Suggested point: index None, value {'x': array([0.00198404]), 'y': array([-0.25583275])}, acquisition 1.718221419144903
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00198404]), 'y': array([-0.25583275])}
# Registering params [ 0.00198404 -0.25583275] with index None and target value 0.9988807120474711
# Extracting info: target 0.9988807120474711 is scalar
# Point registered successfully
# Probed target value: 0.9988807120474711
# Probing_barriers at point: index None, value {'x': array([0.00198404]), 'y': array([-0.25583275])}
# Probed barrier_target values: [-5.57487562]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718221      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 107: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00197687]
#  [-0.25579973]]) = 1.7182221595079132
# Suggested point: index None, value {'x': array([0.00197687]), 'y': array([-0.25579973])}, acquisition 1.7182221595079132
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00197687]), 'y': array([-0.25579973])}
# Registering params [ 0.00197687 -0.25579973] with index None and target value 0.9988825770073663
# Extracting info: target 0.9988825770073663 is scalar
# Point registered successfully
# Probed target value: 0.9988825770073663
# Probing_barriers at point: index None, value {'x': array([0.00197687]), 'y': array([-0.25579973])}
# Probed barrier_target values: [-5.5748946]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718222      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 108: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00196833]
#  [-0.25575815]]) = 1.7182229535640257
# Suggested point: index None, value {'x': array([0.00196833]), 'y': array([-0.25575815])}, acquisition 1.7182229535640257
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00196833]), 'y': array([-0.25575815])}
# Registering params [ 0.00196833 -0.25575815] with index None and target value 0.9988848138343973
# Extracting info: target 0.9988848138343973 is scalar
# Point registered successfully
# Probed target value: 0.9988848138343973
# Probing_barriers at point: index None, value {'x': array([0.00196833]), 'y': array([-0.25575815])}
# Probed barrier_target values: [-5.57491834]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718223      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 109: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00195954]
#  [-0.25571096]]) = 1.718223821758628
# Suggested point: index None, value {'x': array([0.00195954]), 'y': array([-0.25571096])}, acquisition 1.718223821758628
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00195954]), 'y': array([-0.25571096])}
# Registering params [ 0.00195954 -0.25571096] with index None and target value 0.998887146451126
# Extracting info: target 0.998887146451126 is scalar
# Point registered successfully
# Probed target value: 0.998887146451126
# Probing_barriers at point: index None, value {'x': array([0.00195954]), 'y': array([-0.25571096])}
# Probed barrier_target values: [-5.57494499]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718224      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 110: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00194836]
#  [-0.25566232]]) = 1.7182247811077274
# Suggested point: index None, value {'x': array([0.00194836]), 'y': array([-0.25566232])}, acquisition 1.7182247811077274
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00194836]), 'y': array([-0.25566232])}
# Registering params [ 0.00194836 -0.25566232] with index None and target value 0.9988900338053299
# Extracting info: target 0.9988900338053299 is scalar
# Point registered successfully
# Probed target value: 0.9988900338053299
# Probing_barriers at point: index None, value {'x': array([0.00194836]), 'y': array([-0.25566232])}
# Probed barrier_target values: [-5.57497307]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718225      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 111: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00193448]
#  [-0.25560249]]) = 1.7182258455262909
# Suggested point: index None, value {'x': array([0.00193448]), 'y': array([-0.25560249])}, acquisition 1.7182258455262909
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00193448]), 'y': array([-0.25560249])}
# Registering params [ 0.00193448 -0.25560249] with index None and target value 0.9988936164633121
# Extracting info: target 0.9988936164633121 is scalar
# Point registered successfully
# Probed target value: 0.9988936164633121
# Probing_barriers at point: index None, value {'x': array([0.00193448]), 'y': array([-0.25560249])}
# Probed barrier_target values: [-5.57500763]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718226      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 112: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00191734]
#  [-0.2555326 ]]) = 1.718227054303173
# Suggested point: index None, value {'x': array([0.00191734]), 'y': array([-0.2555326])}, acquisition 1.718227054303173
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00191734]), 'y': array([-0.2555326])}
# Registering params [ 0.00191734 -0.2555326 ] with index None and target value 0.9988980127167467
# Extracting info: target 0.9988980127167467 is scalar
# Point registered successfully
# Probed target value: 0.9988980127167467
# Probing_barriers at point: index None, value {'x': array([0.00191734]), 'y': array([-0.2555326])}
# Probed barrier_target values: [-5.57504822]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718227      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 113: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00189679]
#  [-0.25545125]]) = 1.7182284549022737
# Suggested point: index None, value {'x': array([0.00189679]), 'y': array([-0.25545125])}, acquisition 1.7182284549022737
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00189679]), 'y': array([-0.25545125])}
# Registering params [ 0.00189679 -0.25545125] with index None and target value 0.9989032636471136
# Extracting info: target 0.9989032636471136 is scalar
# Point registered successfully
# Probed target value: 0.9989032636471136
# Probing_barriers at point: index None, value {'x': array([0.00189679]), 'y': array([-0.25545125])}
# Probed barrier_target values: [-5.57509558]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718228      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 114: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.0018719 ]
#  [-0.25535421]]) = 1.7182301127283848
# Suggested point: index None, value {'x': array([0.0018719]), 'y': array([-0.25535421])}, acquisition 1.7182301127283848
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.0018719]), 'y': array([-0.25535421])}
# Registering params [ 0.0018719  -0.25535421] with index None and target value 0.9989096155035303
# Extracting info: target 0.9989096155035303 is scalar
# Point registered successfully
# Probed target value: 0.9989096155035303
# Probing_barriers at point: index None, value {'x': array([0.0018719]), 'y': array([-0.25535421])}
# Probed barrier_target values: [-5.5751521]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None      1.71823      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 115: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00184022]
#  [-0.2552345 ]]) = 1.7182321300056922
# Suggested point: index None, value {'x': array([0.00184022]), 'y': array([-0.2552345])}, acquisition 1.7182321300056922
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00184022]), 'y': array([-0.2552345])}
# Registering params [ 0.00184022 -0.2552345 ] with index None and target value 0.9989176737040955
# Extracting info: target 0.9989176737040955 is scalar
# Point registered successfully
# Probed target value: 0.9989176737040955
# Probing_barriers at point: index None, value {'x': array([0.00184022]), 'y': array([-0.2552345])}
# Probed barrier_target values: [-5.57522195]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718232      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 116: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.0017993 ]
#  [-0.25508368]]) = 1.718234677904718
# Suggested point: index None, value {'x': array([0.0017993]), 'y': array([-0.25508368])}, acquisition 1.718234677904718
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.0017993]), 'y': array([-0.25508368])}
# Registering params [ 0.0017993  -0.25508368] with index None and target value 0.9989280526628664
# Extracting info: target 0.9989280526628664 is scalar
# Point registered successfully
# Probed target value: 0.9989280526628664
# Probing_barriers at point: index None, value {'x': array([0.0017993]), 'y': array([-0.25508368])}
# Probed barrier_target values: [-5.57530999]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718235      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 117: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00174798]
#  [-0.25489215]]) = 1.7182380473353134
# Suggested point: index None, value {'x': array([0.00174798]), 'y': array([-0.25489215])}, acquisition 1.7182380473353134
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00174798]), 'y': array([-0.25489215])}
# Registering params [ 0.00174798 -0.25489215] with index None and target value 0.998941084913676
# Extracting info: target 0.998941084913676 is scalar
# Point registered successfully
# Probed target value: 0.998941084913676
# Probing_barriers at point: index None, value {'x': array([0.00174798]), 'y': array([-0.25489215])}
# Probed barrier_target values: [-5.57542123]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718238      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 118: suggesting new point
# End of acq_max(): maximizer of utility is ac([[0.78734772]
#  [0.55879284]]) = 1.4988822767140746
# Suggested point: index None, value {'x': array([0.78734772]), 'y': array([0.55879284])}, acquisition 1.4988822767140746
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.78734772]), 'y': array([0.55879284])}
# Registering params [0.78734772 0.55879284] with index None and target value 1.031995643266702
# Extracting info: target 1.031995643266702 is scalar
# Point registered successfully
# Probed target value: 1.031995643266702
# Probing_barriers at point: index None, value {'x': array([0.78734772]), 'y': array([0.55879284])}
# Probed barrier_target values: [-4.48531885]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.498882      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# New iteration 119: suggesting new point
# End of acq_max(): maximizer of utility is ac([[ 0.00166741]
#  [-0.25464021]]) = 1.7182427105681244
# Suggested point: index None, value {'x': array([0.00166741]), 'y': array([-0.25464021])}, acquisition 1.7182427105681244
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': array([0.00166741]), 'y': array([-0.25464021])}
# Registering params [ 0.00166741 -0.25464021] with index None and target value 0.9989612198367338
# Extracting info: target 0.9989612198367338 is scalar
# Point registered successfully
# Probed target value: 0.9989612198367338
# Probing_barriers at point: index None, value {'x': array([0.00166741]), 'y': array([-0.25464021])}
# Probed barrier_target values: [-5.57557023]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     1.718243      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# max: {'target': 1.4878168241360838, 'params': {'x': -0.8496437081706785, 'y': 0.01938233176122317}}
# Results successfully saved to /Users/lucacaroselli/Desktop/STUDIO/Uni_Magistrale/Esami/Bayesiana/PROGETTO/MALIBOO-temp
# =================================================

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[:50]
results_df = results_df.iloc[50:].reset_index(drop = True)
# print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()

# %% [markdown]
# # (acq = 'eb', fixed gamma = 1e6)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27222
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=120,acq='eb',acq_info={'static_lambda':True, 'lam': 1e-6})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[:50]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')

plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()

# %%
print(len([x for x in x_iter if x < 0]))
# Out:
# 97

# %% [markdown]
# # (acq: 'eb', fixed gamma = 10)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27122
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=120,acq='eb',acq_info={'static_lambda':True, 'lam': 1e-1})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[50:]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')

plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()

# %% [markdown]
# # (acq = eic_bm, gamma = 10)

# %%
import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# with these values it converges seed = 27122
optimizer = BayesianOptimization(target, {'x': (-2.25,2.5),'y': (-2.5,1.75)}, 
                                 random_state=27222,
                                 barrier_func={'constraint1': lambda x,y: x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2},
                                 debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=50, n_iter=200,acq='eic_bm',acq_info={'static_lambda':True, 'lam': 1e-1})
    # optimizer.maximize(init_points=50, n_iter=120,acq='eic_bm',acq_info={'static_lambda':True, 'lam':10})

# %%
results_df = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = results_df.iloc[50:]
results_df = results_df.iloc[50:].reset_index(drop = True)
print(f'first occurrence of maximum at iteration: {np.where(results_df['target'] == optimizer.max['target'])[0][0]}')
valid_mask = np.where(results_df['target'] <= optimizer.max['target'])[0]
x_iter = results_df['x'].iloc[valid_mask]
y_iter = results_df['y'].iloc[valid_mask]

sampled = [x_iter, y_iter]
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = target(X, Y)
Z_constraint = constraint(X, Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(2.0052938, 1.1944509, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'], first50['y'], s = 10, color = 'red')

plt.xlabel('x')
plt.ylabel('y')
plt.title('(constrained) Townsend contour levels')
plt.show()
