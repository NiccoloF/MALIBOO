# %% [markdown]
# # Gramacy

# %%
from maliboo import BayesianOptimization, UtilityFunction
import numpy as np
import os

import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

import pandas as pd
import time

import warnings

# %%
ninit = 10

# %%
def gramacy(x,y):
    return -(x+y)

# %%
# Gramacy
def target(x,y):
    return -(x + y)

# %%
def constraint1(x,y):
    return 3/2 -x-2*y - 1/2*np.sin(2*np.pi*(x**2 - 2*y))
    #return x**2+y**2-(2*np.cos(np.arctan2(x,y))-0.5*np.cos(2*np.arctan2(x,y))-0.25*np.cos(3*np.arctan2(x,y))-0.125*np.cos(4*np.arctan2(x,y)))**2-(2*np.sin(np.arctan2(x,y)))**2

# %%
def constraint2(x,y):
    return x**2 + y**2 - 3/2

# %%
ninit = 10

# %%
### INITIALIZE SOME FUNCTIONS AND PERFORM THE OPTIMIZATION


import warnings
def posterior(optimizer, x_obs, y_obs, grid):
    optimizer._gp.fit(x_obs, y_obs)
    mu, sigma = optimizer._gp.predict(grid, return_std=True)
    return mu, sigma

def plot_gp(optimizer, x, y, show_minimized=False, style='transparent'):

    if style == 'classic':
        plt.style.use(style)
    elif style == 'dark':
        plt.style.use('dark_background')
    elif style == 'transparent':
        pass
    else:
        raise ValueError("Wrong style")

    # Swap sign of stuff
    sign = -1 if show_minimized else 1
    
    # Set up complete plot
    plt.rcParams.update({'font.size': 20})

    fig = plt.figure(figsize=(16, 10))
    steps = len(optimizer.space)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])

    ## MAIN PLOT
    # Plot true objective
    target_col = 'limegreen' if style == 'dark' else 'gray'
    axis.plot(x, sign*y, linewidth=3.5, label='objective function',
              color=target_col)
    # Plot observations
    x_obs = np.array([[res["x"]] for res in optimizer.res])
    y_obs = np.array([res["target"] for res in optimizer.res])
    axis.scatter(x_obs, sign*y_obs, marker='o', s=300,
                 label='observations', color='red', zorder=10)   
    # Plot mean function
    mu, sigma = posterior(optimizer, x_obs, y_obs, x)
    mu = sign * mu
    axis.plot(x, mu, dashes=(12, 3.5), color='blue', lw=2.5, label='mean prediction')
    # Plot credible interval
    quant = 1.96
    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - quant * sigma, (mu + quant * sigma)[::-1]]),
        alpha=.6, fc='paleturquoise', ec='None', label='95% credible interval')
    # Set parameters
    xlim = (-2,10)
    axis.set_xlim(xlim)
    axis.set_xlabel('x')
    axis.set_ylim(-1.61, 0.01)
    axis.set_ylabel('objective function')
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

    ## ACQUISITION PLOT
    utility_function = UtilityFunction(kind="ucb", kappa=5, xi=0)
    utility = utility_function.utility(x, optimizer._gp, 0)
    x_next = x[np.argmax(utility)]
    print(x_next)
    acq.plot(x, utility, label='acquisition function', lw=2, color='fuchsia')
    acq.scatter(x_next, np.max(utility), marker='x', s=300, 
             label='next observation', ec='red', lw=4, zorder=10)
    acq.set_xlim(xlim)
    acq.set_ylim((0, 2.501))
    acq.set_ylabel('utility')
    acq.set_xlabel('x')
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1))

    # Vertical lines in both
    axis.vlines(x_next, sign*0, sign*1.6, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')
    acq.vlines(x_next,       0,        5, lw=1.5, linestyle=(0, (10, 3.5)), color='silver')

    # Overlay vertical Gaussian distribution
    ypos_idx = np.abs(x-x_next).argmin()
    ypos = mu[ypos_idx]
    var = 0.6 * sigma[ypos_idx]  # I'm cheating a little bit with the variance
                                 # for representation purposes
    bound = 0.5
    supp = np.linspace(-bound, bound, 1000).reshape(-1, 1)
    gaussian = np.exp((-supp ** 2.0) / (2 * var ** 2.0))
    gaussian /= gaussian.max()
    gaussian *= -0.5  # height
    axis.plot(gaussian + x_next, supp + ypos, lw=1.5, color='silver')

    # Save to file
    for fmt in ('png', 'svg'):
        filename = f'bo_{style}_{len(x_obs)}.{fmt}'
        plt.savefig(os.path.join('resources', filename), bbox_inches='tight', dpi=300)

# # UCB
# # Initialize optimizer
# optimizer = BayesianOptimization(target, {'x': (-2, 10)},
#                                  random_state=272242)
# # First rounds of optimization
# optimizer.maximize(init_points=3, n_iter=1, kappa=5)
# for style in ('classic', 'dark'):  # ('transparent', 'classic', 'dark')
#     plot_gp(optimizer, x, y, show_minimized=True, style=style)

# EB
# Initialize optimizer again
optimizer = BayesianOptimization(target, {'x': (0,1)
                                          ,'y': (0,1)
                                           }, 
                                 random_state=27222,barrier_func={'constraint1': lambda x,y: 3/2 -x-2*y - 1/2*np.sin(2*np.pi*(x**2 - 2*y)),
                                                                  'constraint2': lambda x,y: x**2 + y**2 - 3/2
                                                                  }, debug = True)
# Other rounds of optimization
with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    warnings.simplefilter("ignore", FutureWarning)
    optimizer.maximize(init_points=10, n_iter=120,acq='eb',mean_p = 1.,std_p = 1.,acq_info={'static_lambda':False})
# Out:
# Initializing TargetSpace with bounds: {'x': (0, 1), 'y': (0, 1)}
# initialize_dataset(): dataset is None
# TargetSpace initialization completed
# BayesianOptimization initialization completed
# Starting maximize()
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# _prime_queue(): initializing 10 random points
# Uniform randomly sampled point: value [[0.07519784 0.52681689]]
# Uniform randomly sampled point: value [[0.32681975 0.86190258]]
# Uniform randomly sampled point: value [[0.61254226 0.34574648]]
# Uniform randomly sampled point: value [[0.80114922 0.45265681]]
# Uniform randomly sampled point: value [[0.12850917 0.61009722]]
# Uniform randomly sampled point: value [[0.4140246  0.22827787]]
# Uniform randomly sampled point: value [[0.54206149 0.78481709]]
# Uniform randomly sampled point: value [[0.77107487 0.97016069]]
# Uniform randomly sampled point: value [[0.2238236 0.1646788]]
# Uniform randomly sampled point: value [[0.97405925 0.06397921]]
# Initializing UtilityFunction of kind 'eb' with acq_info = {'static_lambda': False}
# Setting 'static_lambda' field of acq_info to 'static_lambda' member
# UtilityFunction initialization completed
# Initializing StoppingCriterion with stop_crit_info = {}
# StoppingCriterion initialization completed
# ++++++++++++++++++++++++
# Starting optimization loop
# New iteration: selected point from queue, index None, value {'x': 0.07519783516280615, 'y': 0.5268168888435392}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.07519783516280615, 'y': 0.5268168888435392}
# Registering params [0.07519784 0.52681689] with index None and target value -0.6020147240063454
# Extracting info: target -0.6020147240063454 is scalar
# Point registered successfully
# Probed target value: -0.6020147240063454
# Probing_barriers at point: index None, value {'x': 0.07519783516280615, 'y': 0.5268168888435392}
# Probed barrier_target values: [ 0.51962637 -1.21680925]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.3268197546963732, 'y': 0.8619025766885942}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.3268197546963732, 'y': 0.8619025766885942}
# Registering params [0.32681975 0.86190258] with index None and target value -1.1887223313849673
# Extracting info: target -1.1887223313849673 is scalar
# Point registered successfully
# Probed target value: -1.1887223313849673
# Probing_barriers at point: index None, value {'x': 0.3268197546963732, 'y': 0.8619025766885942}
# Probed barrier_target values: [-0.88595372 -0.6503128 ]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.6125422626461969, 'y': 0.34574647528665803}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.6125422626461969, 'y': 0.34574647528665803}
# Registering params [0.61254226 0.34574648] with index None and target value -0.958288737932855
# Extracting info: target -0.958288737932855 is scalar
# Point registered successfully
# Probed target value: -0.958288737932855
# Probing_barriers at point: index None, value {'x': 0.6125422626461969, 'y': 0.34574647528665803}
# Probed barrier_target values: [ 0.65322399 -1.00525135]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.8011492218294466, 'y': 0.45265680903797856}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.8011492218294466, 'y': 0.45265680903797856}
# Registering params [0.80114922 0.45265681] with index None and target value -1.253806030867425
# Extracting info: target -1.253806030867425 is scalar
# Point registered successfully
# Probed target value: -1.253806030867425
# Probing_barriers at point: index None, value {'x': 0.8011492218294466, 'y': 0.45265680903797856}
# Probed barrier_target values: [ 0.29174654 -0.65326174]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.12850917142212617, 'y': 0.6100972239397024}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.12850917142212617, 'y': 0.6100972239397024}
# Registering params [0.12850917 0.61009722] with index None and target value -0.7386063953618286
# Extracting info: target -0.7386063953618286 is scalar
# Point registered successfully
# Probed target value: -0.7386063953618286
# Probing_barriers at point: index None, value {'x': 0.12850917142212617, 'y': 0.6100972239397024}
# Probed barrier_target values: [ 0.63026963 -1.11126677]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.41402459553241033, 'y': 0.22827786973858455}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.41402459553241033, 'y': 0.22827786973858455}
# Registering params [0.4140246  0.22827787] with index None and target value -0.6423024652709949
# Extracting info: target -0.6423024652709949 is scalar
# Point registered successfully
# Probed target value: -0.6423024652709949
# Probing_barriers at point: index None, value {'x': 0.41402459553241033, 'y': 0.22827786973858455}
# Probed barrier_target values: [ 1.11728234 -1.27647285]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.5420614892125803, 'y': 0.7848170892374507}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.5420614892125803, 'y': 0.7848170892374507}
# Registering params [0.54206149 0.78481709] with index None and target value -1.3268785784500312
# Extracting info: target -1.3268785784500312 is scalar
# Point registered successfully
# Probed target value: -1.3268785784500312
# Probing_barriers at point: index None, value {'x': 0.5420614892125803, 'y': 0.7848170892374507}
# Probed barrier_target values: [-0.11825268 -0.59023148]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.7710748747088971, 'y': 0.9701606898831677}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.7710748747088971, 'y': 0.9701606898831677}
# Registering params [0.77107487 0.97016069] with index None and target value -1.7412355645920647
# Extracting info: target -1.7412355645920647 is scalar
# Point registered successfully
# Probed target value: -1.7412355645920647
# Probing_barriers at point: index None, value {'x': 0.7710748747088971, 'y': 0.9701606898831677}
# Probed barrier_target values: [-0.79921146  0.03576823]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.22382359960439993, 'y': 0.16467879772759503}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.22382359960439993, 'y': 0.16467879772759503}
# Registering params [0.2238236 0.1646788] with index None and target value -0.388502397331995
# Extracting info: target -0.388502397331995 is scalar
# Point registered successfully
# Probed target value: -0.388502397331995
# Probing_barriers at point: index None, value {'x': 0.22382359960439993, 'y': 0.16467879772759503}
# Probed barrier_target values: [ 1.4383924  -1.42278389]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration: selected point from queue, index None, value {'x': 0.9740592545571808, 'y': 0.06397921383673351}
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.9740592545571808, 'y': 0.06397921383673351}
# Registering params [0.97405925 0.06397921] with index None and target value -1.0380384683939143
# Extracting info: target -1.0380384683939143 is scalar
# Point registered successfully
# Probed target value: -1.0380384683939143
# Probing_barriers at point: index None, value {'x': 0.9740592545571808, 'y': 0.06397921383673351}
# Probed barrier_target values: [ 0.84927541 -0.54711523]
# Point was not selected by suggest(): skipping termination check
# Registered optimization information:
#       acquisition terminated
# None          NaN      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 0: suggesting new point
# Suggested point: index None, value {'x': 0.01481910115083482, 'y': 0.8056549427958867}, acquisition [0.87639619]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.01481910115083482, 'y': 0.8056549427958867}
# Registering params [0.0148191  0.80565494] with index None and target value -0.8204740439467215
# Extracting info: target -0.8204740439467215 is scalar
# Point registered successfully
# Probed target value: -0.8204740439467215
# Probing_barriers at point: index None, value {'x': 0.01481910115083482, 'y': 0.8056549427958867}
# Probed barrier_target values: [-0.44747266 -0.85070051]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.876396      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 1: suggesting new point
# Suggested point: index None, value {'x': 0.007729921876848621, 'y': 0.6918316518006462}, acquisition [0.70714247]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.007729921876848621, 'y': 0.6918316518006462}
# Registering params [0.00772992 0.69183165] with index None and target value -0.6995615736774948
# Extracting info: target -0.6995615736774948 is scalar
# Point registered successfully
# Probed target value: -0.6995615736774948
# Probing_barriers at point: index None, value {'x': 0.007729921876848621, 'y': 0.6918316518006462}
# Probed barrier_target values: [ 0.44254073 -1.02130921]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.707142      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 2: suggesting new point
# Suggested point: index None, value {'x': 0.0010798563019512525, 'y': 0.7619618621250149}, acquisition [0.76318433]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.0010798563019512525, 'y': 0.7619618621250149}
# Registering params [0.00107986 0.76196186] with index None and target value -0.7630417184269662
# Extracting info: target -0.7630417184269662 is scalar
# Point registered successfully
# Probed target value: -0.7630417184269662
# Probing_barriers at point: index None, value {'x': 0.0010798563019512525, 'y': 0.7619618621250149}
# Probed barrier_target values: [-0.09987584 -0.91941295]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.763184      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 3: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75263403]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752634      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 4: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.7526278]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752628      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 5: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262567]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 6: suggesting new point
# Suggested point: index None, value {'x': 0.0016162000303123665, 'y': 0.7232961549929645}, acquisition [0.72488368]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.0016162000303123665, 'y': 0.7232961549929645}
# Registering params [0.0016162  0.72329615] with index None and target value -0.7249123550232769
# Extracting info: target -0.7249123550232769 is scalar
# Point registered successfully
# Probed target value: -0.7249123550232769
# Probing_barriers at point: index None, value {'x': 0.0016162000303123665, 'y': 0.7232961549929645}
# Probed barrier_target values: [ 0.21645315 -0.97684006]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.724884      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 7: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262869]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752629      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 8: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262762]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752628      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 9: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262689]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752627      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 10: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262637]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 11: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262598]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 12: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262567]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 13: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262543]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 14: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262523]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 15: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262506]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 16: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262492]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 17: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.7526248]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 18: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.7526247]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 19: suggesting new point
# Suggested point: index None, value {'x': 0.003343683383244882, 'y': 0.7455761780603846}, acquisition [0.74882382]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.003343683383244882, 'y': 0.7455761780603846}
# Registering params [0.00334368 0.74557618] with index None and target value -0.7489198614436294
# Extracting info: target -0.7489198614436294 is scalar
# Point registered successfully
# Probed target value: -0.7489198614436294
# Probing_barriers at point: index None, value {'x': 0.003343683383244882, 'y': 0.7455761780603846}
# Probed barrier_target values: [ 0.03332041 -0.94410498]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.748824      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 20: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262615]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 21: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262592]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 22: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262573]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 23: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262556]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752626      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 24: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.7526254]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 25: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262526]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 26: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262513]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 27: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262502]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 28: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262492]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 29: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262482]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 30: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262473]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 31: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262466]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 32: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262458]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 33: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262452]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752625      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 34: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262446]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752624      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 35: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.7526244]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752624      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 36: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262435]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752624      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 37: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.7526243]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752624      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 38: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262425]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752624      False
# End of current iteration
# ++++++++++++++++++++++++
# ...
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 104: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262349]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 105: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262349]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 106: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262349]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 107: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262349]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 108: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262348]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 109: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262348]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 110: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262348]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 111: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262348]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 112: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262348]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 113: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262347]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 114: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262347]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 115: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262347]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 116: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262347]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 117: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262347]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 118: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262347]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# New iteration 119: suggesting new point
# Suggested point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}, acquisition [0.75262346]
# No dataset, or dataset for X only: evaluating target function
# Probing point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Registering params [1.02557147e-04 7.52520810e-01] with index None and target value -0.752623366869562
# Extracting info: target -0.752623366869562 is scalar
# Point registered successfully
# Probed target value: -0.752623366869562
# Probing_barriers at point: index None, value {'x': 0.000102557146854293, 'y': 0.7525208097227077}
# Probed barrier_target values: [-0.02098021 -0.93371242]
# No termination criteria have been used
# Result of termination criteria: False
# Registered optimization information:
#       acquisition terminated
# None     0.752623      False
# End of current iteration
# ++++++++++++++++++++++++
# Saved current results to /Users/niccoloferesini/Desktop/MALIBOO
# max: {'target': -0.752623366869562, 'params': {'x': 0.000102557146854293, 'y': 0.7525208097227077}}
# Results successfully saved to /Users/niccoloferesini/Desktop/MALIBOO
# =================================================

# %%
# PLOT THE RESULTS 


resultsdf = pd.read_csv('results.csv', usecols=['x','y','target'])
first50 = pd.read_csv('results.csv', usecols=['x','y']).iloc[:ninit]
resultsdf = resultsdf.iloc[ninit:].reset_index(drop = True)

# mask = np.where(resultsdf['target'] <= 2.002)[0]
x_iter = resultsdf['x']#.iloc[mask]
y_iter = resultsdf['y']#.iloc[mask]
# plt.hist(x_iter)
# meshgrid
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)

Z_target = gramacy(X, Y)
Z_constraint1 = constraint1(X, Y)
Z_constraint2 = constraint2(X,Y)

# target contour levels
plt.figure(figsize=(10, 8))
contour_target = plt.contourf(X, Y, Z_target, levels=25,cmap='YlOrRd') # Use 100 levels for smooth gradients
plt.colorbar(contour_target)

# constraint contour levels (only 2: >0 or <=0)
# grey for <= 0, transparent for > 0
plt.contourf(X, Y, Z_constraint1 <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.contourf(X, Y, Z_constraint2 <= 0, levels=[-np.inf, 0, np.inf], colors=['0.8', 'none'])
plt.scatter(x_iter, y_iter, s=20, alpha = 0.5)
plt.scatter(0.2107769570103368, 0.4055921617970899, color = 'black')
plt.scatter(0.1954, 0.40449, edgecolors='red', facecolors='none', linewidths=1.5)
plt.scatter(first50['x'],first50['y'],s = 10, color = 'red')
